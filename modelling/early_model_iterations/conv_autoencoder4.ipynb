# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import time
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset

# %%
def generate_random_samples(batch, read = "/Users/maks/Documents/MSc_project/data/features", sequence_length = 60):
    """
    A function that creates a list of independent arrays that are to serve as samples for processing later.
    read is the directory where Excel files containing variables are stored;
    batch is the number of samples that will be generated;
    sequence length is the length of each sample.
    Returns a list of numpy arrays.
    """

    def load_excel(file_path):
        """
        Extracts sheets from Excel files given a file directory.
        """
        excel_file = pd.ExcelFile(file_path)
        
        sheets = {sheet_name: pd.read_excel(excel_file, sheet_name = sheet_name) for sheet_name in excel_file.sheet_names}

        return sheets
    
    def random_file(read):
        """
        Chooses a random file from a provided directory.
        """
        files = [f for f in os.listdir(read) if f.endswith(".xlsx") and not f.startswith(".")]
        
        if not files:
            raise FileNotFoundError("No Excel files found in the directory")
        
        return os.path.join(read, random.choice(files))
    
    def normalise_columns(df, columns):
        """
        Normalises specified columns between -1 and 1.
        """
        df = df.copy()  # Make a copy to avoid modifying the original DataFrame
    
        for column in columns:
            max_val = df[column].max()
            min_val = df[column].min()
            
            df.loc[:, column] = 2 * (df[column] - min_val) / (max_val - min_val) - 1

        return df

    def sampler(sheet_data, sequence_length):
        """
        Randomly creates a sample from an Excel sheet.
        sheet_data are sheets representing time series segments from where data is going to be sampled
        sequence_length is the number of points each sample will contain.
        """

        #Normalises velocities and angular velocities using normalise_columns
        columns = ["velocity_x", "velocity_y", "velocity_z","tortuosity3d", "angular_velocity_yz", "angular_velocity_xz", "angular_velocity_xy"]
        sheet_data = normalise_columns(sheet_data, columns)

        num_points = len(sheet_data)

        if num_points < sequence_length + 2:
            return None
        
        start_index = random.randint(2, num_points - sequence_length)
        end_index = start_index + sequence_length
        sample = sheet_data.iloc[start_index : end_index].to_numpy()

        return sample #Transposes the samle to switch rows and columns
    
    def weighted_random_choice(sheets):
        """
        Assigns weights to sheets based on the length of each sheet.
        """
        total_points = sum(len(data) for data in sheets.values())
        weights = [len(data) / total_points for data in sheets.values()]

        return random.choices(list(sheets.keys()), weights = weights, k = 1)[0]
    
    #Initializes list to strore sample arrays
    samples = []

    while len(samples) < batch:
        file_path = random_file(read)
        sheets = load_excel(file_path)

        while len(samples) < batch:
            sheet_name = weighted_random_choice(sheets)
            sheet_data = sheets[sheet_name][["velocity_x", "velocity_y", "velocity_z", "tortuosity3d", "angular_velocity_yz", "angular_velocity_xz", "angular_velocity_xy"]]
            sample = sampler(sheet_data, sequence_length)

            if sample is not None:
                samples.append(sample)

            #Stops once batch size is reached
            if len(samples) >= batch:
                break

    return samples

# %%
#Class to contain our sampled time series data
class TimeSeriesData(Dataset):
    def __init__(self, no_samples):
        self.data = generate_random_samples(no_samples)

        # Converts the list of numpy arrays to a single numpy array
        self.data = np.array(self.data)
                             
        self.data = torch.tensor(self.data, dtype = torch.float32)
    
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, i):
        return self.data[i]

# %%
#Convolutional autoencoder model
class ConvAutoencoder(nn.Module):
    def __init__(self):
        super(ConvAutoencoder, self).__init__()

        #Encoder
        self.encoder = nn.Sequential(
            nn.Conv1d(in_channels = 7, out_channels = 16, kernel_size = 3, stride = 1, padding = 1), 
            nn.ELU(),
            nn.MaxPool1d(kernel_size = 2, stride = 2), 
            #nn.Dropout(0.1),

            nn.Conv1d(in_channels = 16, out_channels = 32, kernel_size = 3, stride = 1, padding = 1), 
            nn.ELU(),
            nn.MaxPool1d(kernel_size = 2, stride = 2), 
            #nn.Dropout(0.2),

            nn.Conv1d(in_channels = 32, out_channels = 64, kernel_size = 3, stride = 1, padding = 1),
            nn.ELU(),
            nn.MaxPool1d(kernel_size = 2, stride = 2),
            #nn.Dropout(0.3)
        )

        #Decoder
        self.decoder = nn.Sequential(
            nn.ConvTranspose1d(in_channels = 64, out_channels = 32, kernel_size = 2, stride = 2, output_padding = 1),
            nn.ELU(),
            #nn.Dropout(0.3),

            nn.ConvTranspose1d(in_channels = 32, out_channels = 16, kernel_size = 2, stride = 2), 
            nn.ELU(),
            #nn.Dropout(0.3),

            nn.ConvTranspose1d(in_channels = 16, out_channels =8, kernel_size = 2, stride = 2), 
            nn.ELU(),
            #nn.Dropout(0.3),

            nn.ConvTranspose1d(in_channels = 8, out_channels = 7, kernel_size = 3, stride = 1, padding = 1), 
            nn.Tanh(),
        )

    def forward(self, x):
        x = x.permute(0, 2, 1)
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        decoded = decoded.permute(0, 2, 1)
        return decoded
    
    def encode(self, x):
        x = x.permute(0, 2, 1)
        encoded = self.encoder(x)
        return encoded

# %%
#Dataset and dataloader parameters
no_samples = 480
batch_size = 32

# %%
#Model, loss function and optimiser
model = ConvAutoencoder()
criterion = nn.L1Loss()
optimiser = optim.Adam(model.parameters(), lr = 0.001)
max_gradient_norm = 1.0

# %%
#Training loop
no_episodes = 50
epochs = 15
#os.makedirs("/Users/maks/Documents/MSc_project/data/hidden_layer_representations/day_1", exist_ok = True)

for episode in range(no_episodes):
    print(f"Starting episode {episode + 1}/{no_episodes}")

    #Generates dataset
    dataset = TimeSeriesData(no_samples)
    dataloader = DataLoader(dataset, batch_size = batch_size, shuffle = True)

    #Records start time for an episode
    start_time = time.time()

    for epoch in range(epochs):
        epoch_loss = 0.0
        for batch_data in dataloader:
            #Forward pass
            output = model(batch_data)
            loss = criterion(output, batch_data)

            #Backward pass
            optimiser.zero_grad()
            loss.backward()

            #Gradient clipping
            nn.utils.clip_grad_norm_(model.parameters(), max_gradient_norm)

            #Optimisation step
            optimiser.step()

            epoch_loss += loss.item()

        average_epoch_loss = epoch_loss / len(dataloader)
        print(f"Episode {episode + 1 }, epoch [{epoch + 1}/{epochs}], loss: {average_epoch_loss}")

    #Records end time of the episode
    end_time = time.time()

    #Prints duration of the episode
    runtime = end_time - start_time
    print(f"Episode {episode + 1} completed in {runtime:.2f} seconds")

    #Saves hidden layer representation every 10 episodes
    if (episode + 1) % 10 == 0:
        hidden_representations = []
        for batch_data in dataloader:
            with torch.no_grad():
                hidden_repr = model.encode(batch_data)
                hidden_representations.append(hidden_repr.numpy())

        hidden_representations = np.concatenate(hidden_representations, axis = 0)
        np.save(f"/Users/maks/Documents/MSc_project/data/hidden_layer_representations/day_1/hidden_representations_episode_{episode + 1}.npy", hidden_representations)
        print(f"Saved hidden representations for episode {episode + 1}")

print("Training finished!")
# Out:
# Starting episode 1/50
# Episode 1, epoch [1/15], loss: 0.33099226156870526
# Episode 1, epoch [2/15], loss: 0.3028621693452199
# Episode 1, epoch [3/15], loss: 0.26228278279304507
# Episode 1, epoch [4/15], loss: 0.23760848542054494
# Episode 1, epoch [5/15], loss: 0.22785938580830892
# Episode 1, epoch [6/15], loss: 0.22050891717274984
# Episode 1, epoch [7/15], loss: 0.21003809571266174
# Episode 1, epoch [8/15], loss: 0.20012796819210052
# Episode 1, epoch [9/15], loss: 0.1943786064783732
# Episode 1, epoch [10/15], loss: 0.1901702692111333
# Episode 1, epoch [11/15], loss: 0.18584230939547222
# Episode 1, epoch [12/15], loss: 0.1803291251262029
# Episode 1, epoch [13/15], loss: 0.17264705002307892
# Episode 1, epoch [14/15], loss: 0.16716097195943197
# Episode 1, epoch [15/15], loss: 0.16402767797311146
# Episode 1 completed in 9.50 seconds
# Starting episode 2/50
# Episode 2, epoch [1/15], loss: 0.15576321283976238
# Episode 2, epoch [2/15], loss: 0.150495574871699
# Episode 2, epoch [3/15], loss: 0.14780276616414387
# Episode 2, epoch [4/15], loss: 0.1457662910223007
# Episode 2, epoch [5/15], loss: 0.14392745594183604
# Episode 2, epoch [6/15], loss: 0.1428958167632421
# Episode 2, epoch [7/15], loss: 0.14185368567705153
# Episode 2, epoch [8/15], loss: 0.14134547313054402
# Episode 2, epoch [9/15], loss: 0.14054738283157348
# Episode 2, epoch [10/15], loss: 0.13932482798894247
# Episode 2, epoch [11/15], loss: 0.13873420854409535
# Episode 2, epoch [12/15], loss: 0.13798066427310307
# Episode 2, epoch [13/15], loss: 0.1374804362654686
# Episode 2, epoch [14/15], loss: 0.13663982500632604
# Episode 2, epoch [15/15], loss: 0.1363372469941775
# Episode 2 completed in 9.29 seconds
# Starting episode 3/50
# Episode 3, epoch [1/15], loss: 0.11334669242302577
# Episode 3, epoch [2/15], loss: 0.11106761346260706
# Episode 3, epoch [3/15], loss: 0.10965181340773901
# Episode 3, epoch [4/15], loss: 0.10821902602910996
# Episode 3, epoch [5/15], loss: 0.10705083658297856
# Episode 3, epoch [6/15], loss: 0.10637701054414113
# Episode 3, epoch [7/15], loss: 0.10553486694892247
# Episode 3, epoch [8/15], loss: 0.10516236871480941
# Episode 3, epoch [9/15], loss: 0.10456418842077256
# Episode 3, epoch [10/15], loss: 0.10381521433591842
# Episode 3, epoch [11/15], loss: 0.10323849419752756
# Episode 3, epoch [12/15], loss: 0.10282383859157562
# Episode 3, epoch [13/15], loss: 0.10259199688831964
# Episode 3, epoch [14/15], loss: 0.1029500961303711
# Episode 3, epoch [15/15], loss: 0.10231170207262039
# Episode 3 completed in 9.34 seconds
# Starting episode 4/50
# Episode 4, epoch [1/15], loss: 0.15125072300434111
# Episode 4, epoch [2/15], loss: 0.14709254801273347
# Episode 4, epoch [3/15], loss: 0.14606538911660513
# Episode 4, epoch [4/15], loss: 0.14408744871616364
# Episode 4, epoch [5/15], loss: 0.1434504081805547
# Episode 4, epoch [6/15], loss: 0.14263624946276346
# Episode 4, epoch [7/15], loss: 0.142109810312589
# Episode 4, epoch [8/15], loss: 0.14095124900341033
# Episode 4, epoch [9/15], loss: 0.14001140942176182
# Episode 4, epoch [10/15], loss: 0.13941688189903895
# Episode 4, epoch [11/15], loss: 0.13878132899602255
# Episode 4, epoch [12/15], loss: 0.138052499294281
# Episode 4, epoch [13/15], loss: 0.1376791218916575
# Episode 4, epoch [14/15], loss: 0.13767091830571493
# Episode 4, epoch [15/15], loss: 0.13679704070091248
# Episode 4 completed in 9.35 seconds
# Starting episode 5/50
# Episode 5, epoch [1/15], loss: 0.138724052409331
# Episode 5, epoch [2/15], loss: 0.13754626661539077
# Episode 5, epoch [3/15], loss: 0.1368110532561938
# Episode 5, epoch [4/15], loss: 0.13644454578558604
# Episode 5, epoch [5/15], loss: 0.13573771864175796
# Episode 5, epoch [6/15], loss: 0.1355432321627935
# Episode 5, epoch [7/15], loss: 0.1351771558324496
# Episode 5, epoch [8/15], loss: 0.1347082108259201
# Episode 5, epoch [9/15], loss: 0.1343147004644076
# Episode 5, epoch [10/15], loss: 0.13389840424060823
# Episode 5, epoch [11/15], loss: 0.1338568687438965
# Episode 5, epoch [12/15], loss: 0.13356090436379114
# Episode 5, epoch [13/15], loss: 0.1332393596569697
# Episode 5, epoch [14/15], loss: 0.13363825529813766
# Episode 5, epoch [15/15], loss: 0.13337857772906622
# Episode 5 completed in 9.55 seconds
# Starting episode 6/50
# Episode 6, epoch [1/15], loss: 0.13611396153767905
# Episode 6, epoch [2/15], loss: 0.13558640480041503
# Episode 6, epoch [3/15], loss: 0.13505789488554001
# Episode 6, epoch [4/15], loss: 0.13445292164882025
# Episode 6, epoch [5/15], loss: 0.13455358743667603
# Episode 6, epoch [6/15], loss: 0.13426833997170132
# Episode 6, epoch [7/15], loss: 0.133952992161115
# Episode 6, epoch [8/15], loss: 0.13397919336954753
# Episode 6, epoch [9/15], loss: 0.13373543073733649
# Episode 6, epoch [10/15], loss: 0.13401675273974736
# Episode 6, epoch [11/15], loss: 0.1332834149400393
# Episode 6, epoch [12/15], loss: 0.13335242768128713
# Episode 6, epoch [13/15], loss: 0.13314610620339712
# Episode 6, epoch [14/15], loss: 0.13313184728225072
# Episode 6, epoch [15/15], loss: 0.13289206673701603
# Episode 6 completed in 9.42 seconds
# Starting episode 7/50
# Episode 7, epoch [1/15], loss: 0.1451329876979192
# Episode 7, epoch [2/15], loss: 0.14567063053448995
# Episode 7, epoch [3/15], loss: 0.14439671834309895
# Episode 7, epoch [4/15], loss: 0.14322467843691508
# Episode 7, epoch [5/15], loss: 0.14369343221187592
# Episode 7, epoch [6/15], loss: 0.1433523585398992
# Episode 7, epoch [7/15], loss: 0.14267612348000208
# Episode 7, epoch [8/15], loss: 0.14262076665957768
# Episode 7, epoch [9/15], loss: 0.14260212232669195
# Episode 7, epoch [10/15], loss: 0.14233059684435526
# Episode 7, epoch [11/15], loss: 0.14281836251417795
# Episode 7, epoch [12/15], loss: 0.14190285950899123
# Episode 7, epoch [13/15], loss: 0.1413215031226476
# Episode 7, epoch [14/15], loss: 0.14145186841487883
# Episode 7, epoch [15/15], loss: 0.14151579042275747
# Episode 7 completed in 9.22 seconds
# Starting episode 8/50
# Episode 8, epoch [1/15], loss: 0.1620521197716395
# Episode 8, epoch [2/15], loss: 0.16127834220727286
# Episode 8, epoch [3/15], loss: 0.1603126883506775
# Episode 8, epoch [4/15], loss: 0.15975032647450765
# Episode 8, epoch [5/15], loss: 0.1596255987882614
# Episode 8, epoch [6/15], loss: 0.15957626203695932
# Episode 8, epoch [7/15], loss: 0.15939455529054006
# Episode 8, epoch [8/15], loss: 0.15844212770462035
# Episode 8, epoch [9/15], loss: 0.15819082061449688
# Episode 8, epoch [10/15], loss: 0.15811218520005543
# Episode 8, epoch [11/15], loss: 0.1568724185228348
# Episode 8, epoch [12/15], loss: 0.15670747955640157
# Episode 8, epoch [13/15], loss: 0.15696954925855
# Episode 8, epoch [14/15], loss: 0.15638644695281984
# Episode 8, epoch [15/15], loss: 0.15640538235505422
# Episode 8 completed in 9.30 seconds
# Starting episode 9/50
# Episode 9, epoch [1/15], loss: 0.13419266939163207
# Episode 9, epoch [2/15], loss: 0.13302805374066035
# Episode 9, epoch [3/15], loss: 0.13264051328102747
# Episode 9, epoch [4/15], loss: 0.13239459892114003
# Episode 9, epoch [5/15], loss: 0.13212730834881464
# Episode 9, epoch [6/15], loss: 0.13182558317979176
# Episode 9, epoch [7/15], loss: 0.13173171679178874
# Episode 9, epoch [8/15], loss: 0.1316165879368782
# Episode 9, epoch [9/15], loss: 0.13158835719029108
# Episode 9, epoch [10/15], loss: 0.13150067528088888
# Episode 9, epoch [11/15], loss: 0.13165182024240493
# Episode 9, epoch [12/15], loss: 0.13132493098576864
# Episode 9, epoch [13/15], loss: 0.13165919383366903
# Episode 9, epoch [14/15], loss: 0.13170959701140722
# Episode 9, epoch [15/15], loss: 0.13119255900382995
# Episode 9 completed in 9.38 seconds
# Starting episode 10/50
# Episode 10, epoch [1/15], loss: 0.11859213709831237
# Episode 10, epoch [2/15], loss: 0.11818174670139948
# Episode 10, epoch [3/15], loss: 0.11851831128199895
# Episode 10, epoch [4/15], loss: 0.11822365870078405
# Episode 10, epoch [5/15], loss: 0.11762042889992395
# Episode 10, epoch [6/15], loss: 0.11764533321062724
# Episode 10, epoch [7/15], loss: 0.11742511789004008
# Episode 10, epoch [8/15], loss: 0.11715039759874343
# Episode 10, epoch [9/15], loss: 0.11739838620026906
# Episode 10, epoch [10/15], loss: 0.11726621786753337
# Episode 10, epoch [11/15], loss: 0.11704478909571965
# Episode 10, epoch [12/15], loss: 0.11687827159961064
# Episode 10, epoch [13/15], loss: 0.11712312002976735
# Episode 10, epoch [14/15], loss: 0.11748650223016739
# Episode 10, epoch [15/15], loss: 0.11692812244097392
# Episode 10 completed in 9.09 seconds
# Saved hidden representations for episode 10
# Starting episode 11/50
# Episode 11, epoch [1/15], loss: 0.10607370932896933
# Episode 11, epoch [2/15], loss: 0.10567857374747594
# Episode 11, epoch [3/15], loss: 0.10549777100483576
# Episode 11, epoch [4/15], loss: 0.10505510767300924
# Episode 11, epoch [5/15], loss: 0.10491978526115417
# Episode 11, epoch [6/15], loss: 0.10474931846062342
# Episode 11, epoch [7/15], loss: 0.10471305052439371
# Episode 11, epoch [8/15], loss: 0.10470894873142242
# Episode 11, epoch [9/15], loss: 0.10459817548592885
# Episode 11, epoch [10/15], loss: 0.10450124690930049
# Episode 11, epoch [11/15], loss: 0.10435804824034373
# Episode 11, epoch [12/15], loss: 0.10417889008919398
# Episode 11, epoch [13/15], loss: 0.10411228736241658
# Episode 11, epoch [14/15], loss: 0.10412502686182658
# Episode 11, epoch [15/15], loss: 0.10416800677776336
# Episode 11 completed in 9.25 seconds
# Starting episode 12/50
# Episode 12, epoch [1/15], loss: 0.1333136300245921
# Episode 12, epoch [2/15], loss: 0.13291070163249968
# Episode 12, epoch [3/15], loss: 0.13234157065550486
# Episode 12, epoch [4/15], loss: 0.13212029089530308
# Episode 12, epoch [5/15], loss: 0.1321524366736412
# Episode 12, epoch [6/15], loss: 0.13236380964517594
# Episode 12, epoch [7/15], loss: 0.13235915104548138
# Episode 12, epoch [8/15], loss: 0.13191616535186768
# Episode 12, epoch [9/15], loss: 0.13198727717002232
# Episode 12, epoch [10/15], loss: 0.1319478154182434
# Episode 12, epoch [11/15], loss: 0.1315890168150266
# Episode 12, epoch [12/15], loss: 0.13154680728912355
# Episode 12, epoch [13/15], loss: 0.13151167184114457
# Episode 12, epoch [14/15], loss: 0.13127683649460475
# Episode 12, epoch [15/15], loss: 0.13116314460833867
# Episode 12 completed in 9.41 seconds
# Starting episode 13/50
# Episode 13, epoch [1/15], loss: 0.12965933978557587
# Episode 13, epoch [2/15], loss: 0.1287975490093231
# Episode 13, epoch [3/15], loss: 0.12851855903863907
# Episode 13, epoch [4/15], loss: 0.12827266852060953
# Episode 13, epoch [5/15], loss: 0.12847997148831686
# Episode 13, epoch [6/15], loss: 0.12819559971491495
# Episode 13, epoch [7/15], loss: 0.12815241614977518
# Episode 13, epoch [8/15], loss: 0.12850405027469
# Episode 13, epoch [9/15], loss: 0.12843846132357914
# Episode 13, epoch [10/15], loss: 0.1280043229460716
# Episode 13, epoch [11/15], loss: 0.12818971027930579
# Episode 13, epoch [12/15], loss: 0.12787101914485297
# Episode 13, epoch [13/15], loss: 0.12826968729496002
# Episode 13, epoch [14/15], loss: 0.12788660774628322
# Episode 13, epoch [15/15], loss: 0.12829587360223135
# Episode 13 completed in 9.11 seconds
# Starting episode 14/50
# Episode 14, epoch [1/15], loss: 0.1397027591864268
# Episode 14, epoch [2/15], loss: 0.1393364851673444
# Episode 14, epoch [3/15], loss: 0.13909088919560114
# Episode 14, epoch [4/15], loss: 0.13862904012203217
# Episode 14, epoch [5/15], loss: 0.13831948737303415
# Episode 14, epoch [6/15], loss: 0.13847988545894624
# Episode 14, epoch [7/15], loss: 0.13833496967951456
# Episode 14, epoch [8/15], loss: 0.13840994586547214
# Episode 14, epoch [9/15], loss: 0.13857868810494742
# Episode 14, epoch [10/15], loss: 0.13879921684662502
# Episode 14, epoch [11/15], loss: 0.13831570545832317
# Episode 14, epoch [12/15], loss: 0.13813457588354747
# Episode 14, epoch [13/15], loss: 0.13802872200806934
# Episode 14, epoch [14/15], loss: 0.1379349112510681
# Episode 14, epoch [15/15], loss: 0.13762239416440328
# Episode 14 completed in 9.33 seconds
# Starting episode 15/50
# Episode 15, epoch [1/15], loss: 0.13038179626067478
# Episode 15, epoch [2/15], loss: 0.1302481527129809
# Episode 15, epoch [3/15], loss: 0.12983099669218062
# Episode 15, epoch [4/15], loss: 0.13012140144904455
# Episode 15, epoch [5/15], loss: 0.12956465184688568
# Episode 15, epoch [6/15], loss: 0.12946381469567617
# Episode 15, epoch [7/15], loss: 0.12937067449092865
# Episode 15, epoch [8/15], loss: 0.12926651885112125
# Episode 15, epoch [9/15], loss: 0.12908104012409846
# Episode 15, epoch [10/15], loss: 0.1293183073401451
# Episode 15, epoch [11/15], loss: 0.1296192541718483
# Episode 15, epoch [12/15], loss: 0.12925852785507838
# Episode 15, epoch [13/15], loss: 0.1292561819156011
# Episode 15, epoch [14/15], loss: 0.1291284536321958
# Episode 15, epoch [15/15], loss: 0.12912857035795847
# Episode 15 completed in 9.28 seconds
# Starting episode 16/50
# Episode 16, epoch [1/15], loss: 0.14970202644666036
# Episode 16, epoch [2/15], loss: 0.14934060573577881
# Episode 16, epoch [3/15], loss: 0.14922641813755036
# Episode 16, epoch [4/15], loss: 0.14828608185052872
# Episode 16, epoch [5/15], loss: 0.14787979423999786
# Episode 16, epoch [6/15], loss: 0.14851825137933095
# Episode 16, epoch [7/15], loss: 0.1482741336027781
# Episode 16, epoch [8/15], loss: 0.1479063520828883
# Episode 16, epoch [9/15], loss: 0.14798665444056194
# Episode 16, epoch [10/15], loss: 0.14827113449573517
# Episode 16, epoch [11/15], loss: 0.14791380862394968
# Episode 16, epoch [12/15], loss: 0.1482088714838028
# Episode 16, epoch [13/15], loss: 0.14849582811196646
# Episode 16, epoch [14/15], loss: 0.14831841886043548
# Episode 16, epoch [15/15], loss: 0.14864114224910735
# Episode 16 completed in 9.14 seconds
# Starting episode 17/50
# Episode 17, epoch [1/15], loss: 0.1141867458820343
# Episode 17, epoch [2/15], loss: 0.1134139895439148
# Episode 17, epoch [3/15], loss: 0.11323976218700409
# Episode 17, epoch [4/15], loss: 0.11345726797978083
# Episode 17, epoch [5/15], loss: 0.11251278867324194
# Episode 17, epoch [6/15], loss: 0.11239370107650756
# Episode 17, epoch [7/15], loss: 0.11229367107152939
# Episode 17, epoch [8/15], loss: 0.11253567039966583
# Episode 17, epoch [9/15], loss: 0.11232466300328572
# Episode 17, epoch [10/15], loss: 0.11205574969450632
# Episode 17, epoch [11/15], loss: 0.11190426101287206
# Episode 17, epoch [12/15], loss: 0.1118158832192421
# Episode 17, epoch [13/15], loss: 0.11172719200452169
# Episode 17, epoch [14/15], loss: 0.1118210514386495
# Episode 17, epoch [15/15], loss: 0.11203103015820186
# Episode 17 completed in 9.25 seconds
# Starting episode 18/50
# Episode 18, epoch [1/15], loss: 0.11842502256234487
# Episode 18, epoch [2/15], loss: 0.11776859660943349
# Episode 18, epoch [3/15], loss: 0.11705588152011236
# Episode 18, epoch [4/15], loss: 0.11686183164517085
# Episode 18, epoch [5/15], loss: 0.1165930151939392
# Episode 18, epoch [6/15], loss: 0.11653969784577688
# Episode 18, epoch [7/15], loss: 0.11650701065858206
# Episode 18, epoch [8/15], loss: 0.11620483895142873
# Episode 18, epoch [9/15], loss: 0.11631535937388739
# Episode 18, epoch [10/15], loss: 0.1160487433274587
# Episode 18, epoch [11/15], loss: 0.11654360890388489
# Episode 18, epoch [12/15], loss: 0.1164882481098175
# Episode 18, epoch [13/15], loss: 0.11645993888378144
# Episode 18, epoch [14/15], loss: 0.11615582555532455
# Episode 18, epoch [15/15], loss: 0.11592601736386617
# Episode 18 completed in 9.11 seconds
# Starting episode 19/50
# Episode 19, epoch [1/15], loss: 0.13186773012081782
# Episode 19, epoch [2/15], loss: 0.13055389026800793
# Episode 19, epoch [3/15], loss: 0.12948723087708155
# Episode 19, epoch [4/15], loss: 0.12956375380357107
# Episode 19, epoch [5/15], loss: 0.12973546236753464
# Episode 19, epoch [6/15], loss: 0.12923551350831985
# Episode 19, epoch [7/15], loss: 0.12885193328062694
# Episode 19, epoch [8/15], loss: 0.12856787989536922
# Episode 19, epoch [9/15], loss: 0.12826186964909236
# Episode 19, epoch [10/15], loss: 0.12800971219937007
# Episode 19, epoch [11/15], loss: 0.1276938314239184
# Episode 19, epoch [12/15], loss: 0.127708304921786
# Episode 19, epoch [13/15], loss: 0.12797052611907322
# Episode 19, epoch [14/15], loss: 0.12773106694221498
# Episode 19, epoch [15/15], loss: 0.12744891345500947
# Episode 19 completed in 9.28 seconds
# Starting episode 20/50
# Episode 20, epoch [1/15], loss: 0.10741330186525981
# Episode 20, epoch [2/15], loss: 0.10677816172440847
# Episode 20, epoch [3/15], loss: 0.10639173239469528
# Episode 20, epoch [4/15], loss: 0.1064766009648641
# Episode 20, epoch [5/15], loss: 0.10615067183971405
# Episode 20, epoch [6/15], loss: 0.10596492489178976
# Episode 20, epoch [7/15], loss: 0.10608922938505809
# Episode 20, epoch [8/15], loss: 0.10565189818541208
# Episode 20, epoch [9/15], loss: 0.10577353537082672
# Episode 20, epoch [10/15], loss: 0.10563913782437642
# Episode 20, epoch [11/15], loss: 0.1055187592903773
# Episode 20, epoch [12/15], loss: 0.10551648288965225
# Episode 20, epoch [13/15], loss: 0.10563091983397802
# Episode 20, epoch [14/15], loss: 0.10557237813870111
# Episode 20, epoch [15/15], loss: 0.1056262195110321
# Episode 20 completed in 9.28 seconds
# Saved hidden representations for episode 20
# Starting episode 21/50
# Episode 21, epoch [1/15], loss: 0.12525477806727092
# Episode 21, epoch [2/15], loss: 0.12518974393606186
# Episode 21, epoch [3/15], loss: 0.12529862225055693
# Episode 21, epoch [4/15], loss: 0.12500319133202234
# Episode 21, epoch [5/15], loss: 0.1249000589052836
# Episode 21, epoch [6/15], loss: 0.12504388988018036
# Episode 21, epoch [7/15], loss: 0.12519724319378536
# Episode 21, epoch [8/15], loss: 0.12542378256718317
# Episode 21, epoch [9/15], loss: 0.12494420955578486
# Episode 21, epoch [10/15], loss: 0.12484425952037176
# Episode 21, epoch [11/15], loss: 0.12470953911542892
# Episode 21, epoch [12/15], loss: 0.1243722046415011
# Episode 21, epoch [13/15], loss: 0.12437820186217625
# Episode 21, epoch [14/15], loss: 0.12468105604251226
# Episode 21, epoch [15/15], loss: 0.12468721071879069
# Episode 21 completed in 9.45 seconds
# Starting episode 22/50
# Episode 22, epoch [1/15], loss: 0.12869125207265217
# Episode 22, epoch [2/15], loss: 0.12791309903065365
# Episode 22, epoch [3/15], loss: 0.1280031755566597
# Episode 22, epoch [4/15], loss: 0.1276746690273285
# Episode 22, epoch [5/15], loss: 0.1271139293909073
# Episode 22, epoch [6/15], loss: 0.1271353637178739
# Episode 22, epoch [7/15], loss: 0.12684949735800424
# Episode 22, epoch [8/15], loss: 0.1268643374244372
# Episode 22, epoch [9/15], loss: 0.12696154018243153
# Episode 22, epoch [10/15], loss: 0.12662977675596873
# Episode 22, epoch [11/15], loss: 0.12662043819824856
# Episode 22, epoch [12/15], loss: 0.12651367634534835
# Episode 22, epoch [13/15], loss: 0.12663795699675878
# Episode 22, epoch [14/15], loss: 0.1264431009689967
# Episode 22, epoch [15/15], loss: 0.126692533493042
# Episode 22 completed in 9.08 seconds
# Starting episode 23/50
# Episode 23, epoch [1/15], loss: 0.10371852119763693
# Episode 23, epoch [2/15], loss: 0.10296394228935242
# Episode 23, epoch [3/15], loss: 0.10251987129449844
# Episode 23, epoch [4/15], loss: 0.10238662213087082
# Episode 23, epoch [5/15], loss: 0.10232980499664943
# Episode 23, epoch [6/15], loss: 0.1020409752925237
# Episode 23, epoch [7/15], loss: 0.10196922570466996
# Episode 23, epoch [8/15], loss: 0.10186101148525874
# Episode 23, epoch [9/15], loss: 0.10167925357818604
# Episode 23, epoch [10/15], loss: 0.10185804118712743
# Episode 23, epoch [11/15], loss: 0.1017060860991478
# Episode 23, epoch [12/15], loss: 0.10160784174998601
# Episode 23, epoch [13/15], loss: 0.10154827535152436
# Episode 23, epoch [14/15], loss: 0.10153164714574814
# Episode 23, epoch [15/15], loss: 0.10131227473417918
# Episode 23 completed in 9.10 seconds
# Starting episode 24/50
# Episode 24, epoch [1/15], loss: 0.12862641662359237
# Episode 24, epoch [2/15], loss: 0.12826055735349656
# Episode 24, epoch [3/15], loss: 0.12846229920784633
# Episode 24, epoch [4/15], loss: 0.128425865372022
# Episode 24, epoch [5/15], loss: 0.12951636264721553
# Episode 24, epoch [6/15], loss: 0.12848190019528072
# Episode 24, epoch [7/15], loss: 0.12763779858748117
# Episode 24, epoch [8/15], loss: 0.12743027557929357
# Episode 24, epoch [9/15], loss: 0.12732784946759543
# Episode 24, epoch [10/15], loss: 0.12721461455027264
# Episode 24, epoch [11/15], loss: 0.1281185542543729
# Episode 24, epoch [12/15], loss: 0.12785725345214208
# Episode 24, epoch [13/15], loss: 0.12751722385485967
# Episode 24, epoch [14/15], loss: 0.12753179371356965
# Episode 24, epoch [15/15], loss: 0.12703871577978135
# Episode 24 completed in 9.80 seconds
# Starting episode 25/50
# Episode 25, epoch [1/15], loss: 0.15284901161988576
# Episode 25, epoch [2/15], loss: 0.15342870553334553
# Episode 25, epoch [3/15], loss: 0.15356168448925017
# Episode 25, epoch [4/15], loss: 0.15318778057893118
# Episode 25, epoch [5/15], loss: 0.15332755347092947
# Episode 25, epoch [6/15], loss: 0.15286314288775127
# Episode 25, epoch [7/15], loss: 0.15205760101477306
# Episode 25, epoch [8/15], loss: 0.1522682636976242
# Episode 25, epoch [9/15], loss: 0.15266588528951008
# Episode 25, epoch [10/15], loss: 0.15263331532478333
# Episode 25, epoch [11/15], loss: 0.15305834412574768
# Episode 25, epoch [12/15], loss: 0.15242850581804912
# Episode 25, epoch [13/15], loss: 0.15168022314707438
# Episode 25, epoch [14/15], loss: 0.15205698211987814
# Episode 25, epoch [15/15], loss: 0.15177693863709768
# Episode 25 completed in 9.15 seconds
# Starting episode 26/50
# Episode 26, epoch [1/15], loss: 0.10072301576534907
# Episode 26, epoch [2/15], loss: 0.10029069036245346
# Episode 26, epoch [3/15], loss: 0.100129700700442
# Episode 26, epoch [4/15], loss: 0.09996399283409119
# Episode 26, epoch [5/15], loss: 0.09974977225065232
# Episode 26, epoch [6/15], loss: 0.09960853407780329
# Episode 26, epoch [7/15], loss: 0.09991049120823542
# Episode 26, epoch [8/15], loss: 0.09968533863623937
# Episode 26, epoch [9/15], loss: 0.09936650147040685
# Episode 26, epoch [10/15], loss: 0.09935881992181142
# Episode 26, epoch [11/15], loss: 0.09936011830965678
# Episode 26, epoch [12/15], loss: 0.09941645463307698
# Episode 26, epoch [13/15], loss: 0.09931603322426479
# Episode 26, epoch [14/15], loss: 0.09926432569821676
# Episode 26, epoch [15/15], loss: 0.09923140406608581
# Episode 26 completed in 9.32 seconds
# Starting episode 27/50
# Episode 27, epoch [1/15], loss: 0.1684203545252482
# Episode 27, epoch [2/15], loss: 0.1688961774110794
# Episode 27, epoch [3/15], loss: 0.16800572077433268
# Episode 27, epoch [4/15], loss: 0.1678319106499354
# Episode 27, epoch [5/15], loss: 0.16726486484209696
# Episode 27, epoch [6/15], loss: 0.16746146182219188
# Episode 27, epoch [7/15], loss: 0.1672026813030243
# Episode 27, epoch [8/15], loss: 0.16714069743951163
# Episode 27, epoch [9/15], loss: 0.1661017765601476
# Episode 27, epoch [10/15], loss: 0.1666454573472341
# Episode 27, epoch [11/15], loss: 0.16666341225306194
# Episode 27, epoch [12/15], loss: 0.16595734457174938
# Episode 27, epoch [13/15], loss: 0.16606313288211821
# Episode 27, epoch [14/15], loss: 0.16604652106761933
# Episode 27, epoch [15/15], loss: 0.1655967394510905
# Episode 27 completed in 9.13 seconds
# Starting episode 28/50
# Episode 28, epoch [1/15], loss: 0.12228292177120845
# Episode 28, epoch [2/15], loss: 0.12178911765416463
# Episode 28, epoch [3/15], loss: 0.12148973147074381
# Episode 28, epoch [4/15], loss: 0.12117938647667567
# Episode 28, epoch [5/15], loss: 0.12102994173765183
# Episode 28, epoch [6/15], loss: 0.12054545134305954
# Episode 28, epoch [7/15], loss: 0.12055212855339051
# Episode 28, epoch [8/15], loss: 0.1204756423830986
# Episode 28, epoch [9/15], loss: 0.12038764158884684
# Episode 28, epoch [10/15], loss: 0.12057077685991922
# Episode 28, epoch [11/15], loss: 0.12057157903909684
# Episode 28, epoch [12/15], loss: 0.12026745577653249
# Episode 28, epoch [13/15], loss: 0.1196881428360939
# Episode 28, epoch [14/15], loss: 0.11990639666716257
# Episode 28, epoch [15/15], loss: 0.11974144925673803
# Episode 28 completed in 9.28 seconds
# Starting episode 29/50
# Episode 29, epoch [1/15], loss: 0.1253032887975375
# Episode 29, epoch [2/15], loss: 0.12544697175423306
# Episode 29, epoch [3/15], loss: 0.125141608218352
# Episode 29, epoch [4/15], loss: 0.1246216336886088
# Episode 29, epoch [5/15], loss: 0.12435335566600164
# Episode 29, epoch [6/15], loss: 0.12430016249418259
# Episode 29, epoch [7/15], loss: 0.12478437721729278
# Episode 29, epoch [8/15], loss: 0.12515599528948465
# Episode 29, epoch [9/15], loss: 0.12573780218760172
# Episode 29, epoch [10/15], loss: 0.12460513313611349
# Episode 29, epoch [11/15], loss: 0.12431030919154486
# Episode 29, epoch [12/15], loss: 0.12414816667636236
# Episode 29, epoch [13/15], loss: 0.12380076845486959
# Episode 29, epoch [14/15], loss: 0.12400486419598261
# Episode 29, epoch [15/15], loss: 0.1240433027346929
# Episode 29 completed in 9.19 seconds
# Starting episode 30/50
# Episode 30, epoch [1/15], loss: 0.15405710339546203
# Episode 30, epoch [2/15], loss: 0.15377669632434846
# Episode 30, epoch [3/15], loss: 0.1539724479118983
# Episode 30, epoch [4/15], loss: 0.15442370474338532
# Episode 30, epoch [5/15], loss: 0.1542214532693227
# Episode 30, epoch [6/15], loss: 0.1546559711297353
# Episode 30, epoch [7/15], loss: 0.15367936491966247
# Episode 30, epoch [8/15], loss: 0.15334865152835847
# Episode 30, epoch [9/15], loss: 0.1532757103443146
# Episode 30, epoch [10/15], loss: 0.15253214438756307
# Episode 30, epoch [11/15], loss: 0.15220352311929067
# Episode 30, epoch [12/15], loss: 0.152128928899765
# Episode 30, epoch [13/15], loss: 0.1519217242797216
# Episode 30, epoch [14/15], loss: 0.15261517961819968
# Episode 30, epoch [15/15], loss: 0.1529150664806366
# Episode 30 completed in 9.03 seconds
# Saved hidden representations for episode 30
# Starting episode 31/50
# Episode 31, epoch [1/15], loss: 0.13486144344011944
# Episode 31, epoch [2/15], loss: 0.13450973530610402
# Episode 31, epoch [3/15], loss: 0.13386458059151968
# Episode 31, epoch [4/15], loss: 0.1340256080031395
# Episode 31, epoch [5/15], loss: 0.13385625382264454
# Episode 31, epoch [6/15], loss: 0.1339254707098007
# Episode 31, epoch [7/15], loss: 0.13380277703205745
# Episode 31, epoch [8/15], loss: 0.13376078655322393
# Episode 31, epoch [9/15], loss: 0.13378584583600361
# Episode 31, epoch [10/15], loss: 0.13364210824171702
# Episode 31, epoch [11/15], loss: 0.13372040688991546
# Episode 31, epoch [12/15], loss: 0.13379047960042953
# Episode 31, epoch [13/15], loss: 0.13379258712132772
# Episode 31, epoch [14/15], loss: 0.13343461652596791
# Episode 31, epoch [15/15], loss: 0.13368413696686426
# Episode 31 completed in 9.09 seconds
# Starting episode 32/50
# Episode 32, epoch [1/15], loss: 0.11846366773049037
# Episode 32, epoch [2/15], loss: 0.11784739245971045
# Episode 32, epoch [3/15], loss: 0.11767740348974863
# Episode 32, epoch [4/15], loss: 0.11758923977613449
# Episode 32, epoch [5/15], loss: 0.11754022687673568
# Episode 32, epoch [6/15], loss: 0.1172393500804901
# Episode 32, epoch [7/15], loss: 0.11725043853123983
# Episode 32, epoch [8/15], loss: 0.11721181372801463
# Episode 32, epoch [9/15], loss: 0.11714816341797511
# Episode 32, epoch [10/15], loss: 0.1171442911028862
# Episode 32, epoch [11/15], loss: 0.11708871275186539
# Episode 32, epoch [12/15], loss: 0.1171035572886467
# Episode 32, epoch [13/15], loss: 0.11714449425538381
# Episode 32, epoch [14/15], loss: 0.11723535309235254
# Episode 32, epoch [15/15], loss: 0.11711832632621129
# Episode 32 completed in 9.32 seconds
# Starting episode 33/50
# Episode 33, epoch [1/15], loss: 0.14929964492718378
# Episode 33, epoch [2/15], loss: 0.14912909666697186
# Episode 33, epoch [3/15], loss: 0.14941034118334454
# Episode 33, epoch [4/15], loss: 0.14935935537020364
# Episode 33, epoch [5/15], loss: 0.1490717073281606
# Episode 33, epoch [6/15], loss: 0.14866670668125154
# Episode 33, epoch [7/15], loss: 0.14853270252545675
# Episode 33, epoch [8/15], loss: 0.14853550692399342
# Episode 33, epoch [9/15], loss: 0.14864264627297719
# Episode 33, epoch [10/15], loss: 0.14867703119913736
# Episode 33, epoch [11/15], loss: 0.14806366761525472
# Episode 33, epoch [12/15], loss: 0.14797799686590832
# Episode 33, epoch [13/15], loss: 0.1484495202700297
# Episode 33, epoch [14/15], loss: 0.14862380524476368
# Episode 33, epoch [15/15], loss: 0.1486103951931
# Episode 33 completed in 9.40 seconds
# Starting episode 34/50
# Episode 34, epoch [1/15], loss: 0.1501842399438222
# Episode 34, epoch [2/15], loss: 0.14909558494885763
# Episode 34, epoch [3/15], loss: 0.1487277070681254
# Episode 34, epoch [4/15], loss: 0.14849586188793182
# Episode 34, epoch [5/15], loss: 0.1481802781422933
# Episode 34, epoch [6/15], loss: 0.1478745977083842
# Episode 34, epoch [7/15], loss: 0.14771774411201477
# Episode 34, epoch [8/15], loss: 0.14787919620672862
# Episode 34, epoch [9/15], loss: 0.14771276315053303
# Episode 34, epoch [10/15], loss: 0.14737622638543446
# Episode 34, epoch [11/15], loss: 0.14719667236010234
# Episode 34, epoch [12/15], loss: 0.14717244803905488
# Episode 34, epoch [13/15], loss: 0.1470463792483012
# Episode 34, epoch [14/15], loss: 0.1471793363491694
# Episode 34, epoch [15/15], loss: 0.14717298448085786
# Episode 34 completed in 9.40 seconds
# Starting episode 35/50
# Episode 35, epoch [1/15], loss: 0.09839369455973307
# Episode 35, epoch [2/15], loss: 0.09773465842008591
# Episode 35, epoch [3/15], loss: 0.09730748583873113
# Episode 35, epoch [4/15], loss: 0.09700738141934077
# Episode 35, epoch [5/15], loss: 0.09686947017908096
# Episode 35, epoch [6/15], loss: 0.09683664788802465
# Episode 35, epoch [7/15], loss: 0.09678113361199697
# Episode 35, epoch [8/15], loss: 0.09662838280200958
# Episode 35, epoch [9/15], loss: 0.09652426540851593
# Episode 35, epoch [10/15], loss: 0.09641215950250626
# Episode 35, epoch [11/15], loss: 0.09644087503353754
# Episode 35, epoch [12/15], loss: 0.09623280068238577
# Episode 35, epoch [13/15], loss: 0.09609509458144506
# Episode 35, epoch [14/15], loss: 0.09615243673324585
# Episode 35, epoch [15/15], loss: 0.0963571086525917
# Episode 35 completed in 9.20 seconds
# Starting episode 36/50
# Episode 36, epoch [1/15], loss: 0.13934310128291447
# Episode 36, epoch [2/15], loss: 0.1392810583114624
# Episode 36, epoch [3/15], loss: 0.13958127647638321
# Episode 36, epoch [4/15], loss: 0.13952225943406424
# Episode 36, epoch [5/15], loss: 0.13886679609616598
# Episode 36, epoch [6/15], loss: 0.13712384849786757
# Episode 36, epoch [7/15], loss: 0.13718684961398442
# Episode 36, epoch [8/15], loss: 0.13786490708589555
# Episode 36, epoch [9/15], loss: 0.1368443523844083
# Episode 36, epoch [10/15], loss: 0.13607933123906454
# Episode 36, epoch [11/15], loss: 0.13682601153850554
# Episode 36, epoch [12/15], loss: 0.13690758099158604
# Episode 36, epoch [13/15], loss: 0.13673135936260222
# Episode 36, epoch [14/15], loss: 0.13727926462888718
# Episode 36, epoch [15/15], loss: 0.13759851257006328
# Episode 36 completed in 9.12 seconds
# Starting episode 37/50
# Episode 37, epoch [1/15], loss: 0.09164018879334132
# Episode 37, epoch [2/15], loss: 0.0908040036757787
# Episode 37, epoch [3/15], loss: 0.09028501510620117
# Episode 37, epoch [4/15], loss: 0.09007129222154617
# Episode 37, epoch [5/15], loss: 0.08976307660341262
# Episode 37, epoch [6/15], loss: 0.08982512156168619
# Episode 37, epoch [7/15], loss: 0.08976478228966395
# Episode 37, epoch [8/15], loss: 0.08972571889559428
# Episode 37, epoch [9/15], loss: 0.08970546225706737
# Episode 37, epoch [10/15], loss: 0.0894700437784195
# Episode 37, epoch [11/15], loss: 0.08928841203451157
# Episode 37, epoch [12/15], loss: 0.08920108526945114
# Episode 37, epoch [13/15], loss: 0.08917776842912038
# Episode 37, epoch [14/15], loss: 0.08917356133460999
# Episode 37, epoch [15/15], loss: 0.0891987845301628
# Episode 37 completed in 9.28 seconds
# Starting episode 38/50
# Episode 38, epoch [1/15], loss: 0.12834414690732956
# Episode 38, epoch [2/15], loss: 0.12802927941083908
# Episode 38, epoch [3/15], loss: 0.12785732199748356
# Episode 38, epoch [4/15], loss: 0.12784306158622105
# Episode 38, epoch [5/15], loss: 0.12773168881734212
# Episode 38, epoch [6/15], loss: 0.12778091977039974
# Episode 38, epoch [7/15], loss: 0.12762484749158223
# Episode 38, epoch [8/15], loss: 0.1275153438250224
# Episode 38, epoch [9/15], loss: 0.12751556783914567
# Episode 38, epoch [10/15], loss: 0.12759698033332825
# Episode 38, epoch [11/15], loss: 0.12748102595408758
# Episode 38, epoch [12/15], loss: 0.12734267562627793
# Episode 38, epoch [13/15], loss: 0.12744521697362263
# Episode 38, epoch [14/15], loss: 0.12722092618544897
# Episode 38, epoch [15/15], loss: 0.12708551287651063
# Episode 38 completed in 9.26 seconds
# Starting episode 39/50
# Episode 39, epoch [1/15], loss: 0.12140268385410309
# Episode 39, epoch [2/15], loss: 0.12130623608827591
# Episode 39, epoch [3/15], loss: 0.12133896897236505
# Episode 39, epoch [4/15], loss: 0.120859394967556
# Episode 39, epoch [5/15], loss: 0.12077421347300211
# Episode 39, epoch [6/15], loss: 0.12077740728855133
# Episode 39, epoch [7/15], loss: 0.12080532213052114
# Episode 39, epoch [8/15], loss: 0.12050003508726756
# Episode 39, epoch [9/15], loss: 0.12044091025988261
# Episode 39, epoch [10/15], loss: 0.12041090230147043
# Episode 39, epoch [11/15], loss: 0.1207238217194875
# Episode 39, epoch [12/15], loss: 0.12094179292519887
# Episode 39, epoch [13/15], loss: 0.12036528786023458
# Episode 39, epoch [14/15], loss: 0.12044874578714371
# Episode 39, epoch [15/15], loss: 0.12041846066713333
# Episode 39 completed in 9.28 seconds
# Starting episode 40/50
# Episode 40, epoch [1/15], loss: 0.16381976505120596
# Episode 40, epoch [2/15], loss: 0.16379212041695912
# Episode 40, epoch [3/15], loss: 0.16385325094064077
# Episode 40, epoch [4/15], loss: 0.1630498598019282
# Episode 40, epoch [5/15], loss: 0.1633287082115809
# Episode 40, epoch [6/15], loss: 0.16306090354919434
# Episode 40, epoch [7/15], loss: 0.16286027431488037
# Episode 40, epoch [8/15], loss: 0.1640302876631419
# Episode 40, epoch [9/15], loss: 0.16355677843093872
# Episode 40, epoch [10/15], loss: 0.16249206960201262
# Episode 40, epoch [11/15], loss: 0.1631884068250656
# Episode 40, epoch [12/15], loss: 0.16381772657235463
# Episode 40, epoch [13/15], loss: 0.1637778699398041
# Episode 40, epoch [14/15], loss: 0.1628925492366155
# Episode 40, epoch [15/15], loss: 0.16259643236796062
# Episode 40 completed in 9.33 seconds
# Saved hidden representations for episode 40
# Starting episode 41/50
# Episode 41, epoch [1/15], loss: 0.13954806427160898
# Episode 41, epoch [2/15], loss: 0.13970738252003986
# Episode 41, epoch [3/15], loss: 0.13930714080731074
# Episode 41, epoch [4/15], loss: 0.1389202465613683
# Episode 41, epoch [5/15], loss: 0.1381290887792905
# Episode 41, epoch [6/15], loss: 0.1377598946293195
# Episode 41, epoch [7/15], loss: 0.13816418101390202
# Episode 41, epoch [8/15], loss: 0.13830282241106034
# Episode 41, epoch [9/15], loss: 0.13796108216047287
# Episode 41, epoch [10/15], loss: 0.138303679227829
# Episode 41, epoch [11/15], loss: 0.13867766857147218
# Episode 41, epoch [12/15], loss: 0.1388735681772232
# Episode 41, epoch [13/15], loss: 0.13786282340685527
# Episode 41, epoch [14/15], loss: 0.13788479169209797
# Episode 41, epoch [15/15], loss: 0.13788414845863978
# Episode 41 completed in 9.04 seconds
# Starting episode 42/50
# Episode 42, epoch [1/15], loss: 0.12805374811093012
# Episode 42, epoch [2/15], loss: 0.127808811267217
# Episode 42, epoch [3/15], loss: 0.12764169722795488
# Episode 42, epoch [4/15], loss: 0.12749927043914794
# Episode 42, epoch [5/15], loss: 0.12710294127464294
# Episode 42, epoch [6/15], loss: 0.12659535706043243
# Episode 42, epoch [7/15], loss: 0.12669830868641535
# Episode 42, epoch [8/15], loss: 0.12739909291267396
# Episode 42, epoch [9/15], loss: 0.1269286498427391
# Episode 42, epoch [10/15], loss: 0.12694096167882282
# Episode 42, epoch [11/15], loss: 0.12696466793616612
# Episode 42, epoch [12/15], loss: 0.12644103020429612
# Episode 42, epoch [13/15], loss: 0.12599786072969438
# Episode 42, epoch [14/15], loss: 0.1260162020723025
# Episode 42, epoch [15/15], loss: 0.1259010801712672
# Episode 42 completed in 9.19 seconds
# Starting episode 43/50
# Episode 43, epoch [1/15], loss: 0.12570491731166838
# Episode 43, epoch [2/15], loss: 0.12510184894005458
# Episode 43, epoch [3/15], loss: 0.12466950168212255
# Episode 43, epoch [4/15], loss: 0.12437514215707779
# Episode 43, epoch [5/15], loss: 0.1248101164897283
# Episode 43, epoch [6/15], loss: 0.12472694466511408
# Episode 43, epoch [7/15], loss: 0.12447747786839804
# Episode 43, epoch [8/15], loss: 0.12421547671159108
# Episode 43, epoch [9/15], loss: 0.12442953238884608
# Episode 43, epoch [10/15], loss: 0.12434351841608683
# Episode 43, epoch [11/15], loss: 0.12411166628201803
# Episode 43, epoch [12/15], loss: 0.12402108212312063
# Episode 43, epoch [13/15], loss: 0.12403663744529088
# Episode 43, epoch [14/15], loss: 0.12393735349178314
# Episode 43, epoch [15/15], loss: 0.12381228158871332
# Episode 43 completed in 9.14 seconds
# Starting episode 44/50
# Episode 44, epoch [1/15], loss: 0.14777332941691082
# Episode 44, epoch [2/15], loss: 0.1472686509291331
# Episode 44, epoch [3/15], loss: 0.14685348371664683
# Episode 44, epoch [4/15], loss: 0.14658950567245482
# Episode 44, epoch [5/15], loss: 0.14663242201010387
# Episode 44, epoch [6/15], loss: 0.14647227029005686
# Episode 44, epoch [7/15], loss: 0.14629120727380115
# Episode 44, epoch [8/15], loss: 0.14600472748279572
# Episode 44, epoch [9/15], loss: 0.1459648311138153
# Episode 44, epoch [10/15], loss: 0.14594658414522807
# Episode 44, epoch [11/15], loss: 0.14595139225323994
# Episode 44, epoch [12/15], loss: 0.14586173593997956
# Episode 44, epoch [13/15], loss: 0.14558741748332976
# Episode 44, epoch [14/15], loss: 0.14544585744539898
# Episode 44, epoch [15/15], loss: 0.14556267658869426
# Episode 44 completed in 9.27 seconds
# Starting episode 45/50
# Episode 45, epoch [1/15], loss: 0.12831428945064544
# Episode 45, epoch [2/15], loss: 0.12791904558738074
# Episode 45, epoch [3/15], loss: 0.12768467019001642
# Episode 45, epoch [4/15], loss: 0.12708474000295003
# Episode 45, epoch [5/15], loss: 0.1264894609649976
# Episode 45, epoch [6/15], loss: 0.12649677594502767
# Episode 45, epoch [7/15], loss: 0.12639466325441998
# Episode 45, epoch [8/15], loss: 0.12601020236810048
# Episode 45, epoch [9/15], loss: 0.12645793308814365
# Episode 45, epoch [10/15], loss: 0.12681206315755844
# Episode 45, epoch [11/15], loss: 0.1263805389404297
# Episode 45, epoch [12/15], loss: 0.12587459832429887
# Episode 45, epoch [13/15], loss: 0.12624033490816752
# Episode 45, epoch [14/15], loss: 0.1268197387456894
# Episode 45, epoch [15/15], loss: 0.12643007238705953
# Episode 45 completed in 9.17 seconds
# Starting episode 46/50
# Episode 46, epoch [1/15], loss: 0.11865154008070627
# Episode 46, epoch [2/15], loss: 0.11827391336361567
# Episode 46, epoch [3/15], loss: 0.11770288050174713
# Episode 46, epoch [4/15], loss: 0.11730056305726369
# Episode 46, epoch [5/15], loss: 0.11756998101870218
# Episode 46, epoch [6/15], loss: 0.11772991220156352
# Episode 46, epoch [7/15], loss: 0.11773722072442373
# Episode 46, epoch [8/15], loss: 0.1169283206264178
# Episode 46, epoch [9/15], loss: 0.11681183675924937
# Episode 46, epoch [10/15], loss: 0.11736446817715963
# Episode 46, epoch [11/15], loss: 0.11682617564996084
# Episode 46, epoch [12/15], loss: 0.11658037304878235
# Episode 46, epoch [13/15], loss: 0.1162366067369779
# Episode 46, epoch [14/15], loss: 0.11623819321393966
# Episode 46, epoch [15/15], loss: 0.11665604064861933
# Episode 46 completed in 9.23 seconds
# Starting episode 47/50
# Episode 47, epoch [1/15], loss: 0.08851741353670756
# Episode 47, epoch [2/15], loss: 0.08788906633853913
# Episode 47, epoch [3/15], loss: 0.08757227162520091
# Episode 47, epoch [4/15], loss: 0.0873938779036204
# Episode 47, epoch [5/15], loss: 0.08717407484849295
# Episode 47, epoch [6/15], loss: 0.08735308001438777
# Episode 47, epoch [7/15], loss: 0.08734801113605499
# Episode 47, epoch [8/15], loss: 0.08732814242442449
# Episode 47, epoch [9/15], loss: 0.08721756935119629
# Episode 47, epoch [10/15], loss: 0.08715949306885401
# Episode 47, epoch [11/15], loss: 0.0869606946905454
# Episode 47, epoch [12/15], loss: 0.08693584899107615
# Episode 47, epoch [13/15], loss: 0.08687960157791773
# Episode 47, epoch [14/15], loss: 0.08676471710205078
# Episode 47, epoch [15/15], loss: 0.08671802431344985
# Episode 47 completed in 9.25 seconds
# Starting episode 48/50
# Episode 48, epoch [1/15], loss: 0.12127283463875453
# Episode 48, epoch [2/15], loss: 0.12105114310979843
# Episode 48, epoch [3/15], loss: 0.12099454402923585
# Episode 48, epoch [4/15], loss: 0.12120771656433742
# Episode 48, epoch [5/15], loss: 0.12042563756306966
# Episode 48, epoch [6/15], loss: 0.1200446014602979
# Episode 48, epoch [7/15], loss: 0.11971586098273596
# Episode 48, epoch [8/15], loss: 0.11987246721982955
# Episode 48, epoch [9/15], loss: 0.11955083062251409
# Episode 48, epoch [10/15], loss: 0.11970878690481186
# Episode 48, epoch [11/15], loss: 0.11930635074774425
# Episode 48, epoch [12/15], loss: 0.11930199066797892
# Episode 48, epoch [13/15], loss: 0.11943542013565699
# Episode 48, epoch [14/15], loss: 0.11933625390132269
# Episode 48, epoch [15/15], loss: 0.11866039484739303
# Episode 48 completed in 9.40 seconds
# Starting episode 49/50
# Episode 49, epoch [1/15], loss: 0.1395008017619451
# Episode 49, epoch [2/15], loss: 0.13940758059422176
# Episode 49, epoch [3/15], loss: 0.13955225149790446
# Episode 49, epoch [4/15], loss: 0.13896376192569732
# Episode 49, epoch [5/15], loss: 0.13941012223561605
# Episode 49, epoch [6/15], loss: 0.1393948644399643
# Episode 49, epoch [7/15], loss: 0.13906322022279102
# Episode 49, epoch [8/15], loss: 0.13946672429641088
# Episode 49, epoch [9/15], loss: 0.1399567812681198
# Episode 49, epoch [10/15], loss: 0.1397254337867101
# Episode 49, epoch [11/15], loss: 0.13950158854325612
# Episode 49, epoch [12/15], loss: 0.13849996427694958
# Episode 49, epoch [13/15], loss: 0.1384599030017853
# Episode 49, epoch [14/15], loss: 0.13836951653162638
# Episode 49, epoch [15/15], loss: 0.13818608770767848
# Episode 49 completed in 9.28 seconds
# Starting episode 50/50
# Episode 50, epoch [1/15], loss: 0.10395819048086802
# Episode 50, epoch [2/15], loss: 0.10321396191914876
# Episode 50, epoch [3/15], loss: 0.10263774991035461
# Episode 50, epoch [4/15], loss: 0.10236654033263524
# Episode 50, epoch [5/15], loss: 0.10225463410218556
# Episode 50, epoch [6/15], loss: 0.10208204487959543
# Episode 50, epoch [7/15], loss: 0.10192173024018605
# Episode 50, epoch [8/15], loss: 0.10187809964021047
# Episode 50, epoch [9/15], loss: 0.1017688607176145
# Episode 50, epoch [10/15], loss: 0.1016153926650683
# Episode 50, epoch [11/15], loss: 0.10145681152741114
# Episode 50, epoch [12/15], loss: 0.10138127406438192
# Episode 50, epoch [13/15], loss: 0.101515394449234
# Episode 50, epoch [14/15], loss: 0.10148554841677347
# Episode 50, epoch [15/15], loss: 0.1014378011226654
# Episode 50 completed in 9.18 seconds
# Saved hidden representations for episode 50
# Training finished!

# %%
#Visualising reconstructed data
def plot_reconstruction(original, reconstructed, n = 5):
    
    plt.figure(figsize = (15, 10))

    for i in range(n):
        for j in range(7):
            ax = plt.subplot(n, 7, i * 7 + j + 1)
            plt.plot(original[i][:, j].numpy(), label = "Original")
            plt.plot(reconstructed[i][:, j].detach().numpy(), label = "Reconstructed")
            
            if j == 0:
                ax.set_ylabel(f"Sample {i + 1}")
            if i == 0:
                ax.set_title(f"Variable {j + 1}")
            if i == n - 1 and j == 2:
                ax.legend()

    plt.show()

# %%
test_data = next(iter(dataloader))
reconstructed_data = model(test_data)

plot_reconstruction(test_data, reconstructed_data)
