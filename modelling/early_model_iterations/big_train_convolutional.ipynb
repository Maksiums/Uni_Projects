# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import time
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset

# %%
def generate_random_samples(batch, read = "/Users/maks/Documents/MSc_project/data/features", sequence_length = 60):
    """
    A function that creates a list of independent arrays that are to serve as samples for processing later.
    read is the directory where Excel files containing variables are stored;
    batch is the number of samples that will be generated;
    sequence length is the length of each sample.
    Returns a list of numpy arrays.
    """

    def load_excel(file_path):
        """
        Extracts sheets from Excel files given a file directory.
        """
        excel_file = pd.ExcelFile(file_path)
        
        sheets = {sheet_name: pd.read_excel(excel_file, sheet_name = sheet_name, engine = "openpyxl") for sheet_name in excel_file.sheet_names}

        return sheets
    
    def random_file(read):
        """
        Chooses a random file from a provided directory.
        """
        files = [f for f in os.listdir(read) if f.endswith(".xlsx") and not f.startswith(".")]
        
        if not files:
            raise FileNotFoundError("No Excel files found in the directory")
        
        return os.path.join(read, random.choice(files))
    
    def normalise_columns(df, columns):
        """
        Normalises specified columns between -1 and 1.
        """
        df = df.copy()  # Make a copy to avoid modifying the original DataFrame
    
        for column in columns:
            max_val = df[column].max()
            min_val = df[column].min()
            
            df.loc[:, column] = 2 * (df[column] - min_val) / (max_val - min_val) - 1

        return df

    def sampler(sheet_data, sequence_length):
        """
        Randomly creates a sample from an Excel sheet.
        sheet_data are sheets representing time series segments from where data is going to be sampled
        sequence_length is the number of points each sample will contain.
        """

        #Normalises velocities and angular velocities using normalise_columns
        columns = ["velocity_x", "velocity_y", "velocity_z", "angular_velocity_yz", "angular_velocity_xz", "angular_velocity_xy"]
        sheet_data = normalise_columns(sheet_data, columns)

        num_points = len(sheet_data)

        if num_points < sequence_length + 2:
            return None
        
        start_index = random.randint(2, num_points - sequence_length)
        end_index = start_index + sequence_length
        sample = sheet_data.iloc[start_index : end_index].to_numpy()

        return sample #Transposes the samle to switch rows and columns
    
    def weighted_random_choice(sheets):
        """
        Assigns weights to sheets based on the length of each sheet.
        """
        total_points = sum(len(data) for data in sheets.values())
        weights = [len(data) / total_points for data in sheets.values()]

        return random.choices(list(sheets.keys()), weights = weights, k = 1)[0]
    
    #Initializes list to strore sample arrays
    samples = []

    while len(samples) < batch:
        file_path = random_file(read)
        sheets = load_excel(file_path)

        while len(samples) < batch:
            sheet_name = weighted_random_choice(sheets)
            sheet_data = sheets[sheet_name][["velocity_x", "velocity_y", "velocity_z", "tortuosity3d", "angular_velocity_yz", "angular_velocity_xz", "angular_velocity_xy"]]
            sample = sampler(sheet_data, sequence_length)

            if sample is not None:
                samples.append(sample)

            #Stops once batch size is reached
            if len(samples) >= batch:
                break

    return samples

# %%
#Class to contain our sampled time series data
class TimeSeriesData(Dataset):
    def __init__(self, no_samples):
        self.data = generate_random_samples(no_samples)
        self.data = torch.tensor(self.data, dtype = torch.float32)
    
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, i):
        return self.data[i]

# %%
#Convolutional autoencoder model
class ConvAutoencoder(nn.Module):
    def __init__(self):
        super(ConvAutoencoder, self).__init__()

        #Encoder
        self.encoder = nn.Sequential(
            nn.Conv1d(in_channels = 7, out_channels = 32, kernel_size = 3, stride = 1, padding = 1), #output: (16, 60)
            #nn.BatchNorm1d(16),
            nn.ELU(),
            nn.MaxPool1d(kernel_size = 2, stride = 2), #output (16, 30)

            nn.Conv1d(in_channels = 32, out_channels = 64, kernel_size = 3, stride = 1, padding = 1), #output: (32, 30)
            #nn.BatchNorm1d(32),
            nn.ELU(),
            nn.MaxPool1d(kernel_size = 2, stride = 2), #output: (32, 15)
            nn.Dropout(0.1)
        )

        #Decoder
        self.decoder = nn.Sequential(
            nn.ConvTranspose1d(in_channels = 64, out_channels = 32, kernel_size = 2, stride = 2), #output: (16, 30)
            #nn.BatchNorm1d(16),
            nn.ELU(),

            nn.ConvTranspose1d(in_channels = 32, out_channels = 16, kernel_size = 3, stride = 2, padding = 1, output_padding = 1), #output: (8, 60)
            #nn.BatchNorm1d(8),
            nn.ELU(),
            nn.ConvTranspose1d(in_channels = 16, out_channels = 7, kernel_size = 3, stride = 1, padding = 1), #output: (7, 60)
            nn.Tanh(),
        )

    def forward(self, x):
        x = x.permute(0, 2, 1)
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        decoded = decoded.permute(0, 2, 1)
        return decoded
    
    def encode(self, x):
        x = x.permute(0, 2, 1)
        encoded = self.encoder(x)
        return encoded

# %%
#Dataset and dataloader parameters
no_samples = 480
batch_size = 32

# %%
#Model, loss function and optimiser
model = ConvAutoencoder()
criterion = nn.L1Loss()
optimiser = optim.AdamW(model.parameters(), lr = 0.001)
max_gradient_norm = 1.0

# %%
#Training loop
no_episodes = 500
epochs = 15
#os.makedirs("/Users/maks/Documents/MSc_project/data/hidden_layer_representations/day_1", exist_ok = True)

for episode in range(no_episodes):
    print(f"Starting episode {episode + 1}/{no_episodes}")

    #Generates dataset
    dataset = TimeSeriesData(no_samples)
    dataloader = DataLoader(dataset, batch_size = batch_size, shuffle = True)

    #Records start time for an episode
    start_time = time.time()

    for epoch in range(epochs):
        epoch_loss = 0.0
        for batch_data in dataloader:
            #Forward pass
            output = model(batch_data)

            #if output is None:
                #print("Model output is None.")
            #else:
                #print("Model output shape:", output.shape)
                
            loss = criterion(output, batch_data)

            #Backward pass
            optimiser.zero_grad()
            loss.backward()

            #Gradient clipping
            nn.utils.clip_grad_norm_(model.parameters(), max_gradient_norm)

            #Optimisation step
            optimiser.step()

            epoch_loss += loss.item()

        average_epoch_loss = epoch_loss / len(dataloader)
        print(f"Episode {episode + 1 }, epoch [{epoch + 1}/{epochs}], loss: {average_epoch_loss}")

    #Records end time of the episode
    end_time = time.time()

    #Prints duration of the episode
    runtime = end_time - start_time
    print(f"Episode {episode + 1} completed in {runtime:.2f} seconds")

    #Saves hidden layer representation every 10 episodes
    if (episode + 1) % 10 == 0:
        hidden_representations = []
        for batch_data in dataloader:
            with torch.no_grad():
                hidden_repr = model.encode(batch_data)
                hidden_representations.append(hidden_repr.numpy())

        hidden_representations = np.concatenate(hidden_representations, axis = 0)
        np.save(f"/Users/maks/Documents/MSc_project/data/hidden_layer_representations/day_2/_convolutional_hidden_representations_episode_{episode + 1}.npy", hidden_representations)
        print(f"Saved hidden representations for episode {episode + 1}")

print("Training finished!")
# Out:
# Starting episode 1/500
# /var/folders/fc/xb4m883n569bgzjfj4b22cgh0000gq/T/ipykernel_6415/2374304228.py:5: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:277.)
#   self.data = torch.tensor(self.data, dtype = torch.float32)
# Episode 1, epoch [1/15], loss: 3.8113596439361572
# Episode 1, epoch [2/15], loss: 3.7237767219543456
# Episode 1, epoch [3/15], loss: 3.7008673667907717
# Episode 1, epoch [4/15], loss: 3.6945284366607667
# Episode 1, epoch [5/15], loss: 3.689931344985962
# Episode 1, epoch [6/15], loss: 3.685778347651164
# Episode 1, epoch [7/15], loss: 3.6795718828837076
# Episode 1, epoch [8/15], loss: 3.669830004374186
# Episode 1, epoch [9/15], loss: 3.657211422920227
# Episode 1, epoch [10/15], loss: 3.649329694112142
# Episode 1, epoch [11/15], loss: 3.6448694864908853
# Episode 1, epoch [12/15], loss: 3.644375721613566
# Episode 1, epoch [13/15], loss: 3.641973304748535
# Episode 1, epoch [14/15], loss: 3.6384928862253827
# Episode 1, epoch [15/15], loss: 3.632451645533244
# Episode 1 completed in 7.23 seconds
# Starting episode 2/500
# Episode 2, epoch [1/15], loss: 2.196390211582184
# Episode 2, epoch [2/15], loss: 2.1906837304433187
# Episode 2, epoch [3/15], loss: 2.1876850883165995
# Episode 2, epoch [4/15], loss: 2.1863804260889688
# Episode 2, epoch [5/15], loss: 2.1866888721783955
# Episode 2, epoch [6/15], loss: 2.185880454381307
# Episode 2, epoch [7/15], loss: 2.184199603398641
# Episode 2, epoch [8/15], loss: 2.183089542388916
# Episode 2, epoch [9/15], loss: 2.1827059666315716
# Episode 2, epoch [10/15], loss: 2.1821584184964498
# Episode 2, epoch [11/15], loss: 2.181100686391195
# Episode 2, epoch [12/15], loss: 2.1803571422894796
# Episode 2, epoch [13/15], loss: 2.1799666126569113
# Episode 2, epoch [14/15], loss: 2.1793142716089884
# Episode 2, epoch [15/15], loss: 2.1787962913513184
# Episode 2 completed in 7.25 seconds
# Starting episode 3/500
# Episode 3, epoch [1/15], loss: 1.2164249618848164
# Episode 3, epoch [2/15], loss: 1.2155214866002402
# Episode 3, epoch [3/15], loss: 1.2151924173037212
# Episode 3, epoch [4/15], loss: 1.214353624979655
# Episode 3, epoch [5/15], loss: 1.2134246428807576
# Episode 3, epoch [6/15], loss: 1.2125511089960734
# Episode 3, epoch [7/15], loss: 1.2119738260904949
# Episode 3, epoch [8/15], loss: 1.2122262636820476
# Episode 3, epoch [9/15], loss: 1.2108667969703675
# Episode 3, epoch [10/15], loss: 1.2106910983721415
# Episode 3, epoch [11/15], loss: 1.2104037364323934
# Episode 3, epoch [12/15], loss: 1.2095760385195413
# Episode 3, epoch [13/15], loss: 1.2093481461207072
# Episode 3, epoch [14/15], loss: 1.2088294665018717
# Episode 3, epoch [15/15], loss: 1.2081992427508037
# Episode 3 completed in 7.20 seconds
# Starting episode 4/500
# Episode 4, epoch [1/15], loss: 2.173087775707245
# Episode 4, epoch [2/15], loss: 2.1735298852125804
# Episode 4, epoch [3/15], loss: 2.171813110510508
# Episode 4, epoch [4/15], loss: 2.170281541347504
# Episode 4, epoch [5/15], loss: 2.1697447896003723
# Episode 4, epoch [6/15], loss: 2.1690600752830504
# Episode 4, epoch [7/15], loss: 2.168439551194509
# Episode 4, epoch [8/15], loss: 2.167720890045166
# Episode 4, epoch [9/15], loss: 2.168135948975881
# Episode 4, epoch [10/15], loss: 2.167286471525828
# Episode 4, epoch [11/15], loss: 2.1666621446609495
# Episode 4, epoch [12/15], loss: 2.166687568028768
# Episode 4, epoch [13/15], loss: 2.1662654519081115
# Episode 4, epoch [14/15], loss: 2.1659090598424275
# Episode 4, epoch [15/15], loss: 2.1655487775802613
# Episode 4 completed in 7.91 seconds
# Starting episode 5/500
# Episode 5, epoch [1/15], loss: 0.7349566002686818
# Episode 5, epoch [2/15], loss: 0.7333754142125447
# Episode 5, epoch [3/15], loss: 0.7320981423060099
# Episode 5, epoch [4/15], loss: 0.7313285132249197
# Episode 5, epoch [5/15], loss: 0.7310433328151703
# Episode 5, epoch [6/15], loss: 0.730045598745346
# Episode 5, epoch [7/15], loss: 0.7292474766572317
# Episode 5, epoch [8/15], loss: 0.728587253888448
# Episode 5, epoch [9/15], loss: 0.7283122380574544
# Episode 5, epoch [10/15], loss: 0.7270660777886708
# Episode 5, epoch [11/15], loss: 0.7263393819332122
# Episode 5, epoch [12/15], loss: 0.7260006666183472
# Episode 5, epoch [13/15], loss: 0.7258179565270741
# Episode 5, epoch [14/15], loss: 0.725261253118515
# Episode 5, epoch [15/15], loss: 0.725094364086787
# Episode 5 completed in 7.15 seconds
# Starting episode 6/500
# Episode 6, epoch [1/15], loss: 1.4444584091504415
# Episode 6, epoch [2/15], loss: 1.4446834286053976
# Episode 6, epoch [3/15], loss: 1.443358564376831
# Episode 6, epoch [4/15], loss: 1.4425960659980774
# Episode 6, epoch [5/15], loss: 1.4423697670300801
# Episode 6, epoch [6/15], loss: 1.4420973181724548
# Episode 6, epoch [7/15], loss: 1.441771642367045
# Episode 6, epoch [8/15], loss: 1.4413156270980836
# Episode 6, epoch [9/15], loss: 1.4410578807195027
# Episode 6, epoch [10/15], loss: 1.4410229961077372
# Episode 6, epoch [11/15], loss: 1.4407978614171346
# Episode 6, epoch [12/15], loss: 1.440138872464498
# Episode 6, epoch [13/15], loss: 1.440376301606496
# Episode 6, epoch [14/15], loss: 1.4403334935506185
# Episode 6, epoch [15/15], loss: 1.4403912663459777
# Episode 6 completed in 7.21 seconds
# Starting episode 7/500
# Episode 7, epoch [1/15], loss: 1.0351505001386008
# Episode 7, epoch [2/15], loss: 1.0335093061129252
# Episode 7, epoch [3/15], loss: 1.032453676064809
# Episode 7, epoch [4/15], loss: 1.0320893247922263
# Episode 7, epoch [5/15], loss: 1.0311072667439778
# Episode 7, epoch [6/15], loss: 1.0304750084877015
# Episode 7, epoch [7/15], loss: 1.0296157479286194
# Episode 7, epoch [8/15], loss: 1.029535190264384
# Episode 7, epoch [9/15], loss: 1.028683106104533
# Episode 7, epoch [10/15], loss: 1.0285041173299154
# Episode 7, epoch [11/15], loss: 1.027698806921641
# Episode 7, epoch [12/15], loss: 1.0269049088160196
# Episode 7, epoch [13/15], loss: 1.0263052781422932
# Episode 7, epoch [14/15], loss: 1.0255402088165284
# Episode 7, epoch [15/15], loss: 1.0246690233548483
# Episode 7 completed in 7.21 seconds
# Starting episode 8/500
# Episode 8, epoch [1/15], loss: 1.7977269411087036
# Episode 8, epoch [2/15], loss: 1.797741746902466
# Episode 8, epoch [3/15], loss: 1.7955571413040161
# Episode 8, epoch [4/15], loss: 1.7934361219406127
# Episode 8, epoch [5/15], loss: 1.793282926082611
# Episode 8, epoch [6/15], loss: 1.7935885151227315
# Episode 8, epoch [7/15], loss: 1.7916589577992756
# Episode 8, epoch [8/15], loss: 1.7912841161092123
# Episode 8, epoch [9/15], loss: 1.7904507756233214
# Episode 8, epoch [10/15], loss: 1.7898775657018027
# Episode 8, epoch [11/15], loss: 1.7900708357493083
# Episode 8, epoch [12/15], loss: 1.7899844725926717
# Episode 8, epoch [13/15], loss: 1.7891347845395407
# Episode 8, epoch [14/15], loss: 1.7894149820009868
# Episode 8, epoch [15/15], loss: 1.7881672898928325
# Episode 8 completed in 7.16 seconds
# Starting episode 9/500
# Episode 9, epoch [1/15], loss: 5.134121719996134
# Episode 9, epoch [2/15], loss: 5.135050710042318
# Episode 9, epoch [3/15], loss: 5.133724776903788
# Episode 9, epoch [4/15], loss: 5.131785281499227
# Episode 9, epoch [5/15], loss: 5.128536359469096
# Episode 9, epoch [6/15], loss: 5.128059244155883
# Episode 9, epoch [7/15], loss: 5.126934480667114
# Episode 9, epoch [8/15], loss: 5.124844471613566
# Episode 9, epoch [9/15], loss: 5.12580943107605
# Episode 9, epoch [10/15], loss: 5.124833456675211
# Episode 9, epoch [11/15], loss: 5.124985488255819
# Episode 9, epoch [12/15], loss: 5.124281493822734
# Episode 9, epoch [13/15], loss: 5.1226413488388065
# Episode 9, epoch [14/15], loss: 5.1228813012441
# Episode 9, epoch [15/15], loss: 5.12135857741038
# Episode 9 completed in 7.28 seconds
# Starting episode 10/500
# Episode 10, epoch [1/15], loss: 1.0289214173952739
# Episode 10, epoch [2/15], loss: 1.0264545679092407
# Episode 10, epoch [3/15], loss: 1.0253164569536846
# Episode 10, epoch [4/15], loss: 1.0239327708880106
# Episode 10, epoch [5/15], loss: 1.0233362396558126
# Episode 10, epoch [6/15], loss: 1.0225560744603475
# Episode 10, epoch [7/15], loss: 1.0221644639968872
# Episode 10, epoch [8/15], loss: 1.022117845217387
# Episode 10, epoch [9/15], loss: 1.0210070371627809
# Episode 10, epoch [10/15], loss: 1.0209320584932964
# Episode 10, epoch [11/15], loss: 1.0205256779988607
# Episode 10, epoch [12/15], loss: 1.0200474778811137
# Episode 10, epoch [13/15], loss: 1.0196882843971253
# Episode 10, epoch [14/15], loss: 1.0192710796991984
# Episode 10, epoch [15/15], loss: 1.0187697569529215
# Episode 10 completed in 7.23 seconds
# Saved hidden representations for episode 10
# Starting episode 11/500
# Episode 11, epoch [1/15], loss: 0.8293906291325887
# Episode 11, epoch [2/15], loss: 0.826957658926646
# Episode 11, epoch [3/15], loss: 0.8256080031394959
# Episode 11, epoch [4/15], loss: 0.8247062842051188
# Episode 11, epoch [5/15], loss: 0.8234380086263021
# Episode 11, epoch [6/15], loss: 0.8231968621412913
# Episode 11, epoch [7/15], loss: 0.8224149743715922
# Episode 11, epoch [8/15], loss: 0.8218916177749633
# Episode 11, epoch [9/15], loss: 0.821431056658427
# Episode 11, epoch [10/15], loss: 0.8210845828056336
# Episode 11, epoch [11/15], loss: 0.820972756544749
# Episode 11, epoch [12/15], loss: 0.8205532828966776
# Episode 11, epoch [13/15], loss: 0.8201664368311564
# Episode 11, epoch [14/15], loss: 0.8198636452356974
# Episode 11, epoch [15/15], loss: 0.8194352070490519
# Episode 11 completed in 7.18 seconds
# Starting episode 12/500
# Episode 12, epoch [1/15], loss: 1038385348609.1665
# Episode 12, epoch [2/15], loss: 1038385335502.0591
# Episode 12, epoch [3/15], loss: 1038385344240.1252
# Episode 12, epoch [4/15], loss: 1038385348609.279
# Episode 12, epoch [5/15], loss: 1038385361716.5677
# Episode 12, epoch [6/15], loss: 1038385344240.2489
# Episode 12, epoch [7/15], loss: 1038385366085.4409
# Episode 12, epoch [8/15], loss: 1038385335502.0198
# Episode 12, epoch [9/15], loss: 1038385344239.988
# Episode 12, epoch [10/15], loss: 1038385361716.4264
# Episode 12, epoch [11/15], loss: 1038385331133.0946
# Episode 12, epoch [12/15], loss: 1038385348609.1827
# Episode 12, epoch [13/15], loss: 1038385296180.5374
# Episode 12, epoch [14/15], loss: 1038385348609.1891
# Episode 12, epoch [15/15], loss: 1038385344240.2308
# Episode 12 completed in 7.25 seconds
# Starting episode 13/500
# Episode 13, epoch [1/15], loss: 1.178281009197235
# Episode 13, epoch [2/15], loss: 1.1766532123088838
# Episode 13, epoch [3/15], loss: 1.1759894212086996
# Episode 13, epoch [4/15], loss: 1.1759159564971924
# Episode 13, epoch [5/15], loss: 1.1758281389872234
# Episode 13, epoch [6/15], loss: 1.1752630511919657
# Episode 13, epoch [7/15], loss: 1.1748397707939149
# Episode 13, epoch [8/15], loss: 1.174751087029775
# Episode 13, epoch [9/15], loss: 1.174540603160858
# Episode 13, epoch [10/15], loss: 1.1741737922032673
# Episode 13, epoch [11/15], loss: 1.1742534597714742
# Episode 13, epoch [12/15], loss: 1.174291761716207
# Episode 13, epoch [13/15], loss: 1.1739316165447236
# Episode 13, epoch [14/15], loss: 1.174308063586553
# Episode 13, epoch [15/15], loss: 1.1738334139188131
# Episode 13 completed in 7.25 seconds
# Starting episode 14/500
# Episode 14, epoch [1/15], loss: 1.186948827902476
# Episode 14, epoch [2/15], loss: 1.186283826828003
# Episode 14, epoch [3/15], loss: 1.1862338662147522
# Episode 14, epoch [4/15], loss: 1.1858034292856852
# Episode 14, epoch [5/15], loss: 1.1847158829371134
# Episode 14, epoch [6/15], loss: 1.1848533511161805
# Episode 14, epoch [7/15], loss: 1.1847816745440165
# Episode 14, epoch [8/15], loss: 1.1843793551127115
# Episode 14, epoch [9/15], loss: 1.1840943296750386
# Episode 14, epoch [10/15], loss: 1.1837872942288716
# Episode 14, epoch [11/15], loss: 1.1839103738466898
# Episode 14, epoch [12/15], loss: 1.1835684895515441
# Episode 14, epoch [13/15], loss: 1.183321217695872
# Episode 14, epoch [14/15], loss: 1.1829660375912985
# Episode 14, epoch [15/15], loss: 1.183050258954366
# Episode 14 completed in 7.36 seconds
# Starting episode 15/500
# Episode 15, epoch [1/15], loss: 1.4820711771647135
# Episode 15, epoch [2/15], loss: 1.4821089426676433
# Episode 15, epoch [3/15], loss: 1.4821537216504415
# Episode 15, epoch [4/15], loss: 1.4810678998629252
# Episode 15, epoch [5/15], loss: 1.4805729230244955
# Episode 15, epoch [6/15], loss: 1.48045525153478
# Episode 15, epoch [7/15], loss: 1.4805931607882181
# Episode 15, epoch [8/15], loss: 1.4807557741800943
# Episode 15, epoch [9/15], loss: 1.480281953016917
# Episode 15, epoch [10/15], loss: 1.4802884618441263
# Episode 15, epoch [11/15], loss: 1.4798843185106914
# Episode 15, epoch [12/15], loss: 1.4795653184254964
# Episode 15, epoch [13/15], loss: 1.478817609945933
# Episode 15, epoch [14/15], loss: 1.4787040869394938
# Episode 15, epoch [15/15], loss: 1.4787803093592327
# Episode 15 completed in 7.20 seconds
# Starting episode 16/500
# Episode 16, epoch [1/15], loss: 1.8730589429537454
# Episode 16, epoch [2/15], loss: 1.872586723168691
# Episode 16, epoch [3/15], loss: 1.873121150334676
# Episode 16, epoch [4/15], loss: 1.8728867729504903
# Episode 16, epoch [5/15], loss: 1.8725575089454651
# Episode 16, epoch [6/15], loss: 1.8716216405232748
# Episode 16, epoch [7/15], loss: 1.8713067054748536
# Episode 16, epoch [8/15], loss: 1.8720035552978516
# Episode 16, epoch [9/15], loss: 1.872536869843801
# Episode 16, epoch [10/15], loss: 1.8714422941207887
# Episode 16, epoch [11/15], loss: 1.8711895585060119
# Episode 16, epoch [12/15], loss: 1.8718547900517781
# Episode 16, epoch [13/15], loss: 1.8709798574447631
# Episode 16, epoch [14/15], loss: 1.8715251008669536
# Episode 16, epoch [15/15], loss: 1.8712926785151163
# Episode 16 completed in 7.35 seconds
# Starting episode 17/500
# Episode 17, epoch [1/15], loss: 0.6803315500418345
# Episode 17, epoch [2/15], loss: 0.6790916085243225
# Episode 17, epoch [3/15], loss: 0.6784067372481029
# Episode 17, epoch [4/15], loss: 0.6779740830262502
# Episode 17, epoch [5/15], loss: 0.6775385499000549
# Episode 17, epoch [6/15], loss: 0.6774331788221996
# Episode 17, epoch [7/15], loss: 0.6772025108337403
# Episode 17, epoch [8/15], loss: 0.6772226989269257
# Episode 17, epoch [9/15], loss: 0.676843770345052
# Episode 17, epoch [10/15], loss: 0.6769453803698222
# Episode 17, epoch [11/15], loss: 0.6767999509970347
# Episode 17, epoch [12/15], loss: 0.6768746435642242
# Episode 17, epoch [13/15], loss: 0.6765291313330333
# Episode 17, epoch [14/15], loss: 0.676485276222229
# Episode 17, epoch [15/15], loss: 0.6764746864636739
# Episode 17 completed in 7.80 seconds
# Starting episode 18/500
# Episode 18, epoch [1/15], loss: 3.503813370068868
# Episode 18, epoch [2/15], loss: 3.5034425973892214
# Episode 18, epoch [3/15], loss: 3.502536424001058
# Episode 18, epoch [4/15], loss: 3.501996652285258
# Episode 18, epoch [5/15], loss: 3.500569788614909
# Episode 18, epoch [6/15], loss: 3.501144615809123
# Episode 18, epoch [7/15], loss: 3.5009816964467366
# Episode 18, epoch [8/15], loss: 3.5003259976704917
# Episode 18, epoch [9/15], loss: 3.4989727973937987
# Episode 18, epoch [10/15], loss: 3.4994266589482623
# Episode 18, epoch [11/15], loss: 3.498780385653178
# Episode 18, epoch [12/15], loss: 3.4984150489171344
# Episode 18, epoch [13/15], loss: 3.499155886967977
# Episode 18, epoch [14/15], loss: 3.4990676164627077
# Episode 18, epoch [15/15], loss: 3.49892102877299
# Episode 18 completed in 7.22 seconds
# Starting episode 19/500
# Episode 19, epoch [1/15], loss: 11.44396375020345
# Episode 19, epoch [2/15], loss: 11.44464724858602
# Episode 19, epoch [3/15], loss: 11.443775256474813
# Episode 19, epoch [4/15], loss: 11.443720499674479
# Episode 19, epoch [5/15], loss: 11.441286746660868
# Episode 19, epoch [6/15], loss: 11.441514603296916
# Episode 19, epoch [7/15], loss: 11.44110894203186
# Episode 19, epoch [8/15], loss: 11.440826797485352
# Episode 19, epoch [9/15], loss: 11.440890407562256
# Episode 19, epoch [10/15], loss: 11.440371084213258
# Episode 19, epoch [11/15], loss: 11.43983203570048
# Episode 19, epoch [12/15], loss: 11.440785932540894
# Episode 19, epoch [13/15], loss: 11.441385746002197
# Episode 19, epoch [14/15], loss: 11.440665133794148
# Episode 19, epoch [15/15], loss: 11.44039535522461
# Episode 19 completed in 7.22 seconds
# Starting episode 20/500
# Episode 20, epoch [1/15], loss: 0.6815616349379222
# Episode 20, epoch [2/15], loss: 0.680052888393402
# Episode 20, epoch [3/15], loss: 0.6795393884181976
# Episode 20, epoch [4/15], loss: 0.6791504383087158
# Episode 20, epoch [5/15], loss: 0.6786912838617961
# Episode 20, epoch [6/15], loss: 0.6781972765922546
# Episode 20, epoch [7/15], loss: 0.6781601846218109
# Episode 20, epoch [8/15], loss: 0.6779019395510356
# Episode 20, epoch [9/15], loss: 0.6778319358825684
# Episode 20, epoch [10/15], loss: 0.6775632858276367
# Episode 20, epoch [11/15], loss: 0.6773476123809814
# Episode 20, epoch [12/15], loss: 0.6772276719411214
# Episode 20, epoch [13/15], loss: 0.6771324475606283
# Episode 20, epoch [14/15], loss: 0.6770258545875549
# Episode 20, epoch [15/15], loss: 0.6768514116605123
# Episode 20 completed in 7.18 seconds
# Saved hidden representations for episode 20
# Starting episode 21/500
# Episode 21, epoch [1/15], loss: 1.1379590113957723
# Episode 21, epoch [2/15], loss: 1.137220291296641
# Episode 21, epoch [3/15], loss: 1.1365561286608379
# Episode 21, epoch [4/15], loss: 1.1358659704526266
# Episode 21, epoch [5/15], loss: 1.135605506102244
# Episode 21, epoch [6/15], loss: 1.1356597820917764
# Episode 21, epoch [7/15], loss: 1.135645322004954
# Episode 21, epoch [8/15], loss: 1.1356555143992106
# Episode 21, epoch [9/15], loss: 1.1350050806999206
# Episode 21, epoch [10/15], loss: 1.1348456263542175
# Episode 21, epoch [11/15], loss: 1.1349955757459005
# Episode 21, epoch [12/15], loss: 1.1344261447588602
# Episode 21, epoch [13/15], loss: 1.13433997631073
# Episode 21, epoch [14/15], loss: 1.1345327019691467
# Episode 21, epoch [15/15], loss: 1.1340493122736612
# Episode 21 completed in 7.30 seconds
# Starting episode 22/500
# Episode 22, epoch [1/15], loss: 7202.415886656443
# Episode 22, epoch [2/15], loss: 7202.415510161718
# Episode 22, epoch [3/15], loss: 7202.414544955889
# Episode 22, epoch [4/15], loss: 7202.413166085879
# Episode 22, epoch [5/15], loss: 7202.412439393997
# Episode 22, epoch [6/15], loss: 7202.412339544297
# Episode 22, epoch [7/15], loss: 7202.411321854592
# Episode 22, epoch [8/15], loss: 7202.41154764096
# Episode 22, epoch [9/15], loss: 7202.411684004465
# Episode 22, epoch [10/15], loss: 7202.41218817234
# Episode 22, epoch [11/15], loss: 7202.411509346962
# Episode 22, epoch [12/15], loss: 7202.412803359826
# Episode 22, epoch [13/15], loss: 7202.412050088246
# Episode 22, epoch [14/15], loss: 7202.4113997300465
# Episode 22, epoch [15/15], loss: 7202.410896158219
# Episode 22 completed in 7.32 seconds
# Starting episode 23/500
# Episode 23, epoch [1/15], loss: 0.6684726039568584
# Episode 23, epoch [2/15], loss: 0.6674444595972697
# Episode 23, epoch [3/15], loss: 0.6673384229342143
# Episode 23, epoch [4/15], loss: 0.6667046864827474
# Episode 23, epoch [5/15], loss: 0.6664389570554098
# Episode 23, epoch [6/15], loss: 0.6660090406735738
# Episode 23, epoch [7/15], loss: 0.665872061252594
# Episode 23, epoch [8/15], loss: 0.6655741572380066
# Episode 23, epoch [9/15], loss: 0.665185817082723
# Episode 23, epoch [10/15], loss: 0.6652374466260275
# Episode 23, epoch [11/15], loss: 0.6651642004648844
# Episode 23, epoch [12/15], loss: 0.6652090509732564
# Episode 23, epoch [13/15], loss: 0.6647501786549886
# Episode 23, epoch [14/15], loss: 0.6647859652837117
# Episode 23, epoch [15/15], loss: 0.6645090937614441
# Episode 23 completed in 7.26 seconds
# Starting episode 24/500
# Episode 24, epoch [1/15], loss: 0.6866096039613088
# Episode 24, epoch [2/15], loss: 0.6844076792399089
# Episode 24, epoch [3/15], loss: 0.6828163206577301
# Episode 24, epoch [4/15], loss: 0.6819883187611898
# Episode 24, epoch [5/15], loss: 0.681851331392924
# Episode 24, epoch [6/15], loss: 0.6813150882720947
# Episode 24, epoch [7/15], loss: 0.6808406313260397
# Episode 24, epoch [8/15], loss: 0.680586846669515
# Episode 24, epoch [9/15], loss: 0.6802776356538137
# Episode 24, epoch [10/15], loss: 0.6800105432669322
# Episode 24, epoch [11/15], loss: 0.6801081001758575
# Episode 24, epoch [12/15], loss: 0.6795539220174154
# Episode 24, epoch [13/15], loss: 0.6795493304729462
# Episode 24, epoch [14/15], loss: 0.6791264454523722
# Episode 24, epoch [15/15], loss: 0.6795098185539246
# Episode 24 completed in 7.30 seconds
# Starting episode 25/500
# Episode 25, epoch [1/15], loss: 1.4422916372617085
# Episode 25, epoch [2/15], loss: 1.4418624798456827
# Episode 25, epoch [3/15], loss: 1.4403231302897135
# Episode 25, epoch [4/15], loss: 1.4398406585057577
# Episode 25, epoch [5/15], loss: 1.4387818654378255
# Episode 25, epoch [6/15], loss: 1.438763435681661
# Episode 25, epoch [7/15], loss: 1.4385816256205242
# Episode 25, epoch [8/15], loss: 1.4382970929145813
# Episode 25, epoch [9/15], loss: 1.4376498103141784
# Episode 25, epoch [10/15], loss: 1.437656851609548
# Episode 25, epoch [11/15], loss: 1.437579051653544
# Episode 25, epoch [12/15], loss: 1.4373613754908243
# Episode 25, epoch [13/15], loss: 1.437588346004486
# Episode 25, epoch [14/15], loss: 1.4372139970461528
# Episode 25, epoch [15/15], loss: 1.4370890696843466
# Episode 25 completed in 7.33 seconds
# Starting episode 26/500
# Episode 26, epoch [1/15], loss: 5817525.123868322
# Episode 26, epoch [2/15], loss: 5817525.090692599
# Episode 26, epoch [3/15], loss: 5817525.184998616
# Episode 26, epoch [4/15], loss: 5817525.112960204
# Episode 26, epoch [5/15], loss: 5817525.096754281
# Episode 26, epoch [6/15], loss: 5817525.065157303
# Episode 26, epoch [7/15], loss: 5817525.157453886
# Episode 26, epoch [8/15], loss: 5817525.167876824
# Episode 26, epoch [9/15], loss: 5817525.159983595
# Episode 26, epoch [10/15], loss: 5817525.106757418
# Episode 26, epoch [11/15], loss: 5817525.222641992
# Episode 26, epoch [12/15], loss: 5817525.032618531
# Episode 26, epoch [13/15], loss: 5817525.217543165
# Episode 26, epoch [14/15], loss: 5817525.088675022
# Episode 26, epoch [15/15], loss: 5817525.069706496
# Episode 26 completed in 7.31 seconds
# Starting episode 27/500
# Episode 27, epoch [1/15], loss: 4.221511363983154
# Episode 27, epoch [2/15], loss: 4.220202199618021
# Episode 27, epoch [3/15], loss: 4.21844711303711
# Episode 27, epoch [4/15], loss: 4.217834059397379
# Episode 27, epoch [5/15], loss: 4.218763303756714
# Episode 27, epoch [6/15], loss: 4.218443624178568
# Episode 27, epoch [7/15], loss: 4.217862184842428
# Episode 27, epoch [8/15], loss: 4.217053397496541
# Episode 27, epoch [9/15], loss: 4.215989549954732
# Episode 27, epoch [10/15], loss: 4.216005754470825
# Episode 27, epoch [11/15], loss: 4.2160268465677895
# Episode 27, epoch [12/15], loss: 4.215995240211487
# Episode 27, epoch [13/15], loss: 4.215284629662832
# Episode 27, epoch [14/15], loss: 4.215769529342651
# Episode 27, epoch [15/15], loss: 4.214872590700785
# Episode 27 completed in 7.36 seconds
# Starting episode 28/500
# Episode 28, epoch [1/15], loss: 0.628228489557902
# Episode 28, epoch [2/15], loss: 0.6272559583187103
# Episode 28, epoch [3/15], loss: 0.6264735261599222
# Episode 28, epoch [4/15], loss: 0.6261657297611236
# Episode 28, epoch [5/15], loss: 0.6258156855901083
# Episode 28, epoch [6/15], loss: 0.6257068276405334
# Episode 28, epoch [7/15], loss: 0.6257428288459778
# Episode 28, epoch [8/15], loss: 0.6252469102541606
# Episode 28, epoch [9/15], loss: 0.6253714938958486
# Episode 28, epoch [10/15], loss: 0.6251549939314525
# Episode 28, epoch [11/15], loss: 0.6248108367125194
# Episode 28, epoch [12/15], loss: 0.6248944679896037
# Episode 28, epoch [13/15], loss: 0.6246707022190094
# Episode 28, epoch [14/15], loss: 0.6246707201004028
# Episode 28, epoch [15/15], loss: 0.6242585003376007
# Episode 28 completed in 7.24 seconds
# Starting episode 29/500
# Episode 29, epoch [1/15], loss: 0.7373543520768483
# Episode 29, epoch [2/15], loss: 0.7364918947219848
# Episode 29, epoch [3/15], loss: 0.7359348893165588
# Episode 29, epoch [4/15], loss: 0.735583637158076
# Episode 29, epoch [5/15], loss: 0.735457452138265
# Episode 29, epoch [6/15], loss: 0.7352229754130045
# Episode 29, epoch [7/15], loss: 0.7358471532662709
# Episode 29, epoch [8/15], loss: 0.7356982847054799
# Episode 29, epoch [9/15], loss: 0.7347510794798533
# Episode 29, epoch [10/15], loss: 0.7345603803793589
# Episode 29, epoch [11/15], loss: 0.7343703826268514
# Episode 29, epoch [12/15], loss: 0.7343064526716868
# Episode 29, epoch [13/15], loss: 0.7343737502892812
# Episode 29, epoch [14/15], loss: 0.7341759840647379
# Episode 29, epoch [15/15], loss: 0.7341307044029236
# Episode 29 completed in 7.52 seconds
# Starting episode 30/500
# Episode 30, epoch [1/15], loss: 1.3011089543501535
# Episode 30, epoch [2/15], loss: 1.2990514576435088
# Episode 30, epoch [3/15], loss: 1.2988577087720234
# Episode 30, epoch [4/15], loss: 1.2976366996765136
# Episode 30, epoch [5/15], loss: 1.2974623262882232
# Episode 30, epoch [6/15], loss: 1.2967122634251913
# Episode 30, epoch [7/15], loss: 1.2960683663686117
# Episode 30, epoch [8/15], loss: 1.2960451563199362
# Episode 30, epoch [9/15], loss: 1.295927902062734
# Episode 30, epoch [10/15], loss: 1.2953764994939168
# Episode 30, epoch [11/15], loss: 1.2958464006582895
# Episode 30, epoch [12/15], loss: 1.2948921104272206
# Episode 30, epoch [13/15], loss: 1.2954428692658742
# Episode 30, epoch [14/15], loss: 1.2946288327376048
# Episode 30, epoch [15/15], loss: 1.294947522878647
# Episode 30 completed in 7.30 seconds
# Saved hidden representations for episode 30
# Starting episode 31/500
# Episode 31, epoch [1/15], loss: 0.9930927435557048
# Episode 31, epoch [2/15], loss: 0.9913324296474457
# Episode 31, epoch [3/15], loss: 0.9907110214233399
# Episode 31, epoch [4/15], loss: 0.9901320656140645
# Episode 31, epoch [5/15], loss: 0.9898456474145253
# Episode 31, epoch [6/15], loss: 0.9891360680262248
# Episode 31, epoch [7/15], loss: 0.9887429018815358
# Episode 31, epoch [8/15], loss: 0.9884605248769124
# Episode 31, epoch [9/15], loss: 0.9888208885987599
# Episode 31, epoch [10/15], loss: 0.9887417991956075
# Episode 31, epoch [11/15], loss: 0.988446323076884
# Episode 31, epoch [12/15], loss: 0.9888868967692057
# Episode 31, epoch [13/15], loss: 0.9886578818162283
# Episode 31, epoch [14/15], loss: 0.988122413555781
# Episode 31, epoch [15/15], loss: 0.9879714846611023
# Episode 31 completed in 7.42 seconds
# Starting episode 32/500
# Episode 32, epoch [1/15], loss: 1.8396689971288045
# Episode 32, epoch [2/15], loss: 1.8381967226664224
# Episode 32, epoch [3/15], loss: 1.8366801102956136
# Episode 32, epoch [4/15], loss: 1.8366695801417032
# Episode 32, epoch [5/15], loss: 1.8356749375661214
# Episode 32, epoch [6/15], loss: 1.8355412801106772
# Episode 32, epoch [7/15], loss: 1.8342960198720297
# Episode 32, epoch [8/15], loss: 1.8343334277470906
# Episode 32, epoch [9/15], loss: 1.834134785334269
# Episode 32, epoch [10/15], loss: 1.833706545829773
# Episode 32, epoch [11/15], loss: 1.8336341778437297
# Episode 32, epoch [12/15], loss: 1.833386977513631
# Episode 32, epoch [13/15], loss: 1.8325639009475707
# Episode 32, epoch [14/15], loss: 1.8329838673273722
# Episode 32, epoch [15/15], loss: 1.8327796459197998
# Episode 32 completed in 7.47 seconds
# Starting episode 33/500
# Episode 33, epoch [1/15], loss: 0.5419583857059479
# Episode 33, epoch [2/15], loss: 0.5397410710652669
# Episode 33, epoch [3/15], loss: 0.5388039628664653
# Episode 33, epoch [4/15], loss: 0.5382467746734619
# Episode 33, epoch [5/15], loss: 0.5375484724839529
# Episode 33, epoch [6/15], loss: 0.5369083344936371
# Episode 33, epoch [7/15], loss: 0.5368254661560059
# Episode 33, epoch [8/15], loss: 0.5362186352411906
# Episode 33, epoch [9/15], loss: 0.536287126938502
# Episode 33, epoch [10/15], loss: 0.5358375449975331
# Episode 33, epoch [11/15], loss: 0.5356618305047353
# Episode 33, epoch [12/15], loss: 0.535752660036087
# Episode 33, epoch [13/15], loss: 0.5356004377206166
# Episode 33, epoch [14/15], loss: 0.5356018046538035
# Episode 33, epoch [15/15], loss: 0.5354345401128133
# Episode 33 completed in 7.46 seconds
# Starting episode 34/500
# Episode 34, epoch [1/15], loss: 15.085659154256184
# Episode 34, epoch [2/15], loss: 15.086799399058025
# Episode 34, epoch [3/15], loss: 15.086409028371175
# Episode 34, epoch [4/15], loss: 15.08692668279012
# Episode 34, epoch [5/15], loss: 15.086383438110351
# Episode 34, epoch [6/15], loss: 15.08423407872518
# Episode 34, epoch [7/15], loss: 15.081754597028096
# Episode 34, epoch [8/15], loss: 15.082689142227172
# Episode 34, epoch [9/15], loss: 15.082686932881673
# Episode 34, epoch [10/15], loss: 15.082720677057901
# Episode 34, epoch [11/15], loss: 15.083070786794027
# Episode 34, epoch [12/15], loss: 15.081501468022664
# Episode 34, epoch [13/15], loss: 15.081490723292033
# Episode 34, epoch [14/15], loss: 15.080950768788655
# Episode 34, epoch [15/15], loss: 15.081586106618245
# Episode 34 completed in 7.47 seconds
# Starting episode 35/500
# Episode 35, epoch [1/15], loss: 0.5990287641684214
# Episode 35, epoch [2/15], loss: 0.5970146199067433
# Episode 35, epoch [3/15], loss: 0.5962574521700541
# Episode 35, epoch [4/15], loss: 0.5960238615671793
# Episode 35, epoch [5/15], loss: 0.5957070728143056
# Episode 35, epoch [6/15], loss: 0.5951238135496776
# Episode 35, epoch [7/15], loss: 0.5951055467128754
# Episode 35, epoch [8/15], loss: 0.5949231227238972
# Episode 35, epoch [9/15], loss: 0.5949698348840078
# Episode 35, epoch [10/15], loss: 0.5951033194859823
# Episode 35, epoch [11/15], loss: 0.5948792994022369
# Episode 35, epoch [12/15], loss: 0.5946792741616567
# Episode 35, epoch [13/15], loss: 0.5944152732690176
# Episode 35, epoch [14/15], loss: 0.5945483028888703
# Episode 35, epoch [15/15], loss: 0.5944554448127747
# Episode 35 completed in 7.35 seconds
# Starting episode 36/500
# Episode 36, epoch [1/15], loss: 5266778.661461576
# Episode 36, epoch [2/15], loss: 5266778.662827225
# Episode 36, epoch [3/15], loss: 5266778.645758112
# Episode 36, epoch [4/15], loss: 5266778.649152193
# Episode 36, epoch [5/15], loss: 5266778.641646554
# Episode 36, epoch [6/15], loss: 5266778.650071796
# Episode 36, epoch [7/15], loss: 5266778.649871894
# Episode 36, epoch [8/15], loss: 5266778.6423015455
# Episode 36, epoch [9/15], loss: 5266778.653184507
# Episode 36, epoch [10/15], loss: 5266778.645434511
# Episode 36, epoch [11/15], loss: 5266778.656564995
# Episode 36, epoch [12/15], loss: 5266778.657089144
# Episode 36, epoch [13/15], loss: 5266778.63741198
# Episode 36, epoch [14/15], loss: 5266778.658920304
# Episode 36, epoch [15/15], loss: 5266778.652140579
# Episode 36 completed in 7.46 seconds
# Starting episode 37/500
# Episode 37, epoch [1/15], loss: 495921154.590843
# Episode 37, epoch [2/15], loss: 495921154.68345517
# Episode 37, epoch [3/15], loss: 495921154.64049375
# Episode 37, epoch [4/15], loss: 495921154.46052164
# Episode 37, epoch [5/15], loss: 495921154.67463195
# Episode 37, epoch [6/15], loss: 495921154.67077804
# Episode 37, epoch [7/15], loss: 495921154.60493314
# Episode 37, epoch [8/15], loss: 495921154.69925463
# Episode 37, epoch [9/15], loss: 495921154.56889814
# Episode 37, epoch [10/15], loss: 495921154.70485497
# Episode 37, epoch [11/15], loss: 495921154.5802174
# Episode 37, epoch [12/15], loss: 495921154.6609548
# Episode 37, epoch [13/15], loss: 495921154.5055195
# Episode 37, epoch [14/15], loss: 495921154.53933436
# Episode 37, epoch [15/15], loss: 495921154.61374545
# Episode 37 completed in 7.49 seconds
# Starting episode 38/500
# Episode 38, epoch [1/15], loss: 461617938.1558286
# Episode 38, epoch [2/15], loss: 461617938.1915208
# Episode 38, epoch [3/15], loss: 461617938.21819144
# Episode 38, epoch [4/15], loss: 461617938.2193991
# Episode 38, epoch [5/15], loss: 461617938.1556719
# Episode 38, epoch [6/15], loss: 461617938.18575376
# Episode 38, epoch [7/15], loss: 461617938.22644
# Episode 38, epoch [8/15], loss: 461617938.17701066
# Episode 38, epoch [9/15], loss: 461617938.20733315
# Episode 38, epoch [10/15], loss: 461617938.1488687
# Episode 38, epoch [11/15], loss: 461617938.18230385
# Episode 38, epoch [12/15], loss: 461617938.2247816
# Episode 38, epoch [13/15], loss: 461617938.1992457
# Episode 38, epoch [14/15], loss: 461617938.2102295
# Episode 38, epoch [15/15], loss: 461617938.1892961
# Episode 38 completed in 7.42 seconds
# Starting episode 39/500
# Episode 39, epoch [1/15], loss: 155068247.3935666
# Episode 39, epoch [2/15], loss: 155068247.3139456
# Episode 39, epoch [3/15], loss: 155068247.27465466
# Episode 39, epoch [4/15], loss: 155068247.23294085
# Episode 39, epoch [5/15], loss: 155068247.35361823
# Episode 39, epoch [6/15], loss: 155068247.3485597
# Episode 39, epoch [7/15], loss: 155068247.24783123
# Episode 39, epoch [8/15], loss: 155068247.1563606
# Episode 39, epoch [9/15], loss: 155068247.3669473
# Episode 39, epoch [10/15], loss: 155068247.3385725
# Episode 39, epoch [11/15], loss: 155068247.12416536
# Episode 39, epoch [12/15], loss: 155068247.30734536
# Episode 39, epoch [13/15], loss: 155068247.365794
# Episode 39, epoch [14/15], loss: 155068247.2456209
# Episode 39, epoch [15/15], loss: 155068247.38883838
# Episode 39 completed in 7.47 seconds
# Starting episode 40/500
# Episode 40, epoch [1/15], loss: 3.0380526781082153
# Episode 40, epoch [2/15], loss: 3.0383108655611673
# Episode 40, epoch [3/15], loss: 3.0375892440478007
# Episode 40, epoch [4/15], loss: 3.0377579887708026
# Episode 40, epoch [5/15], loss: 3.036967476209005
# Episode 40, epoch [6/15], loss: 3.0360409736633303
# Episode 40, epoch [7/15], loss: 3.0354829748471577
# Episode 40, epoch [8/15], loss: 3.0353389104207356
# Episode 40, epoch [9/15], loss: 3.035826094945272
# Episode 40, epoch [10/15], loss: 3.0359156370162963
# Episode 40, epoch [11/15], loss: 3.0355066537857054
# Episode 40, epoch [12/15], loss: 3.0350471178690595
# Episode 40, epoch [13/15], loss: 3.0352471033732096
# Episode 40, epoch [14/15], loss: 3.035200790564219
# Episode 40, epoch [15/15], loss: 3.03531854947408
# Episode 40 completed in 7.48 seconds
# Saved hidden representations for episode 40
# Starting episode 41/500
# Episode 41, epoch [1/15], loss: 52368854.01339154
# Episode 41, epoch [2/15], loss: 52368854.33619976
# Episode 41, epoch [3/15], loss: 52368854.40828015
# Episode 41, epoch [4/15], loss: 52368854.06116352
# Episode 41, epoch [5/15], loss: 52368854.52103009
# Episode 41, epoch [6/15], loss: 52368854.131304756
# Episode 41, epoch [7/15], loss: 52368854.46045108
# Episode 41, epoch [8/15], loss: 52368854.48879876
# Episode 41, epoch [9/15], loss: 52368854.1697156
# Episode 41, epoch [10/15], loss: 52368853.82392259
# Episode 41, epoch [11/15], loss: 52368854.54600337
# Episode 41, epoch [12/15], loss: 52368854.50425075
# Episode 41, epoch [13/15], loss: 52368854.521605425
# Episode 41, epoch [14/15], loss: 52368854.43165615
# Episode 41, epoch [15/15], loss: 52368854.12666035
# Episode 41 completed in 7.68 seconds
# Starting episode 42/500
# Episode 42, epoch [1/15], loss: 3.459678316116333
# Episode 42, epoch [2/15], loss: 3.458684237798055
# Episode 42, epoch [3/15], loss: 3.4578408718109133
# Episode 42, epoch [4/15], loss: 3.4578412055969237
# Episode 42, epoch [5/15], loss: 3.4571303208669026
# Episode 42, epoch [6/15], loss: 3.457049043973287
# Episode 42, epoch [7/15], loss: 3.4563036918640138
# Episode 42, epoch [8/15], loss: 3.4567079305648805
# Episode 42, epoch [9/15], loss: 3.457168197631836
# Episode 42, epoch [10/15], loss: 3.456686806678772
# Episode 42, epoch [11/15], loss: 3.456146319707235
# Episode 42, epoch [12/15], loss: 3.4564643700917563
# Episode 42, epoch [13/15], loss: 3.456544613838196
# Episode 42, epoch [14/15], loss: 3.456329870223999
# Episode 42, epoch [15/15], loss: 3.4560736338297526
# Episode 42 completed in 7.51 seconds
# Starting episode 43/500
# Episode 43, epoch [1/15], loss: 2.7591585596402486
# Episode 43, epoch [2/15], loss: 2.7583593765894574
# Episode 43, epoch [3/15], loss: 2.7582835098107656
# Episode 43, epoch [4/15], loss: 2.7581649939219157
# Episode 43, epoch [5/15], loss: 2.7573421955108643
# Episode 43, epoch [6/15], loss: 2.757372760772705
# Episode 43, epoch [7/15], loss: 2.7573426326115924
# Episode 43, epoch [8/15], loss: 2.757007388273875
# Episode 43, epoch [9/15], loss: 2.757013026873271
# Episode 43, epoch [10/15], loss: 2.756954288482666
# Episode 43, epoch [11/15], loss: 2.7572182496388753
# Episode 43, epoch [12/15], loss: 2.7565483073393504
# Episode 43, epoch [13/15], loss: 2.7567280173301696
# Episode 43, epoch [14/15], loss: 2.7562088847160338
# Episode 43, epoch [15/15], loss: 2.7563903172810873
# Episode 43 completed in 7.48 seconds
# Starting episode 44/500
# Episode 44, epoch [1/15], loss: 0.796860404809316
# Episode 44, epoch [2/15], loss: 0.7951124946276347
# Episode 44, epoch [3/15], loss: 0.7942585349082947
# Episode 44, epoch [4/15], loss: 0.7937203764915466
# Episode 44, epoch [5/15], loss: 0.7931031187375387
# Episode 44, epoch [6/15], loss: 0.7928925653298696
# Episode 44, epoch [7/15], loss: 0.7925073742866516
# Episode 44, epoch [8/15], loss: 0.7922043164571126
# Episode 44, epoch [9/15], loss: 0.7920193394025167
# Episode 44, epoch [10/15], loss: 0.7919699013233185
# Episode 44, epoch [11/15], loss: 0.7916534384091695
# Episode 44, epoch [12/15], loss: 0.7916177789370219
# Episode 44, epoch [13/15], loss: 0.7912396033604939
# Episode 44, epoch [14/15], loss: 0.7911632339159648
# Episode 44, epoch [15/15], loss: 0.7910798708597819
# Episode 44 completed in 7.45 seconds
# Starting episode 45/500
# Episode 45, epoch [1/15], loss: 0.8535901625951131
# Episode 45, epoch [2/15], loss: 0.8522351125876109
# Episode 45, epoch [3/15], loss: 0.8511542836825053
# Episode 45, epoch [4/15], loss: 0.8509046296278636
# Episode 45, epoch [5/15], loss: 0.8502931873003642
# Episode 45, epoch [6/15], loss: 0.8498169541358948
# Episode 45, epoch [7/15], loss: 0.8497974276542664
# Episode 45, epoch [8/15], loss: 0.8498596509297689
# Episode 45, epoch [9/15], loss: 0.849531348546346
# Episode 45, epoch [10/15], loss: 0.849210520585378
# Episode 45, epoch [11/15], loss: 0.8492874105771383
# Episode 45, epoch [12/15], loss: 0.8489676276842754
# Episode 45, epoch [13/15], loss: 0.8487586140632629
# Episode 45, epoch [14/15], loss: 0.848880660533905
# Episode 45, epoch [15/15], loss: 0.8491925915082296
# Episode 45 completed in 7.53 seconds
# Starting episode 46/500
# Episode 46, epoch [1/15], loss: 3.5982983271280924
# Episode 46, epoch [2/15], loss: 3.598080062866211
# Episode 46, epoch [3/15], loss: 3.597240432103475
# Episode 46, epoch [4/15], loss: 3.596705357233683
# Episode 46, epoch [5/15], loss: 3.5962666034698487
# Episode 46, epoch [6/15], loss: 3.596228551864624
# Episode 46, epoch [7/15], loss: 3.5964195569356283
# Episode 46, epoch [8/15], loss: 3.597309366861979
# Episode 46, epoch [9/15], loss: 3.5975508530934652
# Episode 46, epoch [10/15], loss: 3.5975161234537762
# Episode 46, epoch [11/15], loss: 3.5960381348927815
# Episode 46, epoch [12/15], loss: 3.596270449956258
# Episode 46, epoch [13/15], loss: 3.595038715998332
# Episode 46, epoch [14/15], loss: 3.595591155687968
# Episode 46, epoch [15/15], loss: 3.5962463061014813
# Episode 46 completed in 7.52 seconds
# Starting episode 47/500
# Episode 47, epoch [1/15], loss: 0.9067999005317688
# Episode 47, epoch [2/15], loss: 0.9058954497178395
# Episode 47, epoch [3/15], loss: 0.9056054472923278
# Episode 47, epoch [4/15], loss: 0.905701321363449
# Episode 47, epoch [5/15], loss: 0.9052993218104045
# Episode 47, epoch [6/15], loss: 0.9051261524359385
# Episode 47, epoch [7/15], loss: 0.904523762067159
# Episode 47, epoch [8/15], loss: 0.9046914954980214
# Episode 47, epoch [9/15], loss: 0.9044053276379903
# Episode 47, epoch [10/15], loss: 0.904338292280833
# Episode 47, epoch [11/15], loss: 0.9039202590783437
# Episode 47, epoch [12/15], loss: 0.9039773146311442
# Episode 47, epoch [13/15], loss: 0.903867530822754
# Episode 47, epoch [14/15], loss: 0.9039966702461243
# Episode 47, epoch [15/15], loss: 0.9047394394874573
# Episode 47 completed in 7.59 seconds
# Starting episode 48/500
# Episode 48, epoch [1/15], loss: 165144760606.38684
# Episode 48, epoch [2/15], loss: 165144760605.27374
# Episode 48, epoch [3/15], loss: 165144760604.3289
# Episode 48, epoch [4/15], loss: 165144760606.3836
# Episode 48, epoch [5/15], loss: 165144760606.7016
# Episode 48, epoch [6/15], loss: 165144760606.67728
# Episode 48, epoch [7/15], loss: 165144760605.4639
# Episode 48, epoch [8/15], loss: 165144760605.79626
# Episode 48, epoch [9/15], loss: 165144760606.3656
# Episode 48, epoch [10/15], loss: 165144760606.15762
# Episode 48, epoch [11/15], loss: 165144760606.36588
# Episode 48, epoch [12/15], loss: 165144760604.3138
# Episode 48, epoch [13/15], loss: 165144760606.03067
# Episode 48, epoch [14/15], loss: 165144760606.2746
# Episode 48, epoch [15/15], loss: 165144760605.89807
# Episode 48 completed in 7.55 seconds
# Starting episode 49/500
# Episode 49, epoch [1/15], loss: 0.9263486564159393
# Episode 49, epoch [2/15], loss: 0.9252438465754191
# Episode 49, epoch [3/15], loss: 0.9251898487408956
# Episode 49, epoch [4/15], loss: 0.9247586051623027
# Episode 49, epoch [5/15], loss: 0.9248535752296447
# Episode 49, epoch [6/15], loss: 0.9240815242131551
# Episode 49, epoch [7/15], loss: 0.9246896127859752
# Episode 49, epoch [8/15], loss: 0.9246830940246582
# Episode 49, epoch [9/15], loss: 0.9242673138777415
# Episode 49, epoch [10/15], loss: 0.9239829460779826
# Episode 49, epoch [11/15], loss: 0.9239097634951273
# Episode 49, epoch [12/15], loss: 0.9240229805310567
# Episode 49, epoch [13/15], loss: 0.9237217883268992
# Episode 49, epoch [14/15], loss: 0.9236335118611654
# Episode 49, epoch [15/15], loss: 0.9238544762134552
# Episode 49 completed in 7.62 seconds
# Starting episode 50/500
# Episode 50, epoch [1/15], loss: 0.6454865455627441
# Episode 50, epoch [2/15], loss: 0.6442738056182862
# Episode 50, epoch [3/15], loss: 0.6432369470596313
# Episode 50, epoch [4/15], loss: 0.6429816802342733
# Episode 50, epoch [5/15], loss: 0.6420694013436635
# Episode 50, epoch [6/15], loss: 0.6421126286188762
# Episode 50, epoch [7/15], loss: 0.641598371664683
# Episode 50, epoch [8/15], loss: 0.6414701461791992
# Episode 50, epoch [9/15], loss: 0.6414568503697713
# Episode 50, epoch [10/15], loss: 0.6410547355810802
# Episode 50, epoch [11/15], loss: 0.6412820776303609
# Episode 50, epoch [12/15], loss: 0.6408652504285176
# Episode 50, epoch [13/15], loss: 0.6410439133644104
# Episode 50, epoch [14/15], loss: 0.6407389362653096
# Episode 50, epoch [15/15], loss: 0.6406355063120525
# Episode 50 completed in 7.63 seconds
# Saved hidden representations for episode 50
# Starting episode 51/500
# Episode 51, epoch [1/15], loss: 0.8036429941654205
# Episode 51, epoch [2/15], loss: 0.8023323436578115
# Episode 51, epoch [3/15], loss: 0.8014909148216247
# Episode 51, epoch [4/15], loss: 0.8014914870262146
# Episode 51, epoch [5/15], loss: 0.801660950978597
# Episode 51, epoch [6/15], loss: 0.8009702901045481
# Episode 51, epoch [7/15], loss: 0.8006771723429362
# Episode 51, epoch [8/15], loss: 0.800293105840683
# Episode 51, epoch [9/15], loss: 0.8003446996212006
# Episode 51, epoch [10/15], loss: 0.8004173000653585
# Episode 51, epoch [11/15], loss: 0.8006022969881693
# Episode 51, epoch [12/15], loss: 0.8001487056414286
# Episode 51, epoch [13/15], loss: 0.8003375768661499
# Episode 51, epoch [14/15], loss: 0.7998330414295196
# Episode 51, epoch [15/15], loss: 0.7997078160444896
# Episode 51 completed in 7.44 seconds
# Starting episode 52/500
# Episode 52, epoch [1/15], loss: 0.845662126938502
# Episode 52, epoch [2/15], loss: 0.8451997756958007
# Episode 52, epoch [3/15], loss: 0.8444579799969991
# Episode 52, epoch [4/15], loss: 0.8441027065118154
# Episode 52, epoch [5/15], loss: 0.8441143989562988
# Episode 52, epoch [6/15], loss: 0.8437503755092621
# Episode 52, epoch [7/15], loss: 0.8441723863283793
# Episode 52, epoch [8/15], loss: 0.8436637143294017
# Episode 52, epoch [9/15], loss: 0.8440874954064687
# Episode 52, epoch [10/15], loss: 0.8436668336391449
# Episode 52, epoch [11/15], loss: 0.843196181456248
# Episode 52, epoch [12/15], loss: 0.8431991835435232
# Episode 52, epoch [13/15], loss: 0.8432745218276978
# Episode 52, epoch [14/15], loss: 0.8431335051854452
# Episode 52, epoch [15/15], loss: 0.8428841392199199
# Episode 52 completed in 7.51 seconds
# Starting episode 53/500
# Episode 53, epoch [1/15], loss: 0.38280250628789264
# Episode 53, epoch [2/15], loss: 0.3814364512761434
# Episode 53, epoch [3/15], loss: 0.3808203488588333
# Episode 53, epoch [4/15], loss: 0.38050809303919475
# Episode 53, epoch [5/15], loss: 0.38029144207636517
# Episode 53, epoch [6/15], loss: 0.38036539355913795
# Episode 53, epoch [7/15], loss: 0.3799885302782059
# Episode 53, epoch [8/15], loss: 0.3802285581827164
# Episode 53, epoch [9/15], loss: 0.3797771523396174
# Episode 53, epoch [10/15], loss: 0.37974247535069783
# Episode 53, epoch [11/15], loss: 0.3797517736752828
# Episode 53, epoch [12/15], loss: 0.379353999098142
# Episode 53, epoch [13/15], loss: 0.37933905323346456
# Episode 53, epoch [14/15], loss: 0.37920150756835935
# Episode 53, epoch [15/15], loss: 0.37927859723567964
# Episode 53 completed in 7.43 seconds
# Starting episode 54/500
# Episode 54, epoch [1/15], loss: 1.464695922533671
# Episode 54, epoch [2/15], loss: 1.4638884703318278
# Episode 54, epoch [3/15], loss: 1.4628963152567545
# Episode 54, epoch [4/15], loss: 1.4620524128278096
# Episode 54, epoch [5/15], loss: 1.4622222622235617
# Episode 54, epoch [6/15], loss: 1.462257726987203
# Episode 54, epoch [7/15], loss: 1.4617389758427939
# Episode 54, epoch [8/15], loss: 1.4615274786949157
# Episode 54, epoch [9/15], loss: 1.4614846507708232
# Episode 54, epoch [10/15], loss: 1.4610879023869832
# Episode 54, epoch [11/15], loss: 1.4608122984568277
# Episode 54, epoch [12/15], loss: 1.4608444372812908
# Episode 54, epoch [13/15], loss: 1.4616560618082681
# Episode 54, epoch [14/15], loss: 1.4610694964726767
# Episode 54, epoch [15/15], loss: 1.460831844806671
# Episode 54 completed in 7.48 seconds
# Starting episode 55/500
# Episode 55, epoch [1/15], loss: 21941340864512.0
# Episode 55, epoch [2/15], loss: 21941340619844.266
# Episode 55, epoch [3/15], loss: 21941340602368.0
# Episode 55, epoch [4/15], loss: 21941340689749.332
# Episode 55, epoch [5/15], loss: 21941340438528.0
# Episode 55, epoch [6/15], loss: 21941341843182.934
# Episode 55, epoch [7/15], loss: 21941340890726.4
# Episode 55, epoch [8/15], loss: 21941340986845.867
# Episode 55, epoch [9/15], loss: 21941340193860.266
# Episode 55, epoch [10/15], loss: 21941341511134.633
# Episode 55, epoch [11/15], loss: 21941339606223.742
# Episode 55, epoch [12/15], loss: 21941341126656.0
# Episode 55, epoch [13/15], loss: 21941340864514.05
# Episode 55, epoch [14/15], loss: 21941341170346.668
# Episode 55, epoch [15/15], loss: 21941341340740.266
# Episode 55 completed in 7.42 seconds
# Starting episode 56/500
# Episode 56, epoch [1/15], loss: 2.496822381019592
# Episode 56, epoch [2/15], loss: 2.4959410548210146
# Episode 56, epoch [3/15], loss: 2.494843033949534
# Episode 56, epoch [4/15], loss: 2.493668274084727
# Episode 56, epoch [5/15], loss: 2.4931705156962076
# Episode 56, epoch [6/15], loss: 2.493014069398244
# Episode 56, epoch [7/15], loss: 2.4927921136220297
# Episode 56, epoch [8/15], loss: 2.4935736934343975
# Episode 56, epoch [9/15], loss: 2.4932864824930827
# Episode 56, epoch [10/15], loss: 2.492370100816091
# Episode 56, epoch [11/15], loss: 2.4915701349576316
# Episode 56, epoch [12/15], loss: 2.4913607875506085
# Episode 56, epoch [13/15], loss: 2.4926167607307432
# Episode 56, epoch [14/15], loss: 2.4918945391972858
# Episode 56, epoch [15/15], loss: 2.492168303330739
# Episode 56 completed in 7.53 seconds
# Starting episode 57/500
# Episode 57, epoch [1/15], loss: 849594776510.0966
# Episode 57, epoch [2/15], loss: 849594782244.259
# Episode 57, epoch [3/15], loss: 849594819655.7231
# Episode 57, epoch [4/15], loss: 849594747290.3848
# Episode 57, epoch [5/15], loss: 849594789616.1842
# Episode 57, epoch [6/15], loss: 849594737734.8107
# Episode 57, epoch [7/15], loss: 849594798354.7291
# Episode 57, epoch [8/15], loss: 849594807640.7733
# Episode 57, epoch [9/15], loss: 849594780878.6523
# Episode 57, epoch [10/15], loss: 849594803815.5217
# Episode 57, epoch [11/15], loss: 849594813647.8035
# Episode 57, epoch [12/15], loss: 849594784700.5023
# Episode 57, epoch [13/15], loss: 849594775006.6538
# Episode 57, epoch [14/15], loss: 849594772142.2635
# Episode 57, epoch [15/15], loss: 849594793986.4026
# Episode 57 completed in 7.44 seconds
# Starting episode 58/500
# Episode 58, epoch [1/15], loss: 239290443094.41928
# Episode 58, epoch [2/15], loss: 239290441183.02728
# Episode 58, epoch [3/15], loss: 239290447736.6345
# Episode 58, epoch [4/15], loss: 239290443094.62656
# Episode 58, epoch [5/15], loss: 239290443367.62457
# Episode 58, epoch [6/15], loss: 239290445278.99963
# ...
# Episode 482, epoch [3/15], loss: 0.7317048370838165
# Episode 482, epoch [4/15], loss: 0.7317852755387624
# Episode 482, epoch [5/15], loss: 0.7318228085835775
# Episode 482, epoch [6/15], loss: 0.7316407481829326
# Episode 482, epoch [7/15], loss: 0.7318371375401814
# Episode 482, epoch [8/15], loss: 0.7313381234804789
# Episode 482, epoch [9/15], loss: 0.7311129927635193
# Episode 482, epoch [10/15], loss: 0.7307874004046122
# Episode 482, epoch [11/15], loss: 0.730780565738678
# Episode 482, epoch [12/15], loss: 0.7305840452512106
# Episode 482, epoch [13/15], loss: 0.7302051862080892
# Episode 482, epoch [14/15], loss: 0.7303833544254303
# Episode 482, epoch [15/15], loss: 0.7304224729537964
# Episode 482 completed in 6.84 seconds
# Starting episode 483/500
# Episode 483, epoch [1/15], loss: 950098876.3100877
# Episode 483, epoch [2/15], loss: 950098876.3103468
# Episode 483, epoch [3/15], loss: 950098876.324597
# Episode 483, epoch [4/15], loss: 950098876.2825685
# Episode 483, epoch [5/15], loss: 950098876.3152286
# Episode 483, epoch [6/15], loss: 950098876.3141044
# Episode 483, epoch [7/15], loss: 950098876.2927382
# Episode 483, epoch [8/15], loss: 950098876.2975897
# Episode 483, epoch [9/15], loss: 950098876.309954
# Episode 483, epoch [10/15], loss: 950098876.3140978
# Episode 483, epoch [11/15], loss: 950098876.3030668
# Episode 483, epoch [12/15], loss: 950098876.2989634
# Episode 483, epoch [13/15], loss: 950098876.2916977
# Episode 483, epoch [14/15], loss: 950098876.3143789
# Episode 483, epoch [15/15], loss: 950098876.3128622
# Episode 483 completed in 6.96 seconds
# Starting episode 484/500
# Episode 484, epoch [1/15], loss: 1.630140240987142
# Episode 484, epoch [2/15], loss: 1.6295686960220337
# Episode 484, epoch [3/15], loss: 1.6292775948842366
# Episode 484, epoch [4/15], loss: 1.6291885177294414
# Episode 484, epoch [5/15], loss: 1.6306681553522746
# Episode 484, epoch [6/15], loss: 1.6297746499379475
# Episode 484, epoch [7/15], loss: 1.6299622853597004
# Episode 484, epoch [8/15], loss: 1.6291466077168784
# Episode 484, epoch [9/15], loss: 1.6286212484041849
# Episode 484, epoch [10/15], loss: 1.628554097811381
# Episode 484, epoch [11/15], loss: 1.628775413831075
# Episode 484, epoch [12/15], loss: 1.6299262404441834
# Episode 484, epoch [13/15], loss: 1.6295304417610168
# Episode 484, epoch [14/15], loss: 1.628811740875244
# Episode 484, epoch [15/15], loss: 1.6292977372805277
# Episode 484 completed in 7.11 seconds
# Starting episode 485/500
# Episode 485, epoch [1/15], loss: 0.6176014026006063
# Episode 485, epoch [2/15], loss: 0.6172499358654022
# Episode 485, epoch [3/15], loss: 0.616690210501353
# Episode 485, epoch [4/15], loss: 0.6164711773395538
# Episode 485, epoch [5/15], loss: 0.6163987815380096
# Episode 485, epoch [6/15], loss: 0.6164419909318288
# Episode 485, epoch [7/15], loss: 0.6163110752900441
# Episode 485, epoch [8/15], loss: 0.6164341410001118
# Episode 485, epoch [9/15], loss: 0.616113930940628
# Episode 485, epoch [10/15], loss: 0.6158749222755432
# Episode 485, epoch [11/15], loss: 0.6159717361132304
# Episode 485, epoch [12/15], loss: 0.615930833419164
# Episode 485, epoch [13/15], loss: 0.615948098897934
# Episode 485, epoch [14/15], loss: 0.6160531997680664
# Episode 485, epoch [15/15], loss: 0.6159624556700388
# Episode 485 completed in 7.02 seconds
# Starting episode 486/500
# Episode 486, epoch [1/15], loss: 1317113502106.3975
# Episode 486, epoch [2/15], loss: 1317113515213.6794
# Episode 486, epoch [3/15], loss: 1317113497737.3293
# Episode 486, epoch [4/15], loss: 1317113537059.068
# Episode 486, epoch [5/15], loss: 1317113510844.5369
# Episode 486, epoch [6/15], loss: 1317113508660.1885
# Episode 486, epoch [7/15], loss: 1317113510844.5427
# Episode 486, epoch [8/15], loss: 1317113523951.7979
# Episode 486, epoch [9/15], loss: 1317113495552.9468
# Episode 486, epoch [10/15], loss: 1317113495552.9756
# Episode 486, epoch [11/15], loss: 1317113545797.1975
# Episode 486, epoch [12/15], loss: 1317113558904.0745
# Episode 486, epoch [13/15], loss: 1317113528320.8342
# Episode 486, epoch [14/15], loss: 1317113532689.804
# Episode 486, epoch [15/15], loss: 1317113532689.867
# Episode 486 completed in 6.93 seconds
# Starting episode 487/500
# Episode 487, epoch [1/15], loss: 0.9206668535868326
# Episode 487, epoch [2/15], loss: 0.9198576370875041
# Episode 487, epoch [3/15], loss: 0.9194728116194407
# Episode 487, epoch [4/15], loss: 0.9197394371032714
# Episode 487, epoch [5/15], loss: 0.9189434130986531
# Episode 487, epoch [6/15], loss: 0.9192686041196187
# Episode 487, epoch [7/15], loss: 0.9196832100550334
# Episode 487, epoch [8/15], loss: 0.9191282629966736
# Episode 487, epoch [9/15], loss: 0.9189149578412373
# Episode 487, epoch [10/15], loss: 0.9190694789091746
# Episode 487, epoch [11/15], loss: 0.918251383304596
# Episode 487, epoch [12/15], loss: 0.9182559529940287
# Episode 487, epoch [13/15], loss: 0.9178732613722483
# Episode 487, epoch [14/15], loss: 0.9183205366134644
# Episode 487, epoch [15/15], loss: 0.9187859912713369
# Episode 487 completed in 6.84 seconds
# Starting episode 488/500
# Episode 488, epoch [1/15], loss: 2490808867.2849655
# Episode 488, epoch [2/15], loss: 2490808867.2645755
# Episode 488, epoch [3/15], loss: 2490808867.2881494
# Episode 488, epoch [4/15], loss: 2490808867.2354093
# Episode 488, epoch [5/15], loss: 2490808867.2756863
# Episode 488, epoch [6/15], loss: 2490808867.230731
# Episode 488, epoch [7/15], loss: 2490808867.016315
# Episode 488, epoch [8/15], loss: 2490808867.0799193
# Episode 488, epoch [9/15], loss: 2490808867.036461
# Episode 488, epoch [10/15], loss: 2490808867.2432504
# Episode 488, epoch [11/15], loss: 2490808867.2789717
# Episode 488, epoch [12/15], loss: 2490808867.2392354
# Episode 488, epoch [13/15], loss: 2490808867.285798
# Episode 488, epoch [14/15], loss: 2490808867.2734547
# Episode 488, epoch [15/15], loss: 2490808867.306953
# Episode 488 completed in 6.88 seconds
# Starting episode 489/500
# Episode 489, epoch [1/15], loss: 1.959909721215566
# Episode 489, epoch [2/15], loss: 1.9602089524269104
# Episode 489, epoch [3/15], loss: 1.9596866250038147
# Episode 489, epoch [4/15], loss: 1.959707013765971
# Episode 489, epoch [5/15], loss: 1.9599108695983887
# Episode 489, epoch [6/15], loss: 1.9601871172587078
# Episode 489, epoch [7/15], loss: 1.9605885903040567
# Episode 489, epoch [8/15], loss: 1.960944139957428
# Episode 489, epoch [9/15], loss: 1.9595322966575623
# Episode 489, epoch [10/15], loss: 1.9586955547332763
# Episode 489, epoch [11/15], loss: 1.9597860415776571
# Episode 489, epoch [12/15], loss: 1.958837107817332
# Episode 489, epoch [13/15], loss: 1.9584269404411316
# Episode 489, epoch [14/15], loss: 1.9593630989392599
# Episode 489, epoch [15/15], loss: 1.9597246865431468
# Episode 489 completed in 6.88 seconds
# Starting episode 490/500
# Episode 490, epoch [1/15], loss: 1.0110276242097218
# Episode 490, epoch [2/15], loss: 1.009546120961507
# Episode 490, epoch [3/15], loss: 1.008657189210256
# Episode 490, epoch [4/15], loss: 1.0088497122128806
# Episode 490, epoch [5/15], loss: 1.009508736928304
# Episode 490, epoch [6/15], loss: 1.0093865791956584
# Episode 490, epoch [7/15], loss: 1.008569218715032
# Episode 490, epoch [8/15], loss: 1.0088259855906168
# Episode 490, epoch [9/15], loss: 1.0081180334091187
# Episode 490, epoch [10/15], loss: 1.008771053949992
# Episode 490, epoch [11/15], loss: 1.0081993222236634
# Episode 490, epoch [12/15], loss: 1.0084335446357726
# Episode 490, epoch [13/15], loss: 1.0086385409037273
# Episode 490, epoch [14/15], loss: 1.0088307062784831
# Episode 490, epoch [15/15], loss: 1.0088827967643739
# Episode 490 completed in 6.94 seconds
# Saved hidden representations for episode 490
# Starting episode 491/500
# Episode 491, epoch [1/15], loss: 0.6661706944306691
# Episode 491, epoch [2/15], loss: 0.6657027800877889
# Episode 491, epoch [3/15], loss: 0.6654610574245453
# Episode 491, epoch [4/15], loss: 0.6651779929796855
# Episode 491, epoch [5/15], loss: 0.6652933279673259
# Episode 491, epoch [6/15], loss: 0.6651707132657368
# Episode 491, epoch [7/15], loss: 0.6655718723932902
# Episode 491, epoch [8/15], loss: 0.6649759948253632
# Episode 491, epoch [9/15], loss: 0.6645708898703258
# Episode 491, epoch [10/15], loss: 0.6644239862759908
# Episode 491, epoch [11/15], loss: 0.6646862804889679
# Episode 491, epoch [12/15], loss: 0.6652028640111287
# Episode 491, epoch [13/15], loss: 0.6652638137340545
# Episode 491, epoch [14/15], loss: 0.6648069858551026
# Episode 491, epoch [15/15], loss: 0.6645173311233521
# Episode 491 completed in 6.90 seconds
# Starting episode 492/500
# Episode 492, epoch [1/15], loss: 3.1176368951797486
# Episode 492, epoch [2/15], loss: 3.1169337113698323
# Episode 492, epoch [3/15], loss: 3.118338127930959
# Episode 492, epoch [4/15], loss: 3.1169658501942954
# Episode 492, epoch [5/15], loss: 3.1169570803642275
# Episode 492, epoch [6/15], loss: 3.1164568781852724
# Episode 492, epoch [7/15], loss: 3.116817768414815
# Episode 492, epoch [8/15], loss: 3.117873712380727
# Episode 492, epoch [9/15], loss: 3.1169344186782837
# Episode 492, epoch [10/15], loss: 3.1169771711031595
# Episode 492, epoch [11/15], loss: 3.1163133859634398
# Episode 492, epoch [12/15], loss: 3.115838805834452
# Episode 492, epoch [13/15], loss: 3.115799872080485
# Episode 492, epoch [14/15], loss: 3.115346602598826
# Episode 492, epoch [15/15], loss: 3.1152148326237996
# Episode 492 completed in 6.91 seconds
# Starting episode 493/500
# Episode 493, epoch [1/15], loss: 5266778.592588279
# Episode 493, epoch [2/15], loss: 5266778.5902459975
# Episode 493, epoch [3/15], loss: 5266778.5984582165
# Episode 493, epoch [4/15], loss: 5266778.591494745
# Episode 493, epoch [5/15], loss: 5266778.602135017
# Episode 493, epoch [6/15], loss: 5266778.593460087
# Episode 493, epoch [7/15], loss: 5266778.592245791
# Episode 493, epoch [8/15], loss: 5266778.599553238
# Episode 493, epoch [9/15], loss: 5266778.603654599
# Episode 493, epoch [10/15], loss: 5266778.585735836
# Episode 493, epoch [11/15], loss: 5266778.60614775
# Episode 493, epoch [12/15], loss: 5266778.600183045
# Episode 493, epoch [13/15], loss: 5266778.598081133
# Episode 493, epoch [14/15], loss: 5266778.6015160205
# Episode 493, epoch [15/15], loss: 5266778.602991788
# Episode 493 completed in 7.07 seconds
# Starting episode 494/500
# Episode 494, epoch [1/15], loss: 2.3178556124369303
# Episode 494, epoch [2/15], loss: 2.3187467098236083
# Episode 494, epoch [3/15], loss: 2.318212143580119
# Episode 494, epoch [4/15], loss: 2.3175799369812013
# Episode 494, epoch [5/15], loss: 2.3180688858032226
# Episode 494, epoch [6/15], loss: 2.3193902532259623
# Episode 494, epoch [7/15], loss: 2.317586088180542
# Episode 494, epoch [8/15], loss: 2.3184954643249513
# Episode 494, epoch [9/15], loss: 2.317226405938466
# Episode 494, epoch [10/15], loss: 2.3174015641212464
# Episode 494, epoch [11/15], loss: 2.317316269874573
# Episode 494, epoch [12/15], loss: 2.317623547712962
# Episode 494, epoch [13/15], loss: 2.3176254789034525
# Episode 494, epoch [14/15], loss: 2.317860281467438
# Episode 494, epoch [15/15], loss: 2.3178712805112203
# Episode 494 completed in 6.94 seconds
# Starting episode 495/500
# Episode 495, epoch [1/15], loss: 0.7834938168525696
# Episode 495, epoch [2/15], loss: 0.7827857156594594
# Episode 495, epoch [3/15], loss: 0.7824641585350036
# Episode 495, epoch [4/15], loss: 0.7820585648218791
# Episode 495, epoch [5/15], loss: 0.7816736658414205
# Episode 495, epoch [6/15], loss: 0.7820953249931335
# Episode 495, epoch [7/15], loss: 0.7818045059839884
# Episode 495, epoch [8/15], loss: 0.7810098648071289
# Episode 495, epoch [9/15], loss: 0.7814101099967956
# Episode 495, epoch [10/15], loss: 0.7817209819952647
# Episode 495, epoch [11/15], loss: 0.7815898815790813
# Episode 495, epoch [12/15], loss: 0.7812173287073771
# Episode 495, epoch [13/15], loss: 0.7811233083407084
# Episode 495, epoch [14/15], loss: 0.7814255654811859
# Episode 495, epoch [15/15], loss: 0.7811302383740742
# Episode 495 completed in 6.99 seconds
# Starting episode 496/500
# Episode 496, epoch [1/15], loss: 992807145747.9883
# Episode 496, epoch [2/15], loss: 992807145749.3027
# Episode 496, epoch [3/15], loss: 992807133187.4308
# Episode 496, epoch [4/15], loss: 992807134825.8748
# Episode 496, epoch [5/15], loss: 992807142471.951
# Episode 496, epoch [6/15], loss: 992807161586.5023
# Episode 496, epoch [7/15], loss: 992807147387.0978
# Episode 496, epoch [8/15], loss: 992807127179.2598
# Episode 496, epoch [9/15], loss: 992807128545.5797
# Episode 496, epoch [10/15], loss: 992807114072.721
# Episode 496, epoch [11/15], loss: 992807136190.2358
# Episode 496, epoch [12/15], loss: 992807132096.8602
# Episode 496, epoch [13/15], loss: 992807138102.9684
# Episode 496, epoch [14/15], loss: 992807137284.1962
# Episode 496, epoch [15/15], loss: 992807115166.1263
# Episode 496 completed in 7.02 seconds
# Starting episode 497/500
# Episode 497, epoch [1/15], loss: 96005646442.3326
# Episode 497, epoch [2/15], loss: 96005646442.3857
# Episode 497, epoch [3/15], loss: 96005646442.30156
# Episode 497, epoch [4/15], loss: 96005646442.27727
# Episode 497, epoch [5/15], loss: 96005646442.25278
# Episode 497, epoch [6/15], loss: 96005646442.36739
# Episode 497, epoch [7/15], loss: 96005646442.47014
# Episode 497, epoch [8/15], loss: 96005646442.46658
# Episode 497, epoch [9/15], loss: 96005646442.24452
# Episode 497, epoch [10/15], loss: 96005646442.13594
# Episode 497, epoch [11/15], loss: 96005646442.50276
# Episode 497, epoch [12/15], loss: 96005646442.27367
# Episode 497, epoch [13/15], loss: 96005646442.21255
# Episode 497, epoch [14/15], loss: 96005646442.3835
# Episode 497, epoch [15/15], loss: 96005646442.52328
# Episode 497 completed in 6.85 seconds
# Starting episode 498/500
# Episode 498, epoch [1/15], loss: 6267308715.586247
# Episode 498, epoch [2/15], loss: 6267308715.573269
# Episode 498, epoch [3/15], loss: 6267308715.495409
# Episode 498, epoch [4/15], loss: 6267308715.570988
# Episode 498, epoch [5/15], loss: 6267308715.345623
# Episode 498, epoch [6/15], loss: 6267308715.488
# Episode 498, epoch [7/15], loss: 6267308715.553142
# Episode 498, epoch [8/15], loss: 6267308715.575982
# Episode 498, epoch [9/15], loss: 6267308715.584139
# Episode 498, epoch [10/15], loss: 6267308715.586316
# Episode 498, epoch [11/15], loss: 6267308715.574743
# Episode 498, epoch [12/15], loss: 6267308715.362391
# Episode 498, epoch [13/15], loss: 6267308715.5762
# Episode 498, epoch [14/15], loss: 6267308715.577658
# Episode 498, epoch [15/15], loss: 6267308715.59604
# Episode 498 completed in 6.94 seconds
# Starting episode 499/500
# Episode 499, epoch [1/15], loss: 0.7394799669583638
# Episode 499, epoch [2/15], loss: 0.7384397506713867
# Episode 499, epoch [3/15], loss: 0.7385480980078379
# Episode 499, epoch [4/15], loss: 0.7384363929430644
# Episode 499, epoch [5/15], loss: 0.7388225396474203
# Episode 499, epoch [6/15], loss: 0.7381701052188874
# Episode 499, epoch [7/15], loss: 0.7378119965394337
# Episode 499, epoch [8/15], loss: 0.7379455049832662
# Episode 499, epoch [9/15], loss: 0.7387831846872965
# Episode 499, epoch [10/15], loss: 0.73882381717364
# Episode 499, epoch [11/15], loss: 0.7384250064690908
# Episode 499, epoch [12/15], loss: 0.7385375499725342
# Episode 499, epoch [13/15], loss: 0.7383470873037974
# Episode 499, epoch [14/15], loss: 0.73809441725413
# Episode 499, epoch [15/15], loss: 0.7376980721950531
# Episode 499 completed in 7.00 seconds
# Starting episode 500/500
# Episode 500, epoch [1/15], loss: 557393511.8474166
# Episode 500, epoch [2/15], loss: 557393512.0840439
# Episode 500, epoch [3/15], loss: 557393512.0476354
# Episode 500, epoch [4/15], loss: 557393511.9908926
# Episode 500, epoch [5/15], loss: 557393511.8963083
# Episode 500, epoch [6/15], loss: 557393511.760356
# Episode 500, epoch [7/15], loss: 557393512.0766408
# Episode 500, epoch [8/15], loss: 557393512.0434836
# Episode 500, epoch [9/15], loss: 557393512.0366131
# Episode 500, epoch [10/15], loss: 557393512.114472
# Episode 500, epoch [11/15], loss: 557393512.0031964
# Episode 500, epoch [12/15], loss: 557393511.9849794
# Episode 500, epoch [13/15], loss: 557393546.1967875
# Episode 500, epoch [14/15], loss: 557393512.0694308
# Episode 500, epoch [15/15], loss: 557393512.0751536
# Episode 500 completed in 7.07 seconds
# Saved hidden representations for episode 500
# Training finished!

# %%
write1 = "/Users/maks/Documents/MSc_project/data/models/convolutional_ae_long_test.pth"

torch.save(model.state_dict(), write1)
print(f"Model saved to {write1}")
# Out:
# Model saved to /Users/maks/Documents/MSc_project/data/models/convolutional_ae_long_test.pth

# %%
variable_names = ["Velocity x", "Velocity y", "Velocity z", "Tortuosity 3d", "Angular Velocity yz", "Angular Velocity xz", "Angular Velocity xy"]

#Visualising reconstructed data
def plot_reconstruction(original, reconstructed, n = 5):
    
    plt.figure(figsize = (15, 10))

    for i in range(n):
        for j in range(7):
            ax = plt.subplot(n, 7, i * 7 + j + 1)
            plt.plot(original[i][:, j].numpy(), label = "Original")
            plt.plot(reconstructed[i][:, j].detach().numpy(), label = "Reconstructed")
            
            if j == 0:
                ax.set_ylabel(f"Sample {i + 1}")
            if i == 0:
                ax.set_title(variable_names[j])
            if i == n - 1 and j == 2:
                ax.legend()

    plt.subplots_adjust(wspace=0.35, hspace=0.35)
    
    plt.show()

# %%
test_data = next(iter(dataloader))
reconstructed_data = model(test_data)

plot_reconstruction(test_data, reconstructed_data)
