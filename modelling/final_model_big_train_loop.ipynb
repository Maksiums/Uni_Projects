# %% [markdown]
# Training loop for the final version of the model. At first defines the sampling function, then the dataloader, finally the model itself. Then the training loop is set up. The cells following save the model and visualise comparisons of reconstructions and original data.
#
# In the training loop, the terms *episode* and *epoch* were used opposite the usual convention. In this notebook, a training epoch consists of multiple episodes. Instead of the other way around.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import time
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset

# %%
def generate_random_samples(batch, read = "/Users/maks/Documents/MSc_project/data/features", sequence_length = 60):
    """
    A function that creates a list of independent arrays that are to serve as samples for processing later.
    read is the directory where Excel files containing variables are stored;
    batch is the number of samples that will be generated;
    sequence length is the length of each sample.
    Returns a list of numpy arrays.
    """

    def load_excel(file_path):
        """
        Extracts sheets from Excel files given a file directory.
        """
        excel_file = pd.ExcelFile(file_path)
        
        sheets = {sheet_name: pd.read_excel(excel_file, sheet_name = sheet_name, engine = "openpyxl") for sheet_name in excel_file.sheet_names}

        return sheets
    
    def random_file(read):
        """
        Chooses a random file from a provided directory.
        """
        files = [f for f in os.listdir(read) if f.endswith(".xlsx") and not f.startswith(".")]
        
        if not files:
            raise FileNotFoundError("No Excel files found in the directory")
        
        return os.path.join(read, random.choice(files))
    
    def normalise_columns(df, columns):
        """
        Normalises specified columns between -1 and 1.
        """
        df = df.copy()  #Makes a copy to avoid modifying the original DataFrame
    
        for column in columns:
            max_val = df[column].max()
            min_val = df[column].min()
            
            df.loc[:, column] = 2 * (df[column] - min_val) / (max_val - min_val) - 1

        return df

    def sampler(sheet_data, sequence_length):
        """
        Randomly creates a sample from an Excel sheet.
        sheet_data are sheets representing time series segments from where data is going to be sampled
        sequence_length is the number of points each sample will contain.
        """

        #Normalises velocities and angular velocities using normalise_columns
        columns = ["velocity_x", "velocity_y", "velocity_z", "angular_velocity_yz", "angular_velocity_xz", "angular_velocity_xy"]
        sheet_data = normalise_columns(sheet_data, columns)

        num_points = len(sheet_data)

        if num_points < sequence_length + 2:
            return None
        
        start_index = random.randint(2, num_points - sequence_length)
        end_index = start_index + sequence_length
        sample = sheet_data.iloc[start_index : end_index].to_numpy()

        return sample #Transposes the samle to switch rows and columns
    
    def weighted_random_choice(sheets):
        """
        Assigns weights to sheets based on the length of each sheet.
        """
        total_points = sum(len(data) for data in sheets.values())
        weights = [len(data) / total_points for data in sheets.values()]

        return random.choices(list(sheets.keys()), weights = weights, k = 1)[0]
    
    #Initializes list to strore sample arrays
    samples = []

    while len(samples) < batch:
        file_path = random_file(read)
        sheets = load_excel(file_path)

        while len(samples) < batch:
            sheet_name = weighted_random_choice(sheets)
            sheet_data = sheets[sheet_name][["velocity_x", "velocity_y", "velocity_z", "tortuosity3d", "angular_velocity_yz", "angular_velocity_xz", "angular_velocity_xy"]]
            sample = sampler(sheet_data, sequence_length)

            if sample is not None:
                samples.append(sample)

            #Stops once batch size is reached
            if len(samples) >= batch:
                break

    return samples

# %%
#Class to contain our sampled time series data
class TimeSeriesData(Dataset):
    def __init__(self, no_samples):
        self.data = generate_random_samples(no_samples)
        self.data = np.array(self.data)

        self.data = torch.tensor(self.data, dtype = torch.float32)
    
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, i):
        return self.data[i]

# %%
class BranchingAE(nn.Module):
    def __init__(self):
        super(BranchingAE, self).__init__()

        #Branch for velocities (first 3 features)
        self.velocity_branch = nn.Sequential(
            nn.Conv1d(in_channels = 3, out_channels = 32, kernel_size = 3, stride = 1, padding = 1),
            nn.ELU(),
            nn.MaxPool1d(kernel_size = 2, stride = 2),

            nn.Conv1d(in_channels = 32, out_channels = 64, kernel_size = 3, stride = 1, padding = 1),
            nn.ELU(),
            nn.MaxPool1d(kernel_size = 2, stride = 2)
        )

        #Branch for tortuosity (4th feature)
        self.tortuosity_branch = nn.Sequential(
            nn.Conv1d(in_channels = 1, out_channels = 32, kernel_size = 3, stride = 1, padding = 1),
            nn.ELU(),
            nn.MaxPool1d(kernel_size = 2, stride = 2),

            nn.Conv1d(in_channels = 32, out_channels = 64, kernel_size = 3, stride = 1, padding = 1),
            nn.ELU(),
            nn.MaxPool1d(kernel_size = 2, stride = 2)
        )

        #Branch for angular velocities (last 3 features (out of 7))
        self.ang_velocity_branch = nn.Sequential(
            nn.Conv1d(in_channels = 3, out_channels = 32, kernel_size = 3, stride = 1, padding = 1),
            nn.ELU(),
            nn.MaxPool1d(kernel_size = 2, stride = 2),

            nn.Conv1d(in_channels = 32, out_channels = 64, kernel_size = 3, stride = 1, padding = 1),
            nn.ELU(),
            nn.MaxPool1d(kernel_size = 2, stride = 2)
        )

        #Shared decoder for merging the features
        self.decoder = nn.Sequential(
            nn.ConvTranspose1d(in_channels = 192, out_channels = 128, kernel_size = 2, stride = 2),
            nn.ELU(),

            nn.ConvTranspose1d(in_channels = 128, out_channels = 64, kernel_size = 2, stride = 2),
            nn.ELU(),

            nn.ConvTranspose1d(in_channels = 64, out_channels = 32, kernel_size = 3, stride = 1, padding = 1),
            nn.ELU()
        )

        #Output layers for different variables
        self.output_velocity = nn.Sequential(
            nn.Conv1d(in_channels = 32, out_channels = 3, kernel_size = 3, stride = 1, padding = 1),
            nn.Tanh()
        )

        self.output_tortuosity = nn.Sequential(
            nn.Conv1d(in_channels = 32, out_channels = 1, kernel_size = 3, stride = 1, padding = 1)
        )

        self.output_ang_velocity = nn.Sequential(
            nn.Conv1d(in_channels = 32, out_channels = 3, kernel_size = 3, stride = 1, padding = 1),
            nn.Tanh()
        )

    def forward(self, x):

        #print("Input shape:", x.shape)

        velocity = x[:, :, :3]
        tortuosity = x[:, :, 3:4]
        ang_velocity = x[:, :, 4:]

        #print("Velocity shape:", velocity.shape)
        #print("Tortuosity shape:", tortuosity.shape)
        #print("Angular velocity shape:", ang_velocity.shape)

        velocity = velocity.permute(0, 2, 1)
        tortuosity = tortuosity.permute(0, 2, 1)
        ang_velocity = ang_velocity.permute(0, 2, 1)

        #print("Permuted elocity shape:", velocity.shape)
        #print("permuted tortuosity shape:", tortuosity.shape)
        #print("Permuted angular velocity shape:", ang_velocity.shape)

        #Permutes to desired shape
        velocity_encoded = self.velocity_branch(velocity)
        tortuosity_encoded = self.tortuosity_branch(tortuosity)
        ang_velocity_encoded = self.ang_velocity_branch(ang_velocity)

        #print("Velocity encoded shape:", velocity_encoded.shape)
        #print("Tortuosity encoded shape:", tortuosity_encoded.shape)
        #print("Angular velocity encoded shape:", ang_velocity_encoded.shape)

        #Concatenates encoded features
        combined_encoded = torch.cat((velocity_encoded, tortuosity_encoded, ang_velocity_encoded), dim = 1)

        #print("Combined encoded shape:", combined_encoded.shape)

        #Decodes combined features
        decoded = self.decoder(combined_encoded)

        #print("Decoded shape:", decoded.shape)

        #Generates outputs for each set of variables
        velocity_output = self.output_velocity(decoded)
        tortuosity_output = self.output_tortuosity(decoded)
        ang_velocity_output = self.output_ang_velocity(decoded)

        #print("Velocity output shape:", velocity_output.shape)
        #print("Tortuosity output shape:", tortuosity_output.shape)
        #print("Angular velocity output shape:", ang_velocity_output.shape)  

        #Concatenates all outputs
        combined_output = torch.cat((velocity_output, tortuosity_output, ang_velocity_output), dim = 1)
        
        #print("Combined output shape:", combined_output.shape)

        #Permutes back
        output = combined_output.permute(0, 2, 1)
        
        #print("Final output shape:", output.shape)

        return output
    
    def encode(self, x):

        velocity = x[:, :, :3]
        tortuosity = x[:, :, 3:4]
        ang_velocity = x[:, :, 4:]

        velocity = velocity.permute(0, 2, 1)
        tortuosity = tortuosity.permute(0, 2, 1)
        ang_velocity = ang_velocity.permute(0, 2, 1)

        #Permutes to desired shape
        velocity_encoded = self.velocity_branch(velocity)
        tortuosity_encoded = self.tortuosity_branch(tortuosity)
        ang_velocity_encoded = self.ang_velocity_branch(ang_velocity)

        #Concatenates encoded features
        combined_encoded = torch.cat((velocity_encoded, tortuosity_encoded, ang_velocity_encoded), dim = 1)

        return combined_encoded

# %%
#Dataset and dataloader parameters
no_samples = 480
batch_size = 32

# %%
#Model, loss function and optimiser
model = BranchingAE()
criterion = nn.SmoothL1Loss()
optimiser = optim.AdamW(model.parameters(), lr = 0.00075)
max_gradient_norm = 0.66

# %%
#Training loop
no_episodes = 500
epochs = 15
#os.makedirs("/Users/maks/Documents/MSc_project/data/hidden_layer_representations/day_1", exist_ok = True)

for episode in range(no_episodes):
    print(f"Starting episode {episode + 1}/{no_episodes}")

    #Generates dataset
    dataset = TimeSeriesData(no_samples)
    dataloader = DataLoader(dataset, batch_size = batch_size, shuffle = True)

    #Records start time for an episode
    start_time = time.time()

    for epoch in range(epochs):
        epoch_loss = 0.0
        for batch_data in dataloader:
            #Forward pass
            output = model(batch_data)
            #if output is None:
                #print("Model output is None.")
            #else:
                #print("Model output shape:", output.shape)

            loss = criterion(output, batch_data)

            #Backward pass
            optimiser.zero_grad()
            loss.backward()

            #Gradient clipping
            nn.utils.clip_grad_norm_(model.parameters(), max_gradient_norm)

            #Optimisation step
            optimiser.step()

            epoch_loss += loss.item()

        average_epoch_loss = epoch_loss / len(dataloader)
        print(f"Episode {episode + 1 }, epoch [{epoch + 1}/{epochs}], loss: {average_epoch_loss}")

    #Records end time of the episode
    end_time = time.time()

    #Prints duration of the episode
    runtime = end_time - start_time
    print(f"Episode {episode + 1} completed in {runtime:.2f} seconds")

    #Saves hidden layer representation every 10 episodes
    if (episode + 1) % 10 == 0:
        hidden_representations = []
        for batch_data in dataloader:
            with torch.no_grad():
                hidden_repr = model.encode(batch_data)
                hidden_representations.append(hidden_repr.numpy())

        hidden_representations = np.concatenate(hidden_representations, axis = 0)
        np.save(f"/Users/maks/Documents/MSc_project/data/hidden_layer_representations/day_1/hidden_representations_episode_{episode + 1}.npy", hidden_representations)
        print(f"Saved hidden representations for episode {episode + 1}")

print("Training finished!")
# Out:
# Starting episode 1/500
# Episode 1, epoch [1/15], loss: 29113700948377.6
# Episode 1, epoch [2/15], loss: 25913653146419.2
# Episode 1, epoch [3/15], loss: 24457980691524.266
# Episode 1, epoch [4/15], loss: 23265166168338.56
# Episode 1, epoch [5/15], loss: 21872788242433.176
# Episode 1, epoch [6/15], loss: 20466168229614.934
# Episode 1, epoch [7/15], loss: 19700901643332.43
# Episode 1, epoch [8/15], loss: 18679843590417.066
# Episode 1, epoch [9/15], loss: 16563681842517.334
# Episode 1, epoch [10/15], loss: 14772045929949.867
# Episode 1, epoch [11/15], loss: 13448170901777.066
# Episode 1, epoch [12/15], loss: 12113830927837.867
# Episode 1, epoch [13/15], loss: 11885272846609.066
# Episode 1, epoch [14/15], loss: 10094863187968.496
# Episode 1, epoch [15/15], loss: 9521473209412.268
# Episode 1 completed in 17.98 seconds
# Starting episode 2/500
# Episode 2, epoch [1/15], loss: 0.41127437849839527
# Episode 2, epoch [2/15], loss: 0.29378070384263993
# Episode 2, epoch [3/15], loss: 0.26260624875624977
# Episode 2, epoch [4/15], loss: 0.2266314153869947
# Episode 2, epoch [5/15], loss: 0.21658842414617538
# Episode 2, epoch [6/15], loss: 0.20895303189754486
# Episode 2, epoch [7/15], loss: 0.19432276139656704
# Episode 2, epoch [8/15], loss: 0.18441229338447254
# Episode 2, epoch [9/15], loss: 0.16619760915637016
# Episode 2, epoch [10/15], loss: 0.1676628038287163
# Episode 2, epoch [11/15], loss: 0.1661343216896057
# Episode 2, epoch [12/15], loss: 0.15220952332019805
# Episode 2, epoch [13/15], loss: 0.14620798577864966
# Episode 2, epoch [14/15], loss: 0.14689833397666613
# Episode 2, epoch [15/15], loss: 0.1534233085811138
# Episode 2 completed in 17.49 seconds
# Starting episode 3/500
# Episode 3, epoch [1/15], loss: 0.08468615412712097
# Episode 3, epoch [2/15], loss: 0.0782717563211918
# Episode 3, epoch [3/15], loss: 0.07596150313814481
# Episode 3, epoch [4/15], loss: 0.07726178963979086
# Episode 3, epoch [5/15], loss: 0.07180204279720784
# Episode 3, epoch [6/15], loss: 0.0713189996778965
# Episode 3, epoch [7/15], loss: 0.07260760727028052
# Episode 3, epoch [8/15], loss: 0.06905724120636782
# Episode 3, epoch [9/15], loss: 0.07761509443322817
# Episode 3, epoch [10/15], loss: 0.061846144621570905
# Episode 3, epoch [11/15], loss: 0.06195211398104827
# Episode 3, epoch [12/15], loss: 0.06252157886823019
# Episode 3, epoch [13/15], loss: 0.05844809226691723
# Episode 3, epoch [14/15], loss: 0.06892098635435104
# Episode 3, epoch [15/15], loss: 0.06260911201437315
# Episode 3 completed in 17.44 seconds
# Starting episode 4/500
# Episode 4, epoch [1/15], loss: 31228812.86449641
# Episode 4, epoch [2/15], loss: 15802134.988818722
# Episode 4, epoch [3/15], loss: 20136052.32235219
# Episode 4, epoch [4/15], loss: 22942398.977234297
# Episode 4, epoch [5/15], loss: 16089612.31996164
# Episode 4, epoch [6/15], loss: 14106377.642263304
# Episode 4, epoch [7/15], loss: 12353249.661582883
# Episode 4, epoch [8/15], loss: 26280719.512067556
# Episode 4, epoch [9/15], loss: 16057994.180079376
# Episode 4, epoch [10/15], loss: 11107288.57950504
# Episode 4, epoch [11/15], loss: 9071698.440955292
# Episode 4, epoch [12/15], loss: 11038669.112084696
# Episode 4, epoch [13/15], loss: 9872616.57080193
# Episode 4, epoch [14/15], loss: 12615374.975399371
# Episode 4, epoch [15/15], loss: 6961258.164006228
# Episode 4 completed in 17.83 seconds
# Starting episode 5/500
# Episode 5, epoch [1/15], loss: 861328042.6984657
# Episode 5, epoch [2/15], loss: 876617523.2339063
# Episode 5, epoch [3/15], loss: 751920128.0302957
# Episode 5, epoch [4/15], loss: 653551138.1609548
# Episode 5, epoch [5/15], loss: 526217659.76223963
# Episode 5, epoch [6/15], loss: 687674436.2906259
# Episode 5, epoch [7/15], loss: 636114739.2238472
# Episode 5, epoch [8/15], loss: 350660027.7599069
# Episode 5, epoch [9/15], loss: 466241262.9639587
# Episode 5, epoch [10/15], loss: 630231449.655178
# Episode 5, epoch [11/15], loss: 462589610.71696335
# Episode 5, epoch [12/15], loss: 311412428.84655154
# Episode 5, epoch [13/15], loss: 678553463.4964546
# Episode 5, epoch [14/15], loss: 234159684.28867972
# Episode 5, epoch [15/15], loss: 447623953.08943766
# Episode 5 completed in 17.68 seconds
# Starting episode 6/500
# Episode 6, epoch [1/15], loss: 0.025494461382428803
# Episode 6, epoch [2/15], loss: 0.025405127306779227
# Episode 6, epoch [3/15], loss: 0.023388364911079408
# Episode 6, epoch [4/15], loss: 0.022440089161197344
# Episode 6, epoch [5/15], loss: 0.021947626397013663
# Episode 6, epoch [6/15], loss: 0.02162672902146975
# Episode 6, epoch [7/15], loss: 0.02147578845421473
# Episode 6, epoch [8/15], loss: 0.02108875662088394
# Episode 6, epoch [9/15], loss: 0.020993790154655776
# Episode 6, epoch [10/15], loss: 0.02029130980372429
# Episode 6, epoch [11/15], loss: 0.01998127146313588
# Episode 6, epoch [12/15], loss: 0.02008849779764811
# Episode 6, epoch [13/15], loss: 0.019936844644447168
# Episode 6, epoch [14/15], loss: 0.019753412964443367
# Episode 6, epoch [15/15], loss: 0.019405005934337773
# Episode 6 completed in 17.84 seconds
# Starting episode 7/500
# Episode 7, epoch [1/15], loss: 0.019801843104263146
# Episode 7, epoch [2/15], loss: 0.021892690286040305
# Episode 7, epoch [3/15], loss: 0.020414302373925844
# Episode 7, epoch [4/15], loss: 0.019592577187965313
# Episode 7, epoch [5/15], loss: 0.019573531424005825
# Episode 7, epoch [6/15], loss: 0.013661173420647781
# Episode 7, epoch [7/15], loss: 0.020508308398226895
# Episode 7, epoch [8/15], loss: 0.017590933355192344
# Episode 7, epoch [9/15], loss: 0.01630363635097941
# Episode 7, epoch [10/15], loss: 0.01987196517487367
# Episode 7, epoch [11/15], loss: 0.01597748650237918
# Episode 7, epoch [12/15], loss: 0.017734467424452303
# Episode 7, epoch [13/15], loss: 0.01589117410282294
# Episode 7, epoch [14/15], loss: 0.016618006645391384
# Episode 7, epoch [15/15], loss: 0.013555361020068327
# Episode 7 completed in 17.97 seconds
# Starting episode 8/500
# Episode 8, epoch [1/15], loss: 0.02670479075362285
# Episode 8, epoch [2/15], loss: 0.024307777360081672
# Episode 8, epoch [3/15], loss: 0.022687150910496712
# Episode 8, epoch [4/15], loss: 0.023674668495853743
# Episode 8, epoch [5/15], loss: 0.02440206923832496
# Episode 8, epoch [6/15], loss: 0.021594944347937902
# Episode 8, epoch [7/15], loss: 0.021205404400825502
# Episode 8, epoch [8/15], loss: 0.0222097289438049
# Episode 8, epoch [9/15], loss: 0.020773398379484814
# Episode 8, epoch [10/15], loss: 0.021150334862371285
# Episode 8, epoch [11/15], loss: 0.021308899236222107
# Episode 8, epoch [12/15], loss: 0.020548255679508052
# Episode 8, epoch [13/15], loss: 0.021529094874858858
# Episode 8, epoch [14/15], loss: 0.020070334275563557
# Episode 8, epoch [15/15], loss: 0.020669407738993565
# Episode 8 completed in 17.45 seconds
# Starting episode 9/500
# Episode 9, epoch [1/15], loss: 0.17237907399733862
# Episode 9, epoch [2/15], loss: 0.14915084565679232
# Episode 9, epoch [3/15], loss: 0.17092235684394835
# Episode 9, epoch [4/15], loss: 0.17385155310233433
# Episode 9, epoch [5/15], loss: 0.1781745247542858
# Episode 9, epoch [6/15], loss: 0.13072490878403187
# Episode 9, epoch [7/15], loss: 0.16217709630727767
# Episode 9, epoch [8/15], loss: 0.3054983263214429
# Episode 9, epoch [9/15], loss: 0.1792748918135961
# Episode 9, epoch [10/15], loss: 0.12551590688526632
# Episode 9, epoch [11/15], loss: 0.1339015853901704
# Episode 9, epoch [12/15], loss: 0.11818154441813628
# Episode 9, epoch [13/15], loss: 0.15591612483064335
# Episode 9, epoch [14/15], loss: 0.16462716832756996
# Episode 9, epoch [15/15], loss: 0.1518275958796342
# Episode 9 completed in 17.39 seconds
# Starting episode 10/500
# Episode 10, epoch [1/15], loss: 0.026320251077413558
# Episode 10, epoch [2/15], loss: 0.032743300621708236
# Episode 10, epoch [3/15], loss: 0.021909921864668527
# Episode 10, epoch [4/15], loss: 0.025572176091372967
# Episode 10, epoch [5/15], loss: 0.025906342392166454
# Episode 10, epoch [6/15], loss: 0.026974392496049403
# Episode 10, epoch [7/15], loss: 0.02006462576488654
# Episode 10, epoch [8/15], loss: 0.03372658813993136
# Episode 10, epoch [9/15], loss: 0.02344052748133739
# Episode 10, epoch [10/15], loss: 0.022366582540174325
# Episode 10, epoch [11/15], loss: 0.026760295033454895
# Episode 10, epoch [12/15], loss: 0.017561625844488542
# Episode 10, epoch [13/15], loss: 0.024955566972494125
# Episode 10, epoch [14/15], loss: 0.016564453672617673
# Episode 10, epoch [15/15], loss: 0.01919713063786427
# Episode 10 completed in 17.49 seconds
# Saved hidden representations for episode 10
# Starting episode 11/500
# Episode 11, epoch [1/15], loss: 0.01669692639261484
# Episode 11, epoch [2/15], loss: 0.014777530419329802
# Episode 11, epoch [3/15], loss: 0.013036539902289708
# Episode 11, epoch [4/15], loss: 0.013446708054592213
# Episode 11, epoch [5/15], loss: 0.013960844650864602
# Episode 11, epoch [6/15], loss: 0.01398168746381998
# Episode 11, epoch [7/15], loss: 0.011985822301357984
# Episode 11, epoch [8/15], loss: 0.013393612454334895
# Episode 11, epoch [9/15], loss: 0.012089548104753097
# Episode 11, epoch [10/15], loss: 0.014123570422331493
# Episode 11, epoch [11/15], loss: 0.01293708166728417
# Episode 11, epoch [12/15], loss: 0.012047502243270477
# Episode 11, epoch [13/15], loss: 0.015873682436843714
# Episode 11, epoch [14/15], loss: 0.016038379383583865
# Episode 11, epoch [15/15], loss: 0.013593941554427147
# Episode 11 completed in 17.35 seconds
# Starting episode 12/500
# Episode 12, epoch [1/15], loss: 0.024276606862743695
# Episode 12, epoch [2/15], loss: 0.024405743895719447
# Episode 12, epoch [3/15], loss: 0.021177409465114275
# Episode 12, epoch [4/15], loss: 0.030059591804941495
# Episode 12, epoch [5/15], loss: 0.031224843766540288
# Episode 12, epoch [6/15], loss: 0.028070614549020927
# Episode 12, epoch [7/15], loss: 0.02617285680025816
# Episode 12, epoch [8/15], loss: 0.024577224596093097
# Episode 12, epoch [9/15], loss: 0.026248709360758463
# Episode 12, epoch [10/15], loss: 0.02683737880239884
# Episode 12, epoch [11/15], loss: 0.029235266521573065
# Episode 12, epoch [12/15], loss: 0.02601445494219661
# Episode 12, epoch [13/15], loss: 0.02767317251612743
# Episode 12, epoch [14/15], loss: 0.02155913148696224
# Episode 12, epoch [15/15], loss: 0.03246204989651839
# Episode 12 completed in 17.46 seconds
# Starting episode 13/500
# Episode 13, epoch [1/15], loss: 0.03638283181935549
# Episode 13, epoch [2/15], loss: 0.02963720392435789
# Episode 13, epoch [3/15], loss: 0.023219187371432783
# Episode 13, epoch [4/15], loss: 0.017453296730915707
# Episode 13, epoch [5/15], loss: 0.02217626494045059
# Episode 13, epoch [6/15], loss: 0.01919381357729435
# Episode 13, epoch [7/15], loss: 0.018503309600055216
# Episode 13, epoch [8/15], loss: 0.01630263632784287
# Episode 13, epoch [9/15], loss: 0.020036900974810125
# Episode 13, epoch [10/15], loss: 0.020301973323027293
# Episode 13, epoch [11/15], loss: 0.014072194881737232
# Episode 13, epoch [12/15], loss: 0.016529519545535245
# Episode 13, epoch [13/15], loss: 0.016377596991757552
# Episode 13, epoch [14/15], loss: 0.019436725415289402
# Episode 13, epoch [15/15], loss: 0.014363769659151633
# Episode 13 completed in 16.84 seconds
# Starting episode 14/500
# Episode 14, epoch [1/15], loss: 0.013954046834260225
# Episode 14, epoch [2/15], loss: 0.019544792361557484
# Episode 14, epoch [3/15], loss: 0.019192141480743885
# Episode 14, epoch [4/15], loss: 0.01609574497366945
# Episode 14, epoch [5/15], loss: 0.024631976118932166
# Episode 14, epoch [6/15], loss: 0.021392013443013034
# Episode 14, epoch [7/15], loss: 0.01384860264758269
# Episode 14, epoch [8/15], loss: 0.021716248399267595
# Episode 14, epoch [9/15], loss: 0.019828917055080334
# Episode 14, epoch [10/15], loss: 0.014068564648429554
# Episode 14, epoch [11/15], loss: 0.012526502491285403
# Episode 14, epoch [12/15], loss: 0.011304915727426609
# Episode 14, epoch [13/15], loss: 0.011173133086413146
# Episode 14, epoch [14/15], loss: 0.011096687739094098
# Episode 14, epoch [15/15], loss: 0.009610464765379826
# Episode 14 completed in 17.60 seconds
# Starting episode 15/500
# Episode 15, epoch [1/15], loss: 0.01710723846529921
# Episode 15, epoch [2/15], loss: 0.01528114943454663
# Episode 15, epoch [3/15], loss: 0.019119643482069175
# Episode 15, epoch [4/15], loss: 0.02832661842306455
# Episode 15, epoch [5/15], loss: 0.017221083119511604
# Episode 15, epoch [6/15], loss: 0.015541593078523874
# Episode 15, epoch [7/15], loss: 0.016974172834306956
# Episode 15, epoch [8/15], loss: 0.018353439153482518
# Episode 15, epoch [9/15], loss: 0.014458088235308727
# Episode 15, epoch [10/15], loss: 0.01677709271510442
# Episode 15, epoch [11/15], loss: 0.01713652250667413
# Episode 15, epoch [12/15], loss: 0.016226899872223536
# Episode 15, epoch [13/15], loss: 0.011994550904879967
# Episode 15, epoch [14/15], loss: 0.01638112012296915
# Episode 15, epoch [15/15], loss: 0.012764058262109756
# Episode 15 completed in 16.66 seconds
# Starting episode 16/500
# Episode 16, epoch [1/15], loss: 0.012880306939284008
# Episode 16, epoch [2/15], loss: 0.014852788423498471
# Episode 16, epoch [3/15], loss: 0.013119710267831881
# Episode 16, epoch [4/15], loss: 0.014544764161109924
# Episode 16, epoch [5/15], loss: 0.01153515384842952
# Episode 16, epoch [6/15], loss: 0.013229714054614306
# Episode 16, epoch [7/15], loss: 0.013253861293196677
# Episode 16, epoch [8/15], loss: 0.015787455377479394
# Episode 16, epoch [9/15], loss: 0.011762330898394187
# Episode 16, epoch [10/15], loss: 0.010898996982723475
# Episode 16, epoch [11/15], loss: 0.009569437180956205
# Episode 16, epoch [12/15], loss: 0.011023962373534838
# Episode 16, epoch [13/15], loss: 0.01164014224583904
# Episode 16, epoch [14/15], loss: 0.01273986439531048
# Episode 16, epoch [15/15], loss: 0.010970365970085065
# Episode 16 completed in 16.74 seconds
# Starting episode 17/500
# Episode 17, epoch [1/15], loss: 0.009383537496129671
# Episode 17, epoch [2/15], loss: 0.007949479979773362
# Episode 17, epoch [3/15], loss: 0.007266655921315154
# Episode 17, epoch [4/15], loss: 0.010310117558886608
# Episode 17, epoch [5/15], loss: 0.008020822703838349
# Episode 17, epoch [6/15], loss: 0.006577118455121915
# Episode 17, epoch [7/15], loss: 0.006563776669402917
# Episode 17, epoch [8/15], loss: 0.008097748986134927
# Episode 17, epoch [9/15], loss: 0.006196981916824977
# Episode 17, epoch [10/15], loss: 0.007934413710609078
# Episode 17, epoch [11/15], loss: 0.008290679830436905
# Episode 17, epoch [12/15], loss: 0.007345842539022366
# Episode 17, epoch [13/15], loss: 0.008666830292592445
# Episode 17, epoch [14/15], loss: 0.00763361860687534
# Episode 17, epoch [15/15], loss: 0.008105674913773933
# Episode 17 completed in 16.72 seconds
# Starting episode 18/500
# Episode 18, epoch [1/15], loss: 0.03390852529555559
# Episode 18, epoch [2/15], loss: 0.0187779457308352
# Episode 18, epoch [3/15], loss: 0.01744981510564685
# Episode 18, epoch [4/15], loss: 0.016001532537241778
# Episode 18, epoch [5/15], loss: 0.018643261212855578
# Episode 18, epoch [6/15], loss: 0.016791849800695976
# Episode 18, epoch [7/15], loss: 0.01786773062000672
# Episode 18, epoch [8/15], loss: 0.03339534951373935
# Episode 18, epoch [9/15], loss: 0.03458295123030742
# Episode 18, epoch [10/15], loss: 0.03199357862273852
# Episode 18, epoch [11/15], loss: 0.029730472651620706
# Episode 18, epoch [12/15], loss: 0.041129628444711366
# Episode 18, epoch [13/15], loss: 0.037168279631684224
# Episode 18, epoch [14/15], loss: 0.042944646812975405
# Episode 18, epoch [15/15], loss: 0.031921811619152626
# Episode 18 completed in 16.61 seconds
# Starting episode 19/500
# Episode 19, epoch [1/15], loss: 13439065705676.8
# Episode 19, epoch [2/15], loss: 13083254921625.6
# Episode 19, epoch [3/15], loss: 11744075159961.6
# Episode 19, epoch [4/15], loss: 10999999968051.2
# Episode 19, epoch [5/15], loss: 10464503564424.533
# Episode 19, epoch [6/15], loss: 9071797740066.133
# Episode 19, epoch [7/15], loss: 9084633778312.533
# Episode 19, epoch [8/15], loss: 8323699144567.467
# Episode 19, epoch [9/15], loss: 8325926905446.4
# Episode 19, epoch [10/15], loss: 7477798196565.333
# Episode 19, epoch [11/15], loss: 7028420046574.934
# Episode 19, epoch [12/15], loss: 6744539778252.8
# Episode 19, epoch [13/15], loss: 6626523117431.467
# Episode 19, epoch [14/15], loss: 6323011033497.6
# Episode 19, epoch [15/15], loss: 6470399706180.267
# Episode 19 completed in 16.64 seconds
# Starting episode 20/500
# Episode 20, epoch [1/15], loss: 0.08898082872231801
# Episode 20, epoch [2/15], loss: 0.03204682134091854
# Episode 20, epoch [3/15], loss: 0.020982726601262887
# Episode 20, epoch [4/15], loss: 0.01865950059145689
# Episode 20, epoch [5/15], loss: 0.014877314306795597
# Episode 20, epoch [6/15], loss: 0.01300270315259695
# Episode 20, epoch [7/15], loss: 0.013079152287294468
# Episode 20, epoch [8/15], loss: 0.011848623181382816
# Episode 20, epoch [9/15], loss: 0.011566238943487406
# Episode 20, epoch [10/15], loss: 0.011330979317426682
# Episode 20, epoch [11/15], loss: 0.010051246235768
# Episode 20, epoch [12/15], loss: 0.01010932382196188
# Episode 20, epoch [13/15], loss: 0.010058353965481123
# Episode 20, epoch [14/15], loss: 0.010329066558430593
# Episode 20, epoch [15/15], loss: 0.012830077515294155
# Episode 20 completed in 16.96 seconds
# Saved hidden representations for episode 20
# Starting episode 21/500
# Episode 21, epoch [1/15], loss: 0.026584486321856577
# Episode 21, epoch [2/15], loss: 0.021791759319603442
# Episode 21, epoch [3/15], loss: 0.018079792459805805
# Episode 21, epoch [4/15], loss: 0.028191617286453644
# Episode 21, epoch [5/15], loss: 0.0423155943552653
# Episode 21, epoch [6/15], loss: 0.043578952581932145
# Episode 21, epoch [7/15], loss: 0.01476152678951621
# Episode 21, epoch [8/15], loss: 0.015110811032354832
# Episode 21, epoch [9/15], loss: 0.01716065083940824
# Episode 21, epoch [10/15], loss: 0.025576945518453915
# Episode 21, epoch [11/15], loss: 0.024986112055679164
# Episode 21, epoch [12/15], loss: 0.019122698965171974
# Episode 21, epoch [13/15], loss: 0.02061797628800074
# Episode 21, epoch [14/15], loss: 0.014779948101689418
# Episode 21, epoch [15/15], loss: 0.015556721265117328
# Episode 21 completed in 16.80 seconds
# Starting episode 22/500
# Episode 22, epoch [1/15], loss: 0.005966734311853846
# Episode 22, epoch [2/15], loss: 0.007459134065235655
# Episode 22, epoch [3/15], loss: 0.005370344718297323
# Episode 22, epoch [4/15], loss: 0.004898781872664889
# Episode 22, epoch [5/15], loss: 0.0065156407499065
# Episode 22, epoch [6/15], loss: 0.008097441696251432
# Episode 22, epoch [7/15], loss: 0.004882173597191771
# Episode 22, epoch [8/15], loss: 0.0049458171240985395
# Episode 22, epoch [9/15], loss: 0.0050993227865546945
# Episode 22, epoch [10/15], loss: 0.004385711144035061
# Episode 22, epoch [11/15], loss: 0.005405973643064499
# Episode 22, epoch [12/15], loss: 0.00407195563117663
# Episode 22, epoch [13/15], loss: 0.004044501669704914
# Episode 22, epoch [14/15], loss: 0.004731687639529507
# Episode 22, epoch [15/15], loss: 0.004651935476188859
# Episode 22 completed in 16.94 seconds
# Starting episode 23/500
# Episode 23, epoch [1/15], loss: 0.014024028507992625
# Episode 23, epoch [2/15], loss: 0.015337524749338628
# Episode 23, epoch [3/15], loss: 0.014338099149366219
# Episode 23, epoch [4/15], loss: 0.013818056043237447
# Episode 23, epoch [5/15], loss: 0.013525056062887113
# Episode 23, epoch [6/15], loss: 0.012515946508695681
# Episode 23, epoch [7/15], loss: 0.014019117504358292
# Episode 23, epoch [8/15], loss: 0.014875789918005467
# Episode 23, epoch [9/15], loss: 0.013218760676681995
# Episode 23, epoch [10/15], loss: 0.01242134893933932
# Episode 23, epoch [11/15], loss: 0.013598497149844964
# Episode 23, epoch [12/15], loss: 0.014423796410361926
# Episode 23, epoch [13/15], loss: 0.013086188522477945
# Episode 23, epoch [14/15], loss: 0.011038088829567035
# Episode 23, epoch [15/15], loss: 0.014285198288659255
# Episode 23 completed in 16.70 seconds
# Starting episode 24/500
# Episode 24, epoch [1/15], loss: 1009911962009.6528
# Episode 24, epoch [2/15], loss: 614507391658.7245
# Episode 24, epoch [3/15], loss: 534271492096.0477
# Episode 24, epoch [4/15], loss: 379850658065.11426
# Episode 24, epoch [5/15], loss: 542001122508.8484
# Episode 24, epoch [6/15], loss: 268749128772.33133
# Episode 24, epoch [7/15], loss: 590837186560.06
# Episode 24, epoch [8/15], loss: 363748191982.9814
# Episode 24, epoch [9/15], loss: 393785525316.3063
# Episode 24, epoch [10/15], loss: 586710568140.8439
# Episode 24, epoch [11/15], loss: 295485588548.30786
# Episode 24, epoch [12/15], loss: 214397013196.8421
# Episode 24, epoch [13/15], loss: 403146923485.9156
# Episode 24, epoch [14/15], loss: 327223790796.8479
# Episode 24, epoch [15/15], loss: 202164456652.83762
# Episode 24 completed in 16.87 seconds
# Starting episode 25/500
# Episode 25, epoch [1/15], loss: 0.057297289619843164
# Episode 25, epoch [2/15], loss: 0.055573623006542526
# Episode 25, epoch [3/15], loss: 0.049400515574961903
# Episode 25, epoch [4/15], loss: 0.045159500651061536
# Episode 25, epoch [5/15], loss: 0.041323969668398304
# Episode 25, epoch [6/15], loss: 0.04230350060388446
# Episode 25, epoch [7/15], loss: 0.04006604015206297
# Episode 25, epoch [8/15], loss: 0.050877428924043976
# Episode 25, epoch [9/15], loss: 0.04494594397644202
# Episode 25, epoch [10/15], loss: 0.043733287851015726
# Episode 25, epoch [11/15], loss: 0.03980702630554636
# Episode 25, epoch [12/15], loss: 0.038996886399885015
# Episode 25, epoch [13/15], loss: 0.03635084523508946
# Episode 25, epoch [14/15], loss: 0.03977335256834825
# Episode 25, epoch [15/15], loss: 0.036542608744154374
# Episode 25 completed in 16.97 seconds
# Starting episode 26/500
# Episode 26, epoch [1/15], loss: 0.026346928750475247
# Episode 26, epoch [2/15], loss: 0.03250681944191456
# Episode 26, epoch [3/15], loss: 0.03936574434240659
# Episode 26, epoch [4/15], loss: 0.035092142038047315
# Episode 26, epoch [5/15], loss: 0.03565091652174791
# Episode 26, epoch [6/15], loss: 0.02250792011618614
# Episode 26, epoch [7/15], loss: 0.02401368385180831
# Episode 26, epoch [8/15], loss: 0.02284088224793474
# Episode 26, epoch [9/15], loss: 0.02126238914206624
# Episode 26, epoch [10/15], loss: 0.01997114218150576
# Episode 26, epoch [11/15], loss: 0.02103287630404035
# Episode 26, epoch [12/15], loss: 0.022991423526157937
# Episode 26, epoch [13/15], loss: 0.02105780349423488
# Episode 26, epoch [14/15], loss: 0.020542679509768885
# Episode 26, epoch [15/15], loss: 0.018846184046318135
# Episode 26 completed in 17.05 seconds
# Starting episode 27/500
# Episode 27, epoch [1/15], loss: 0.02656278891178469
# Episode 27, epoch [2/15], loss: 0.027457538712769746
# Episode 27, epoch [3/15], loss: 0.026847243153800566
# Episode 27, epoch [4/15], loss: 0.03384833276892702
# Episode 27, epoch [5/15], loss: 0.03207040385653575
# Episode 27, epoch [6/15], loss: 0.034922176677112775
# Episode 27, epoch [7/15], loss: 0.036711107349644105
# Episode 27, epoch [8/15], loss: 0.026410082137833038
# Episode 27, epoch [9/15], loss: 0.036083553762485586
# Episode 27, epoch [10/15], loss: 0.0313714739245673
# Episode 27, epoch [11/15], loss: 0.03672158637394508
# Episode 27, epoch [12/15], loss: 0.02506091119721532
# Episode 27, epoch [13/15], loss: 0.03577149817720056
# Episode 27, epoch [14/15], loss: 0.028516719040150445
# Episode 27, epoch [15/15], loss: 0.02212452972307801
# Episode 27 completed in 17.04 seconds
# Starting episode 28/500
# Episode 28, epoch [1/15], loss: 0.018063626997172833
# Episode 28, epoch [2/15], loss: 0.010960688364381592
# Episode 28, epoch [3/15], loss: 0.010889618750661611
# Episode 28, epoch [4/15], loss: 0.011210549467553696
# Episode 28, epoch [5/15], loss: 0.011239663884043693
# Episode 28, epoch [6/15], loss: 0.015368940743307273
# Episode 28, epoch [7/15], loss: 0.01223225969200333
# Episode 28, epoch [8/15], loss: 0.009767837279165784
# Episode 28, epoch [9/15], loss: 0.015791379443059365
# Episode 28, epoch [10/15], loss: 0.015870489366352557
# Episode 28, epoch [11/15], loss: 0.009803083399310708
# Episode 28, epoch [12/15], loss: 0.0199928916990757
# Episode 28, epoch [13/15], loss: 0.036913366584728165
# Episode 28, epoch [14/15], loss: 0.01740060360170901
# Episode 28, epoch [15/15], loss: 0.011327316441262761
# Episode 28 completed in 17.09 seconds
# Starting episode 29/500
# Episode 29, epoch [1/15], loss: 221316334.9952045
# Episode 29, epoch [2/15], loss: 259138816.0724253
# Episode 29, epoch [3/15], loss: 203783185.20344958
# Episode 29, epoch [4/15], loss: 381784780.9405825
# Episode 29, epoch [5/15], loss: 109650483.28150336
# Episode 29, epoch [6/15], loss: 231309380.31764802
# Episode 29, epoch [7/15], loss: 212103236.38311177
# Episode 29, epoch [8/15], loss: 186662502.50114635
# Episode 29, epoch [9/15], loss: 170123076.30460915
# Episode 29, epoch [10/15], loss: 262787140.32503492
# Episode 29, epoch [11/15], loss: 137215718.45319563
# Episode 29, epoch [12/15], loss: 103453218.19799776
# Episode 29, epoch [13/15], loss: 150530696.59645864
# Episode 29, epoch [14/15], loss: 226373853.94713214
# Episode 29, epoch [15/15], loss: 158622225.12161392
# Episode 29 completed in 17.02 seconds
# Starting episode 30/500
# Episode 30, epoch [1/15], loss: 408681745.08849114
# Episode 30, epoch [2/15], loss: 645807786.6862063
# Episode 30, epoch [3/15], loss: 650815283.2224841
# Episode 30, epoch [4/15], loss: 437940189.88602805
# Episode 30, epoch [5/15], loss: 319674197.3491357
# Episode 30, epoch [6/15], loss: 463228450.1457462
# Episode 30, epoch [7/15], loss: 292043366.4220325
# Episode 30, epoch [8/15], loss: 272023859.21380585
# Episode 30, epoch [9/15], loss: 176260881.08227363
# Episode 30, epoch [10/15], loss: 473687961.6193933
# Episode 30, epoch [11/15], loss: 149716480.01024777
# Episode 30, epoch [12/15], loss: 472135645.8833495
# Episode 30, epoch [13/15], loss: 304074069.347879
# Episode 30, epoch [14/15], loss: 440413661.88213915
# Episode 30, epoch [15/15], loss: 246259814.41685724
# Episode 30 completed in 16.97 seconds
# Saved hidden representations for episode 30
# Starting episode 31/500
# Episode 31, epoch [1/15], loss: 0.022883411527921758
# Episode 31, epoch [2/15], loss: 0.022858163217703502
# Episode 31, epoch [3/15], loss: 0.028459593125929435
# Episode 31, epoch [4/15], loss: 0.019290460273623466
# Episode 31, epoch [5/15], loss: 0.022054905910044907
# Episode 31, epoch [6/15], loss: 0.021578786397973695
# Episode 31, epoch [7/15], loss: 0.019700510427355766
# Episode 31, epoch [8/15], loss: 0.018716621957719327
# Episode 31, epoch [9/15], loss: 0.020835049745316307
# Episode 31, epoch [10/15], loss: 0.01759912117073933
# Episode 31, epoch [11/15], loss: 0.01803495129570365
# Episode 31, epoch [12/15], loss: 0.02074682010958592
# Episode 31, epoch [13/15], loss: 0.02233436514313022
# Episode 31, epoch [14/15], loss: 0.02103046663105488
# Episode 31, epoch [15/15], loss: 0.02140549315760533
# Episode 31 completed in 17.18 seconds
# Starting episode 32/500
# Episode 32, epoch [1/15], loss: 343939959.5262572
# Episode 32, epoch [2/15], loss: 704268765.9290788
# Episode 32, epoch [3/15], loss: 109088981.38705386
# Episode 32, epoch [4/15], loss: 725973947.7897235
# Episode 32, epoch [5/15], loss: 310821922.1833894
# Episode 32, epoch [6/15], loss: 344979763.25399464
# Episode 32, epoch [7/15], loss: 132866628.36968
# Episode 32, epoch [8/15], loss: 409589589.38662916
# Episode 32, epoch [9/15], loss: 130798071.51360057
# Episode 32, epoch [10/15], loss: 272900676.33539313
# Episode 32, epoch [11/15], loss: 205315754.72804165
# Episode 32, epoch [12/15], loss: 265822088.60226038
# Episode 32, epoch [13/15], loss: 81730082.19548737
# Episode 32, epoch [14/15], loss: 497008298.7412545
# Episode 32, epoch [15/15], loss: 103640243.25449458
# Episode 32 completed in 17.07 seconds
# Starting episode 33/500
# Episode 33, epoch [1/15], loss: 0.008711601064230004
# Episode 33, epoch [2/15], loss: 0.007241279678419232
# Episode 33, epoch [3/15], loss: 0.005795359689121445
# Episode 33, epoch [4/15], loss: 0.005375074393426379
# Episode 33, epoch [5/15], loss: 0.006126270606182515
# Episode 33, epoch [6/15], loss: 0.005789558496326208
# Episode 33, epoch [7/15], loss: 0.005785071415205797
# Episode 33, epoch [8/15], loss: 0.007162190461531282
# Episode 33, epoch [9/15], loss: 0.00568718573388954
# Episode 33, epoch [10/15], loss: 0.006107328335444132
# Episode 33, epoch [11/15], loss: 0.006258205246801178
# Episode 33, epoch [12/15], loss: 0.004268206919853886
# Episode 33, epoch [13/15], loss: 0.005093035583073894
# Episode 33, epoch [14/15], loss: 0.005837662875031431
# Episode 33, epoch [15/15], loss: 0.004846261814236641
# Episode 33 completed in 17.01 seconds
# Starting episode 34/500
# Episode 34, epoch [1/15], loss: 0.026600884987662235
# Episode 34, epoch [2/15], loss: 0.02859526068593065
# Episode 34, epoch [3/15], loss: 0.0326431588580211
# Episode 34, epoch [4/15], loss: 0.036465217483540376
# Episode 34, epoch [5/15], loss: 0.02632669238373637
# Episode 34, epoch [6/15], loss: 0.03787578834841649
# Episode 34, epoch [7/15], loss: 0.02537609136973818
# Episode 34, epoch [8/15], loss: 0.032371509447693826
# Episode 34, epoch [9/15], loss: 0.03123131503040592
# Episode 34, epoch [10/15], loss: 0.024930388728777567
# Episode 34, epoch [11/15], loss: 0.03126923100401958
# Episode 34, epoch [12/15], loss: 0.026949543862914045
# Episode 34, epoch [13/15], loss: 0.030810509777317443
# Episode 34, epoch [14/15], loss: 0.03412400685871641
# Episode 34, epoch [15/15], loss: 0.018558873857061068
# Episode 34 completed in 17.17 seconds
# Starting episode 35/500
# Episode 35, epoch [1/15], loss: 5524724667.806527
# Episode 35, epoch [2/15], loss: 3649226615.540831
# Episode 35, epoch [3/15], loss: 9176731921.13875
# Episode 35, epoch [4/15], loss: 2423133252.3274646
# Episode 35, epoch [5/15], loss: 5171168870.47643
# Episode 35, epoch [6/15], loss: 2289369497.6693363
# Episode 35, epoch [7/15], loss: 6318003541.41385
# Episode 35, epoch [8/15], loss: 2683291784.6110306
# Episode 35, epoch [9/15], loss: 6127358771.26193
# Episode 35, epoch [10/15], loss: 3452433203.27456
# Episode 35, epoch [11/15], loss: 4794851874.192079
# Episode 35, epoch [12/15], loss: 2726128571.7776585
# Episode 35, epoch [13/15], loss: 3249139985.1228266
# Episode 35, epoch [14/15], loss: 1106682402.1858418
# Episode 35, epoch [15/15], loss: 3795445896.6000285
# Episode 35 completed in 17.13 seconds
# Starting episode 36/500
# Episode 36, epoch [1/15], loss: 304143001.63227326
# Episode 36, epoch [2/15], loss: 231509358.96772093
# Episode 36, epoch [3/15], loss: 276369664.03596014
# Episode 36, epoch [4/15], loss: 226699494.43345037
# Episode 36, epoch [5/15], loss: 195617322.69401404
# Episode 36, epoch [6/15], loss: 157904413.91811046
# Episode 36, epoch [7/15], loss: 160952925.885309
# Episode 36, epoch [8/15], loss: 215066214.42510787
# Episode 36, epoch [9/15], loss: 122246852.3236106
# Episode 36, epoch [10/15], loss: 230946414.98976868
# Episode 36, epoch [11/15], loss: 133338351.01198502
# Episode 36, epoch [12/15], loss: 190352174.96419936
# Episode 36, epoch [13/15], loss: 162707566.9586435
# Episode 36, epoch [14/15], loss: 119782199.49729107
# Episode 36, epoch [15/15], loss: 156281932.84101132
# Episode 36 completed in 16.88 seconds
# Starting episode 37/500
# Episode 37, epoch [1/15], loss: 0.008570364986856779
# Episode 37, epoch [2/15], loss: 0.006683975582321485
# Episode 37, epoch [3/15], loss: 0.006430759141221642
# Episode 37, epoch [4/15], loss: 0.005157126036162178
# Episode 37, epoch [5/15], loss: 0.004908746543029944
# Episode 37, epoch [6/15], loss: 0.00452546173085769
# Episode 37, epoch [7/15], loss: 0.004362719117974242
# Episode 37, epoch [8/15], loss: 0.004536084613452355
# Episode 37, epoch [9/15], loss: 0.004027012937391798
# Episode 37, epoch [10/15], loss: 0.004032853183646997
# Episode 37, epoch [11/15], loss: 0.004009312686199943
# Episode 37, epoch [12/15], loss: 0.003985766709471743
# Episode 37, epoch [13/15], loss: 0.003958067701508601
# Episode 37, epoch [14/15], loss: 0.004061689926311373
# Episode 37, epoch [15/15], loss: 0.00389028691376249
# Episode 37 completed in 17.15 seconds
# Starting episode 38/500
# Episode 38, epoch [1/15], loss: 17121024074.671204
# Episode 38, epoch [2/15], loss: 26460340659.21751
# Episode 38, epoch [3/15], loss: 16235823351.48333
# Episode 38, epoch [4/15], loss: 24781336619.74013
# Episode 38, epoch [5/15], loss: 13390082096.017216
# Episode 38, epoch [6/15], loss: 18167206150.412266
# Episode 38, epoch [7/15], loss: 19200594082.15686
# Episode 38, epoch [8/15], loss: 22390823837.8879
# Episode 38, epoch [9/15], loss: 11903990112.026525
# Episode 38, epoch [10/15], loss: 23994419835.7426
# Episode 38, epoch [11/15], loss: 14670552360.55298
# Episode 38, epoch [12/15], loss: 27826883144.549885
# Episode 38, epoch [13/15], loss: 10325916238.945438
# Episode 38, epoch [14/15], loss: 11673049254.413746
# Episode 38, epoch [15/15], loss: 12883228632.538168
# Episode 38 completed in 17.03 seconds
# Starting episode 39/500
# Episode 39, epoch [1/15], loss: 0.039475740678608415
# Episode 39, epoch [2/15], loss: 0.02830569107706348
# Episode 39, epoch [3/15], loss: 0.02322177494255205
# Episode 39, epoch [4/15], loss: 0.022853277840962014
# Episode 39, epoch [5/15], loss: 0.022435338081171114
# Episode 39, epoch [6/15], loss: 0.018398351361975075
# Episode 39, epoch [7/15], loss: 0.024041617382317783
# Episode 39, epoch [8/15], loss: 0.024164740368723868
# Episode 39, epoch [9/15], loss: 0.027428957509497802
# Episode 39, epoch [10/15], loss: 0.01708994765455524
# Episode 39, epoch [11/15], loss: 0.019396281040584048
# Episode 39, epoch [12/15], loss: 0.018916613111893337
# Episode 39, epoch [13/15], loss: 0.020735154720023276
# Episode 39, epoch [14/15], loss: 0.019316340858737627
# Episode 39, epoch [15/15], loss: 0.021876202834149202
# Episode 39 completed in 17.16 seconds
# Starting episode 40/500
# Episode 40, epoch [1/15], loss: 0.009084238360325495
# Episode 40, epoch [2/15], loss: 0.008108423262213667
# Episode 40, epoch [3/15], loss: 0.008371513166154424
# Episode 40, epoch [4/15], loss: 0.014361499374111493
# Episode 40, epoch [5/15], loss: 0.0073804438735047976
# Episode 40, epoch [6/15], loss: 0.009356090022871891
# Episode 40, epoch [7/15], loss: 0.014189236052334308
# Episode 40, epoch [8/15], loss: 0.009644788208728034
# Episode 40, epoch [9/15], loss: 0.011106812690074245
# Episode 40, epoch [10/15], loss: 0.007930834700043002
# Episode 40, epoch [11/15], loss: 0.009059633485352
# Episode 40, epoch [12/15], loss: 0.008141882174337903
# Episode 40, epoch [13/15], loss: 0.012224410381168126
# Episode 40, epoch [14/15], loss: 0.009506188395122687
# Episode 40, epoch [15/15], loss: 0.008579802280291916
# Episode 40 completed in 17.20 seconds
# Saved hidden representations for episode 40
# Starting episode 41/500
# Episode 41, epoch [1/15], loss: 0.04711707439273596
# Episode 41, epoch [2/15], loss: 0.04438597417126099
# Episode 41, epoch [3/15], loss: 0.040528913214802745
# Episode 41, epoch [4/15], loss: 0.03767801094800234
# Episode 41, epoch [5/15], loss: 0.05476207000513871
# Episode 41, epoch [6/15], loss: 0.03605850463112195
# Episode 41, epoch [7/15], loss: 0.03585847212622563
# Episode 41, epoch [8/15], loss: 0.03583796036740144
# Episode 41, epoch [9/15], loss: 0.038096073518196744
# Episode 41, epoch [10/15], loss: 0.03850897128383319
# Episode 41, epoch [11/15], loss: 0.035971354537953935
# Episode 41, epoch [12/15], loss: 0.031136049516499044
# Episode 41, epoch [13/15], loss: 0.03308567802111308
# Episode 41, epoch [14/15], loss: 0.033485540313025315
# Episode 41, epoch [15/15], loss: 0.02963934460033973
# Episode 41 completed in 16.95 seconds
# Starting episode 42/500
# Episode 42, epoch [1/15], loss: 206978001578.70154
# Episode 42, epoch [2/15], loss: 204570310519.50803
# Episode 42, epoch [3/15], loss: 190094215304.59842
# Episode 42, epoch [4/15], loss: 184284641689.64163
# Episode 42, epoch [5/15], loss: 180722383803.76868
# Episode 42, epoch [6/15], loss: 153514176785.12436
# Episode 42, epoch [7/15], loss: 160967483392.03064
# Episode 42, epoch [8/15], loss: 178712284364.85013
# Episode 42, epoch [9/15], loss: 144708094634.72113
# Episode 42, epoch [10/15], loss: 132931233382.45084
# Episode 42, epoch [11/15], loss: 124944406937.66096
# Episode 42, epoch [12/15], loss: 105957274419.24876
# Episode 42, epoch [13/15], loss: 99809368473.6409
# Episode 42, epoch [14/15], loss: 99087692868.31664
# Episode 42, epoch [15/15], loss: 111004343773.91669
# Episode 42 completed in 17.11 seconds
# Starting episode 43/500
# Episode 43, epoch [1/15], loss: 0.019407372859617075
# Episode 43, epoch [2/15], loss: 0.014114820243169865
# Episode 43, epoch [3/15], loss: 0.0109841449962308
# Episode 43, epoch [4/15], loss: 0.009949350248401363
# Episode 43, epoch [5/15], loss: 0.008774394200493892
# Episode 43, epoch [6/15], loss: 0.008439357904717327
# Episode 43, epoch [7/15], loss: 0.008652464393526316
# Episode 43, epoch [8/15], loss: 0.00733853845546643
# Episode 43, epoch [9/15], loss: 0.007073081998775403
# Episode 43, epoch [10/15], loss: 0.0071221269822369015
# Episode 43, epoch [11/15], loss: 0.008240282845993837
# Episode 43, epoch [12/15], loss: 0.007571252947673202
# Episode 43, epoch [13/15], loss: 0.006357147994761666
# Episode 43, epoch [14/15], loss: 0.006258376392846306
# Episode 43, epoch [15/15], loss: 0.006438015339275201
# Episode 43 completed in 16.89 seconds
# Starting episode 44/500
# Episode 44, epoch [1/15], loss: 2796951347.7234936
# Episode 44, epoch [2/15], loss: 2041017139.6943846
# Episode 44, epoch [3/15], loss: 2091098897.929454
# Episode 44, epoch [4/15], loss: 1815594121.1163723
# Episode 44, epoch [5/15], loss: 1377507055.3981102
# Episode 44, epoch [6/15], loss: 1254532779.2074378
# Episode 44, epoch [7/15], loss: 2076720333.3123217
# Episode 44, epoch [8/15], loss: 1283246148.5779579
# Episode 44, epoch [9/15], loss: 984986624.9635776
# Episode 44, epoch [10/15], loss: 1213205368.221835
# Episode 44, epoch [11/15], loss: 847071215.4859759
# Episode 44, epoch [12/15], loss: 1790016376.102501
# Episode 44, epoch [13/15], loss: 1190063957.916636
# Episode 44, epoch [14/15], loss: 782666223.6435603
# Episode 44, epoch [15/15], loss: 892278613.9661024
# Episode 44 completed in 16.81 seconds
# Starting episode 45/500
# Episode 45, epoch [1/15], loss: 9597030.462543594
# Episode 45, epoch [2/15], loss: 6103169.652734818
# Episode 45, epoch [3/15], loss: 5100496.051674768
# Episode 45, epoch [4/15], loss: 9181784.606141804
# Episode 45, epoch [5/15], loss: 2938034.4877759637
# Episode 45, epoch [6/15], loss: 6381580.361366684
# Episode 45, epoch [7/15], loss: 2337232.6482460056
# Episode 45, epoch [8/15], loss: 8715005.392172238
# Episode 45, epoch [9/15], loss: 3355802.71579823
# Episode 45, epoch [10/15], loss: 5403337.115191576
# Episode 45, epoch [11/15], loss: 1681938.577915982
# Episode 45, epoch [12/15], loss: 6802072.035294192
# Episode 45, epoch [13/15], loss: 3530296.328541488
# Episode 45, epoch [14/15], loss: 4542564.336707437
# Episode 45, epoch [15/15], loss: 2792829.9263133933
# Episode 45 completed in 17.07 seconds
# Starting episode 46/500
# Episode 46, epoch [1/15], loss: 0.004211150715127588
# Episode 46, epoch [2/15], loss: 0.0032364492459843555
# Episode 46, epoch [3/15], loss: 0.002638900831031303
# Episode 46, epoch [4/15], loss: 0.002410636143758893
# Episode 46, epoch [5/15], loss: 0.0021156401606276633
# Episode 46, epoch [6/15], loss: 0.00202057669715335
# Episode 46, epoch [7/15], loss: 0.0020758168228591483
# Episode 46, epoch [8/15], loss: 0.0018279829062521457
# Episode 46, epoch [9/15], loss: 0.001779406393567721
# Episode 46, epoch [10/15], loss: 0.0019785020500421523
# Episode 46, epoch [11/15], loss: 0.0019220703281462193
# Episode 46, epoch [12/15], loss: 0.0018994291157772144
# Episode 46, epoch [13/15], loss: 0.0018656648385028045
# Episode 46, epoch [14/15], loss: 0.0015936871136849125
# Episode 46, epoch [15/15], loss: 0.0016487935519156358
# Episode 46 completed in 17.09 seconds
# Starting episode 47/500
# Episode 47, epoch [1/15], loss: 40384032944.76122
# Episode 47, epoch [2/15], loss: 25581300972.01359
# Episode 47, epoch [3/15], loss: 20075666700.16303
# Episode 47, epoch [4/15], loss: 15788912243.746088
# Episode 47, epoch [5/15], loss: 24976428508.67663
# Episode 47, epoch [6/15], loss: 17265455713.517014
# Episode 47, epoch [7/15], loss: 16433487088.596607
# Episode 47, epoch [8/15], loss: 11488751062.694477
# Episode 47, epoch [9/15], loss: 9275577896.090166
# Episode 47, epoch [10/15], loss: 11974370076.04846
# Episode 47, epoch [11/15], loss: 14456636911.109495
# Episode 47, epoch [12/15], loss: 9222236430.69366
# Episode 47, epoch [13/15], loss: 12874089540.6616
# Episode 47, epoch [14/15], loss: 13293410820.471361
# Episode 47, epoch [15/15], loss: 12965389053.464268
# Episode 47 completed in 16.98 seconds
# Starting episode 48/500
# Episode 48, epoch [1/15], loss: 0.005908952498187622
# Episode 48, epoch [2/15], loss: 0.0038351623341441156
# Episode 48, epoch [3/15], loss: 0.003162891557440162
# Episode 48, epoch [4/15], loss: 0.003082840982824564
# Episode 48, epoch [5/15], loss: 0.0029040490587552386
# Episode 48, epoch [6/15], loss: 0.002762851569180687
# Episode 48, epoch [7/15], loss: 0.0025913342367857696
# Episode 48, epoch [8/15], loss: 0.0027962701472764215
# Episode 48, epoch [9/15], loss: 0.00267380530325075
# Episode 48, epoch [10/15], loss: 0.002629440153638522
# Episode 48, epoch [11/15], loss: 0.0026208856453498203
# Episode 48, epoch [12/15], loss: 0.0024891883445282777
# Episode 48, epoch [13/15], loss: 0.002450892616373797
# Episode 48, epoch [14/15], loss: 0.0022920029936358334
# Episode 48, epoch [15/15], loss: 0.0023079696732262772
# Episode 48 completed in 16.98 seconds
# Starting episode 49/500
# Episode 49, epoch [1/15], loss: 0.06472746984412273
# Episode 49, epoch [2/15], loss: 0.060965954512357715
# Episode 49, epoch [3/15], loss: 0.07109377617016435
# Episode 49, epoch [4/15], loss: 0.05190737320420643
# Episode 49, epoch [5/15], loss: 0.06468318039551377
# Episode 49, epoch [6/15], loss: 0.05952542616675297
# Episode 49, epoch [7/15], loss: 0.07748175170272589
# Episode 49, epoch [8/15], loss: 0.06509209843352437
# Episode 49, epoch [9/15], loss: 0.055396394431591035
# Episode 49, epoch [10/15], loss: 0.06229779003188014
# Episode 49, epoch [11/15], loss: 0.04082779853294293
# Episode 49, epoch [12/15], loss: 0.04627733114175499
# Episode 49, epoch [13/15], loss: 0.04600633215159178
# Episode 49, epoch [14/15], loss: 0.05030511867565413
# Episode 49, epoch [15/15], loss: 0.05188653515651822
# Episode 49 completed in 16.80 seconds
# Starting episode 50/500
# Episode 50, epoch [1/15], loss: 151269376.05354446
# Episode 50, epoch [2/15], loss: 77877725.90207736
# Episode 50, epoch [3/15], loss: 87744648.56380168
# Episode 50, epoch [4/15], loss: 72453051.77092631
# Episode 50, epoch [5/15], loss: 44982967.501155496
# Episode 50, epoch [6/15], loss: 71517060.30652036
# Episode 50, epoch [7/15], loss: 54171370.69591538
# Episode 50, epoch [8/15], loss: 55691443.241712674
# Episode 50, epoch [9/15], loss: 39056550.42918838
# Episode 50, epoch [10/15], loss: 23683669.374717187
# Episode 50, epoch [11/15], loss: 76784273.09405221
# Episode 50, epoch [12/15], loss: 31678958.956014074
# Episode 50, epoch [13/15], loss: 35510692.296699025
# Episode 50, epoch [14/15], loss: 42228535.48703046
# Episode 50, epoch [15/15], loss: 56277819.753384605
# Episode 50 completed in 16.82 seconds
# Saved hidden representations for episode 50
# Starting episode 51/500
# Episode 51, epoch [1/15], loss: 0.010018565816183884
# Episode 51, epoch [2/15], loss: 0.009590693920229872
# Episode 51, epoch [3/15], loss: 0.00733521676932772
# Episode 51, epoch [4/15], loss: 0.007378588368495306
# Episode 51, epoch [5/15], loss: 0.007471064509203037
# Episode 51, epoch [6/15], loss: 0.007405391025046507
# Episode 51, epoch [7/15], loss: 0.008073649027695258
# Episode 51, epoch [8/15], loss: 0.008089285669848323
# Episode 51, epoch [9/15], loss: 0.0066697724939634405
# Episode 51, epoch [10/15], loss: 0.006990635162219405
# Episode 51, epoch [11/15], loss: 0.006833334034308791
# Episode 51, epoch [12/15], loss: 0.007910251912350456
# Episode 51, epoch [13/15], loss: 0.006680767967676123
# Episode 51, epoch [14/15], loss: 0.007748210492233436
# Episode 51, epoch [15/15], loss: 0.0064659374145170055
# Episode 51 completed in 17.19 seconds
# Starting episode 52/500
# Episode 52, epoch [1/15], loss: 0.06825359190503756
# Episode 52, epoch [2/15], loss: 0.05364055757721265
# Episode 52, epoch [3/15], loss: 0.04499687726298968
# Episode 52, epoch [4/15], loss: 0.04305013070503871
# Episode 52, epoch [5/15], loss: 0.04010635788242022
# Episode 52, epoch [6/15], loss: 0.04068219723800818
# Episode 52, epoch [7/15], loss: 0.0363147875914971
# Episode 52, epoch [8/15], loss: 0.03715110408763091
# Episode 52, epoch [9/15], loss: 0.036778281629085544
# Episode 52, epoch [10/15], loss: 0.03576800686617692
# Episode 52, epoch [11/15], loss: 0.03611566747228304
# Episode 52, epoch [12/15], loss: 0.0363756762817502
# Episode 52, epoch [13/15], loss: 0.036163546269138654
# Episode 52, epoch [14/15], loss: 0.036185289112230144
# Episode 52, epoch [15/15], loss: 0.035996957557896773
# Episode 52 completed in 17.07 seconds
# Starting episode 53/500
# Episode 53, epoch [1/15], loss: 0.005421502298365037
# Episode 53, epoch [2/15], loss: 0.0034588140745957694
# Episode 53, epoch [3/15], loss: 0.003445242345333099
# Episode 53, epoch [4/15], loss: 0.003243548236787319
# Episode 53, epoch [5/15], loss: 0.0031311646879961094
# Episode 53, epoch [6/15], loss: 0.002692766999825835
# Episode 53, epoch [7/15], loss: 0.0028837243327870963
# Episode 53, epoch [8/15], loss: 0.002942761103622615
# Episode 53, epoch [9/15], loss: 0.002806368648695449
# Episode 53, epoch [10/15], loss: 0.0028825434700896343
# Episode 53, epoch [11/15], loss: 0.002798558468930423
# Episode 53, epoch [12/15], loss: 0.002921768145946165
# Episode 53, epoch [13/15], loss: 0.0033655200075979035
# Episode 53, epoch [14/15], loss: 0.004066898689294855
# Episode 53, epoch [15/15], loss: 0.003510981456687053
# Episode 53 completed in 17.23 seconds
# Starting episode 54/500
# Episode 54, epoch [1/15], loss: 7691700.809660555
# Episode 54, epoch [2/15], loss: 10975651.211849865
# Episode 54, epoch [3/15], loss: 7338802.677934538
# Episode 54, epoch [4/15], loss: 8872333.346658034
# Episode 54, epoch [5/15], loss: 5285034.144386793
# Episode 54, epoch [6/15], loss: 4299265.343842167
# Episode 54, epoch [7/15], loss: 9969021.876774754
# Episode 54, epoch [8/15], loss: 5818953.609071954
# Episode 54, epoch [9/15], loss: 7057812.278835088
# Episode 54, epoch [10/15], loss: 5828762.6834198125
# Episode 54, epoch [11/15], loss: 5297368.547810802
# Episode 54, epoch [12/15], loss: 5212282.675645904
# Episode 54, epoch [13/15], loss: 6246304.549498675
# Episode 54, epoch [14/15], loss: 5677647.478733528
# Episode 54, epoch [15/15], loss: 5796890.681506441
# Episode 54 completed in 17.28 seconds
# Starting episode 55/500
# Episode 55, epoch [1/15], loss: 0.025865923815096416
# Episode 55, epoch [2/15], loss: 0.018824168077359597
# Episode 55, epoch [3/15], loss: 0.018725643663977585
# Episode 55, epoch [4/15], loss: 0.016587737062945963
# Episode 55, epoch [5/15], loss: 0.018434119441856942
# Episode 55, epoch [6/15], loss: 0.018671146221458913
# Episode 55, epoch [7/15], loss: 0.01584995340866347
# Episode 55, epoch [8/15], loss: 0.015029351289073626
# Episode 55, epoch [9/15], loss: 0.014396557584404945
# Episode 55, epoch [10/15], loss: 0.015166911172370116
# Episode 55, epoch [11/15], loss: 0.013797649865349133
# Episode 55, epoch [12/15], loss: 0.014425511363272865
# Episode 55, epoch [13/15], loss: 0.011812062157938877
# Episode 55, epoch [14/15], loss: 0.014780792035162449
# Episode 55, epoch [15/15], loss: 0.016011795277396837
# Episode 55 completed in 17.25 seconds
# Starting episode 56/500
# Episode 56, epoch [1/15], loss: 0.00992553224787116
# Episode 56, epoch [2/15], loss: 0.007308707479387522
# Episode 56, epoch [3/15], loss: 0.007766756384323041
# Episode 56, epoch [4/15], loss: 0.007173125818371773
# Episode 56, epoch [5/15], loss: 0.007012605729202429
# Episode 56, epoch [6/15], loss: 0.006552493882675966
# Episode 56, epoch [7/15], loss: 0.00544946410227567
# Episode 56, epoch [8/15], loss: 0.005231083479399482
# Episode 56, epoch [9/15], loss: 0.006221186850840847
# Episode 56, epoch [10/15], loss: 0.006192771003892024
# Episode 56, epoch [11/15], loss: 0.005453893185282747
# Episode 56, epoch [12/15], loss: 0.00639741161527733
# Episode 56, epoch [13/15], loss: 0.006079016393050552
# Episode 56, epoch [14/15], loss: 0.005189135003214081
# Episode 56, epoch [15/15], loss: 0.00521222244327267
# Episode 56 completed in 17.21 seconds
# Starting episode 57/500
# Episode 57, epoch [1/15], loss: 0.052471771091222766
# Episode 57, epoch [2/15], loss: 0.044250722291568914
# Episode 57, epoch [3/15], loss: 0.04317799611017108
# Episode 57, epoch [4/15], loss: 0.04157809894531965
# Episode 57, epoch [5/15], loss: 0.04225905379280448
# Episode 57, epoch [6/15], loss: 0.04122025892138481
# Episode 57, epoch [7/15], loss: 0.03879654252280792
# Episode 57, epoch [8/15], loss: 0.04056369156266252
# ...
# Episode 482, epoch [12/15], loss: 0.015345763601362705
# Episode 482, epoch [13/15], loss: 0.011786157148890197
# Episode 482, epoch [14/15], loss: 0.012158486891227465
# Episode 482, epoch [15/15], loss: 0.010611100044722358
# Episode 482 completed in 16.53 seconds
# Starting episode 483/500
# Episode 483, epoch [1/15], loss: 0.013256495624470213
# Episode 483, epoch [2/15], loss: 0.013033386428530018
# Episode 483, epoch [3/15], loss: 0.01411890819047888
# Episode 483, epoch [4/15], loss: 0.013636716346566876
# Episode 483, epoch [5/15], loss: 0.014550711183498303
# Episode 483, epoch [6/15], loss: 0.011459755486187835
# Episode 483, epoch [7/15], loss: 0.011165186025512716
# Episode 483, epoch [8/15], loss: 0.01078938893818607
# Episode 483, epoch [9/15], loss: 0.011740119374978045
# Episode 483, epoch [10/15], loss: 0.009244143916293978
# Episode 483, epoch [11/15], loss: 0.012089129351079465
# Episode 483, epoch [12/15], loss: 0.009319207530158262
# Episode 483, epoch [13/15], loss: 0.011833096167538314
# Episode 483, epoch [14/15], loss: 0.009597661594549814
# Episode 483, epoch [15/15], loss: 0.009893820007952551
# Episode 483 completed in 16.63 seconds
# Starting episode 484/500
# Episode 484, epoch [1/15], loss: 6701425177.616681
# Episode 484, epoch [2/15], loss: 10996498440.546896
# Episode 484, epoch [3/15], loss: 4484991325.882563
# Episode 484, epoch [4/15], loss: 13439184341.357294
# Episode 484, epoch [5/15], loss: 16668211366.417418
# Episode 484, epoch [6/15], loss: 19734829704.556534
# Episode 484, epoch [7/15], loss: 2392818824.5736437
# Episode 484, epoch [8/15], loss: 6007629717.354156
# Episode 484, epoch [9/15], loss: 8330475110.414057
# Episode 484, epoch [10/15], loss: 7068178180.301421
# Episode 484, epoch [11/15], loss: 3596813619.2157426
# Episode 484, epoch [12/15], loss: 11819725431.479963
# Episode 484, epoch [13/15], loss: 6514526916.282484
# Episode 484, epoch [14/15], loss: 20838101811.213547
# Episode 484, epoch [15/15], loss: 3779472042.677936
# Episode 484 completed in 16.57 seconds
# Starting episode 485/500
# Episode 485, epoch [1/15], loss: 0.0023245391668751834
# Episode 485, epoch [2/15], loss: 0.0020431789569556715
# Episode 485, epoch [3/15], loss: 0.0018038555087211232
# Episode 485, epoch [4/15], loss: 0.0018058514300112922
# Episode 485, epoch [5/15], loss: 0.001651364762801677
# Episode 485, epoch [6/15], loss: 0.0011735398128318289
# Episode 485, epoch [7/15], loss: 0.0012838006912109753
# Episode 485, epoch [8/15], loss: 0.0012748504251552126
# Episode 485, epoch [9/15], loss: 0.0013515548586534958
# Episode 485, epoch [10/15], loss: 0.0012055146663139263
# Episode 485, epoch [11/15], loss: 0.0010390585055574774
# Episode 485, epoch [12/15], loss: 0.0010901258792728186
# Episode 485, epoch [13/15], loss: 0.001013390300795436
# Episode 485, epoch [14/15], loss: 0.001052853191504255
# Episode 485, epoch [15/15], loss: 0.0019454412821990749
# Episode 485 completed in 16.81 seconds
# Starting episode 486/500
# Episode 486, epoch [1/15], loss: 0.022331486099089186
# Episode 486, epoch [2/15], loss: 0.028043579290776204
# Episode 486, epoch [3/15], loss: 0.022543083364143967
# Episode 486, epoch [4/15], loss: 0.025235673955952127
# Episode 486, epoch [5/15], loss: 0.02238423333813747
# Episode 486, epoch [6/15], loss: 0.02188362597177426
# Episode 486, epoch [7/15], loss: 0.015115298160041372
# Episode 486, epoch [8/15], loss: 0.014797825862963994
# Episode 486, epoch [9/15], loss: 0.014282874087803066
# Episode 486, epoch [10/15], loss: 0.01646693629833559
# Episode 486, epoch [11/15], loss: 0.017876728383513788
# Episode 486, epoch [12/15], loss: 0.013105599163100123
# Episode 486, epoch [13/15], loss: 0.013498587789945305
# Episode 486, epoch [14/15], loss: 0.0314728511031717
# Episode 486, epoch [15/15], loss: 0.017255381828484437
# Episode 486 completed in 17.06 seconds
# Starting episode 487/500
# Episode 487, epoch [1/15], loss: 0.009913713694550097
# Episode 487, epoch [2/15], loss: 0.00845355368219316
# Episode 487, epoch [3/15], loss: 0.00850225518612812
# Episode 487, epoch [4/15], loss: 0.01149490283957372
# Episode 487, epoch [5/15], loss: 0.009930208216731747
# Episode 487, epoch [6/15], loss: 0.006999688370463749
# Episode 487, epoch [7/15], loss: 0.007082422108699878
# Episode 487, epoch [8/15], loss: 0.00771712875381733
# Episode 487, epoch [9/15], loss: 0.007625924710494777
# Episode 487, epoch [10/15], loss: 0.007055939586522678
# Episode 487, epoch [11/15], loss: 0.006168889995509138
# Episode 487, epoch [12/15], loss: 0.0062348071951419115
# Episode 487, epoch [13/15], loss: 0.006671581557020545
# Episode 487, epoch [14/15], loss: 0.010022374948797126
# Episode 487, epoch [15/15], loss: 0.010109079691270987
# Episode 487 completed in 16.62 seconds
# Starting episode 488/500
# Episode 488, epoch [1/15], loss: 575449.4255834616
# Episode 488, epoch [2/15], loss: 1381415.4836330025
# Episode 488, epoch [3/15], loss: 412952.61675946123
# Episode 488, epoch [4/15], loss: 927958.878463694
# Episode 488, epoch [5/15], loss: 425190.3481587574
# Episode 488, epoch [6/15], loss: 503511.61329899426
# Episode 488, epoch [7/15], loss: 597068.8160958766
# Episode 488, epoch [8/15], loss: 211867.8726196947
# Episode 488, epoch [9/15], loss: 683971.4980006878
# Episode 488, epoch [10/15], loss: 933358.6327541039
# Episode 488, epoch [11/15], loss: 220672.67829122985
# Episode 488, epoch [12/15], loss: 1674923.2161728337
# Episode 488, epoch [13/15], loss: 781095.4132675857
# Episode 488, epoch [14/15], loss: 1024877.9576493832
# Episode 488, epoch [15/15], loss: 203594.4700037933
# Episode 488 completed in 16.90 seconds
# Starting episode 489/500
# Episode 489, epoch [1/15], loss: 0.05074241186181704
# Episode 489, epoch [2/15], loss: 0.07168808784335852
# Episode 489, epoch [3/15], loss: 0.06701927991428723
# Episode 489, epoch [4/15], loss: 0.059375983538726966
# Episode 489, epoch [5/15], loss: 0.06779370112344622
# Episode 489, epoch [6/15], loss: 0.05474319001659751
# Episode 489, epoch [7/15], loss: 0.05450616247641544
# Episode 489, epoch [8/15], loss: 0.041844710459311804
# Episode 489, epoch [9/15], loss: 0.04286149845769008
# Episode 489, epoch [10/15], loss: 0.04019034577067941
# Episode 489, epoch [11/15], loss: 0.04116319104408225
# Episode 489, epoch [12/15], loss: 0.044148396436745924
# Episode 489, epoch [13/15], loss: 0.04113413024848948
# Episode 489, epoch [14/15], loss: 0.05246864586758117
# Episode 489, epoch [15/15], loss: 0.03259558784775436
# Episode 489 completed in 16.86 seconds
# Starting episode 490/500
# Episode 490, epoch [1/15], loss: 0.012350347265601158
# Episode 490, epoch [2/15], loss: 0.011546427352974812
# Episode 490, epoch [3/15], loss: 0.009761408359433213
# Episode 490, epoch [4/15], loss: 0.00962108257226646
# Episode 490, epoch [5/15], loss: 0.006455127095493177
# Episode 490, epoch [6/15], loss: 0.008172759615505735
# Episode 490, epoch [7/15], loss: 0.006531733740121126
# Episode 490, epoch [8/15], loss: 0.007264504752432306
# Episode 490, epoch [9/15], loss: 0.004485799418762326
# Episode 490, epoch [10/15], loss: 0.0037863648341347773
# Episode 490, epoch [11/15], loss: 0.003808977408334613
# Episode 490, epoch [12/15], loss: 0.0032528442563489078
# Episode 490, epoch [13/15], loss: 0.0032304219979171953
# Episode 490, epoch [14/15], loss: 0.0031399888219311835
# Episode 490, epoch [15/15], loss: 0.003009569163744648
# Episode 490 completed in 17.06 seconds
# Saved hidden representations for episode 490
# Starting episode 491/500
# Episode 491, epoch [1/15], loss: 0.007605867149929206
# Episode 491, epoch [2/15], loss: 0.0074088073413198195
# Episode 491, epoch [3/15], loss: 0.007444235403090716
# Episode 491, epoch [4/15], loss: 0.009027622201635192
# Episode 491, epoch [5/15], loss: 0.009790097549557685
# Episode 491, epoch [6/15], loss: 0.016015908867120742
# Episode 491, epoch [7/15], loss: 0.013450682784120241
# Episode 491, epoch [8/15], loss: 0.012058342977737387
# Episode 491, epoch [9/15], loss: 0.011591167903194826
# Episode 491, epoch [10/15], loss: 0.011430237838067115
# Episode 491, epoch [11/15], loss: 0.012255324112872282
# Episode 491, epoch [12/15], loss: 0.010481469876443347
# Episode 491, epoch [13/15], loss: 0.013370731961913407
# Episode 491, epoch [14/15], loss: 0.00636763166791449
# Episode 491, epoch [15/15], loss: 0.007410619043124219
# Episode 491 completed in 16.63 seconds
# Starting episode 492/500
# Episode 492, epoch [1/15], loss: 1025616.801472896
# Episode 492, epoch [2/15], loss: 1525131.9351626814
# Episode 492, epoch [3/15], loss: 1247348.3013853668
# Episode 492, epoch [4/15], loss: 2379592.2012134464
# Episode 492, epoch [5/15], loss: 854918.8013097733
# Episode 492, epoch [6/15], loss: 1368051.1014444875
# Episode 492, epoch [7/15], loss: 2235170.4013313646
# Episode 492, epoch [8/15], loss: 1048644.7350710935
# Episode 492, epoch [9/15], loss: 984852.9353271556
# Episode 492, epoch [10/15], loss: 573045.5018541993
# Episode 492, epoch [11/15], loss: 739227.1677576907
# Episode 492, epoch [12/15], loss: 665481.4175946297
# Episode 492, epoch [13/15], loss: 751712.5013961704
# Episode 492, epoch [14/15], loss: 438395.9512439792
# Episode 492, epoch [15/15], loss: 932663.3677402098
# Episode 492 completed in 16.96 seconds
# Starting episode 493/500
# Episode 493, epoch [1/15], loss: 0.001571320197156941
# Episode 493, epoch [2/15], loss: 0.0012181672694471974
# Episode 493, epoch [3/15], loss: 0.0009305858732356379
# Episode 493, epoch [4/15], loss: 0.0009456423091857383
# Episode 493, epoch [5/15], loss: 0.0008118472333687048
# Episode 493, epoch [6/15], loss: 0.0007081506172350297
# Episode 493, epoch [7/15], loss: 0.0005952643832036604
# Episode 493, epoch [8/15], loss: 0.0005194209069789697
# Episode 493, epoch [9/15], loss: 0.0005496480366370331
# Episode 493, epoch [10/15], loss: 0.0005949990901475151
# Episode 493, epoch [11/15], loss: 0.0008659524105799695
# Episode 493, epoch [12/15], loss: 0.0008528604346793145
# Episode 493, epoch [13/15], loss: 0.0011272828987178704
# Episode 493, epoch [14/15], loss: 0.0015141229688500366
# Episode 493, epoch [15/15], loss: 0.0012477729314317306
# Episode 493 completed in 16.73 seconds
# Starting episode 494/500
# Episode 494, epoch [1/15], loss: 0.007184471399523318
# Episode 494, epoch [2/15], loss: 0.00680901954571406
# Episode 494, epoch [3/15], loss: 0.006877223472110927
# Episode 494, epoch [4/15], loss: 0.006372996629215777
# Episode 494, epoch [5/15], loss: 0.00816997750274216
# Episode 494, epoch [6/15], loss: 0.005068316772424927
# Episode 494, epoch [7/15], loss: 0.0051996198870862525
# Episode 494, epoch [8/15], loss: 0.006768225141180058
# Episode 494, epoch [9/15], loss: 0.005117302073631436
# Episode 494, epoch [10/15], loss: 0.005522202122180412
# Episode 494, epoch [11/15], loss: 0.004538968026948472
# Episode 494, epoch [12/15], loss: 0.005443082579101126
# Episode 494, epoch [13/15], loss: 0.0034452268465732534
# Episode 494, epoch [14/15], loss: 0.004148166646094372
# Episode 494, epoch [15/15], loss: 0.004105782380793244
# Episode 494 completed in 16.70 seconds
# Starting episode 495/500
# Episode 495, epoch [1/15], loss: 0.0060468401527032254
# Episode 495, epoch [2/15], loss: 0.005221753963269293
# Episode 495, epoch [3/15], loss: 0.00382720868413647
# Episode 495, epoch [4/15], loss: 0.003949917845117549
# Episode 495, epoch [5/15], loss: 0.00293509802625825
# Episode 495, epoch [6/15], loss: 0.003234917623922229
# Episode 495, epoch [7/15], loss: 0.002378064440563321
# Episode 495, epoch [8/15], loss: 0.002895802154671401
# Episode 495, epoch [9/15], loss: 0.0031679428725813826
# Episode 495, epoch [10/15], loss: 0.002693777143334349
# Episode 495, epoch [11/15], loss: 0.0036354954664905865
# Episode 495, epoch [12/15], loss: 0.0027520470748034617
# Episode 495, epoch [13/15], loss: 0.0034740020132934053
# Episode 495, epoch [14/15], loss: 0.0024637914185101787
# Episode 495, epoch [15/15], loss: 0.0029711815373351176
# Episode 495 completed in 16.91 seconds
# Starting episode 496/500
# Episode 496, epoch [1/15], loss: 0.5807432225594918
# Episode 496, epoch [2/15], loss: 0.6400478163113197
# Episode 496, epoch [3/15], loss: 0.5169962648302316
# Episode 496, epoch [4/15], loss: 0.6647229127275447
# Episode 496, epoch [5/15], loss: 0.7828403035489221
# Episode 496, epoch [6/15], loss: 0.46476344478627046
# Episode 496, epoch [7/15], loss: 0.702149145429333
# Episode 496, epoch [8/15], loss: 0.5208814637114604
# Episode 496, epoch [9/15], loss: 0.35542429440344375
# Episode 496, epoch [10/15], loss: 0.356040412451451
# Episode 496, epoch [11/15], loss: 0.33300350115944943
# Episode 496, epoch [12/15], loss: 0.3931573142297566
# Episode 496, epoch [13/15], loss: 0.7071045257772008
# Episode 496, epoch [14/15], loss: 0.7751700807362795
# Episode 496, epoch [15/15], loss: 0.3424174039624631
# Episode 496 completed in 16.69 seconds
# Starting episode 497/500
# Episode 497, epoch [1/15], loss: 315542.0058947816
# Episode 497, epoch [2/15], loss: 672919.0781704242
# Episode 497, epoch [3/15], loss: 355313.83903339616
# Episode 497, epoch [4/15], loss: 458356.07273117534
# Episode 497, epoch [5/15], loss: 269304.73818830046
# Episode 497, epoch [6/15], loss: 427138.2702720441
# Episode 497, epoch [7/15], loss: 256902.1215955023
# Episode 497, epoch [8/15], loss: 405841.1029721617
# Episode 497, epoch [9/15], loss: 261771.853691162
# Episode 497, epoch [10/15], loss: 314126.23739518103
# Episode 497, epoch [11/15], loss: 158791.8716080833
# Episode 497, epoch [12/15], loss: 380745.8046419189
# Episode 497, epoch [13/15], loss: 164282.5381861446
# Episode 497, epoch [14/15], loss: 139849.22261518927
# Episode 497, epoch [15/15], loss: 129490.01210435347
# Episode 497 completed in 16.74 seconds
# Starting episode 498/500
# Episode 498, epoch [1/15], loss: 3666557.8885508934
# Episode 498, epoch [2/15], loss: 4603752.553460431
# Episode 498, epoch [3/15], loss: 2373839.497822554
# Episode 498, epoch [4/15], loss: 2903613.087434024
# Episode 498, epoch [5/15], loss: 1087624.557880808
# Episode 498, epoch [6/15], loss: 7263329.0888306955
# Episode 498, epoch [7/15], loss: 2406939.747658798
# Episode 498, epoch [8/15], loss: 3074390.682709389
# Episode 498, epoch [9/15], loss: 1727873.2166653434
# Episode 498, epoch [10/15], loss: 2118819.083230248
# Episode 498, epoch [11/15], loss: 1029126.4126262105
# Episode 498, epoch [12/15], loss: 2958757.6137894276
# Episode 498, epoch [13/15], loss: 1742029.4836796685
# Episode 498, epoch [14/15], loss: 2104540.28494613
# Episode 498, epoch [15/15], loss: 934818.8894346036
# Episode 498 completed in 17.05 seconds
# Starting episode 499/500
# Episode 499, epoch [1/15], loss: 0.014041677676141262
# Episode 499, epoch [2/15], loss: 0.013433647031585375
# Episode 499, epoch [3/15], loss: 0.015399159428973993
# Episode 499, epoch [4/15], loss: 0.009498500800691544
# Episode 499, epoch [5/15], loss: 0.007423986401408911
# Episode 499, epoch [6/15], loss: 0.008297341285894315
# Episode 499, epoch [7/15], loss: 0.00941450271445016
# Episode 499, epoch [8/15], loss: 0.0099926451065888
# Episode 499, epoch [9/15], loss: 0.006484215582410495
# Episode 499, epoch [10/15], loss: 0.01067907784987862
# Episode 499, epoch [11/15], loss: 0.012918738229200245
# Episode 499, epoch [12/15], loss: 0.013153373667349418
# Episode 499, epoch [13/15], loss: 0.007181994539375107
# Episode 499, epoch [14/15], loss: 0.006896705762483179
# Episode 499, epoch [15/15], loss: 0.01175600963179022
# Episode 499 completed in 16.77 seconds
# Starting episode 500/500
# Episode 500, epoch [1/15], loss: 38050952.54307875
# Episode 500, epoch [2/15], loss: 296389358.9465884
# Episode 500, epoch [3/15], loss: 100380390.41006276
# Episode 500, epoch [4/15], loss: 283822728.5441703
# Episode 500, epoch [5/15], loss: 58965627.74171873
# Episode 500, epoch [6/15], loss: 265228151.47632825
# Episode 500, epoch [7/15], loss: 20808202.67432541
# Episode 500, epoch [8/15], loss: 164937557.34081575
# Episode 500, epoch [9/15], loss: 65958382.93993564
# Episode 500, epoch [10/15], loss: 197082624.00734264
# Episode 500, epoch [11/15], loss: 107392366.94394603
# Episode 500, epoch [12/15], loss: 328052462.9421555
# Episode 500, epoch [13/15], loss: 146394521.6097115
# Episode 500, epoch [14/15], loss: 222574387.20877594
# Episode 500, epoch [15/15], loss: 79336012.80593087
# Episode 500 completed in 16.75 seconds
# Saved hidden representations for episode 500
# Training finished!

# %%
write1 = "/Users/maks/Documents/MSc_project/data/models/branching_ae_long_test.pth"

torch.save(model.state_dict(), write1)
print(f"Model saved to {write1}")
# Out:
# Model saved to /Users/maks/Documents/MSc_project/data/models/branching_ae_long_test.pth

# %%
variable_names = ["Velocity x", "Velocity y", "Velocity z", "Tortuosity 3d", "Angular Velocity yz", "Angular Velocity xz", "Angular Velocity xy"]

#Visualising reconstructed data
def plot_reconstruction(original, reconstructed, n = 5):
    
    plt.figure(figsize = (15, 10))

    for i in range(n):
        for j in range(7):
            ax = plt.subplot(n, 7, i * 7 + j + 1)
            plt.plot(original[i][:, j].numpy(), label = "Original")
            plt.plot(reconstructed[i][:, j].detach().numpy(), label = "Reconstructed")
            
            if j == 0:
                ax.set_ylabel(f"Sample {i + 1}")
            if i == 0:
                ax.set_title(variable_names[j])
            if i == n - 1 and j == 2:
                ax.legend()

    plt.subplots_adjust(wspace=0.35, hspace=0.35)
    
    plt.show()

# %%
test_data = next(iter(dataloader))
reconstructed_data = model(test_data)

plot_reconstruction(test_data, reconstructed_data)
